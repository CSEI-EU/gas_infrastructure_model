# %% [markdown]
# # Model to transform infrastructure
#
# - enables to transform the methane into a hydrogen network
# - allows for new investments on defined edges
# - bidirectional net flows on edges possible

# %% [markdown]
# ### Import packages

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd
import networkx as nx

# %% [markdown]
# ### Import data

# %%
# Specify the path to your Excel file
input_file_path = '../01_data/01_input_data/02_processed/'
excel_file_path = 'Data_update_V02.xlsx'  

# Read the Excel file into a DataFrame
df_nodes = pd.read_excel(input_file_path + excel_file_path, sheet_name='Nodes')
df_commodities = pd.read_excel(input_file_path + excel_file_path, sheet_name='Commodities')
df_edges = pd.read_excel(input_file_path + excel_file_path, sheet_name='Edges')
df_parameter = pd.read_excel(input_file_path + excel_file_path, sheet_name='Parameters')
df_supply_values = pd.read_excel(input_file_path + excel_file_path, sheet_name='Supply')

# %% [markdown]
# ### Create input data structure

# %%
#commodities
commodities = df_commodities['Commodities'].tolist()

#nodes
nodes = df_nodes['Nodes'].tolist()

#edges
edges_base = list(zip(df_edges['Source'], df_edges['Destination']))

#initial capacities
capacity_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['initial_capacities'] 
                 for _, row in df_parameter.iterrows()}

#maximal capacities
capacity_limit_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['max_capacities'] 
                 for _, row in df_parameter.iterrows()}

#variable transportation cost
cost_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['costs_edge'] 
                 for _, row in df_parameter.iterrows()}

#investment cost new capacity
investment_cost_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['new_build_cost'] 
                 for _, row in df_parameter.iterrows()}

#investment cost convert capacity
conversion_cost_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['conversion_cost'] 
                 for _, row in df_parameter.iterrows()}

#converseion capacity factor
conversion_capacity_factor = {tuple(row[['Commodity', 'Source', 'Destination']]): row['conversion_capacity_factor'] 
                 for _, row in df_parameter.iterrows()}

#demand and supply
inflow = {tuple(row[['Commodity', 'Node']]): row['Supply'] 
                 for _, row in df_supply_values.iterrows()}

# %% [markdown]
# ### adjust input data

# %%
# Reverse edges
edges_reverse = [(destination, source) for source, destination in edges_base]

# Combined edges
edges = edges_base + edges_reverse

# Reverse cap
capacity_reverse = {(k, j, i): cap for (k, i, j), cap in capacity_base.items()}

capacity = {**capacity_base, **capacity_reverse}

# Reverse cap
capacity_limit_reverse = {(k, j, i): cap for (k, i, j), cap in capacity_limit_base.items()}

capacity_limit = {**capacity_limit_base, **capacity_limit_reverse}

# Reverse cost
cost_reverse = {(k, j, i): cost for (k, i, j), cost in cost_base.items()}

cost = {**cost_base, **cost_reverse}

# Reverse cost
investment_cost_reverse = {(k, j, i): cost for (k, i, j), cost in investment_cost_base.items()}

investment_cost = {**investment_cost_base, **investment_cost_reverse}

# Reverse cost
conversion_cost_reverse = {(k, j, i): cost for (k, i, j), cost in conversion_cost_base.items()}

conversion_cost = {**conversion_cost_base, **conversion_cost_reverse}

# %% [markdown]
# ### Network control

# %%
#check in all nodes are connected via edges

G = nx.Graph()
G.add_edges_from(edges_base)

# Check if the graph is connected
if nx.is_connected(G):
    print("The graph is connected.")
else:
    print("The graph is not connected.")
# Out:
# The graph is connected.

# %%
# Check if all nodes are connected
if set(nodes) in nx.connected_components(G):
    print("All nodes are connected.")
else:
    print("Not all nodes are connected.")
# Out:
# All nodes are connected.

# %%
if len(edges) != len(set(edges)):
    print("There are duplicates in the list of tuples.")
else:
    print("No duplicates found in the list of tuples.")
# Out:
# There are duplicates in the list of tuples.

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create model

# %%
# Create optimization model
m = gp.Model("Grid_Transformation")

# %% [markdown]
# ### Define variables

# %%
edges
# Out:
# [('node_0001', 'node_0002_2'),
#  ('node_0001', 'node_0002_1'),
#  ('node_0002', 'node_0362'),
#  ('node_0003', 'node_0004'),
#  ('node_0003', 'node_0196'),
#  ('node_0003', 'node_0383'),
#  ('node_0003', 'node_0381'),
#  ('node_0003', 'node_0006_2'),
#  ('node_0003', 'node_0382'),
#  ('node_0003', 'node_0006_1'),
#  ('node_0004', 'node_0005'),
#  ('node_0005', 'node_0006'),
#  ('node_0006', 'node_0007'),
#  ('node_0006', 'node_0200'),
#  ('node_0006', 'node_0384_1'),
#  ('node_0006', 'node_0384_2'),
#  ('node_0006', 'node_0195'),
#  ('node_0006', 'node_0008'),
#  ('node_0006', 'node_0385'),
#  ('node_0007', 'node_0389'),
#  ('node_0007', 'node_0013'),
#  ('node_0007', 'node_0384_1'),
#  ('node_0007', 'node_0386'),
#  ('node_0007', 'node_0384_2'),
#  ('node_0007', 'node_0009_4'),
#  ('node_0007', 'node_0010'),
#  ('node_0007', 'node_0387'),
#  ('node_0007', 'node_0009_3'),
#  ('node_0007', 'node_0009_2'),
#  ('node_0007', 'node_0009_1'),
#  ('node_0007', 'node_0388'),
#  ('node_0008', 'node_0195_2'),
#  ('node_0008', 'node_0019'),
#  ('node_0008', 'node_0018_2'),
#  ('node_0008', 'node_0018_1'),
#  ('node_0008', 'node_0195_1'),
#  ('node_0008', 'node_0194'),
#  ('node_0008', 'node_0195_3'),
#  ('node_0008', 'node_0013_2'),
#  ('node_0008', 'node_0015_1'),
#  ('node_0008', 'node_0014'),
#  ('node_0008', 'node_0015_2'),
#  ('node_0008', 'node_0013_1'),
#  ('node_0009', 'node_0010'),
#  ('node_0009', 'node_0011'),
#  ('node_0009', 'node_0097_2'),
#  ('node_0009', 'node_0012'),
#  ('node_0009', 'node_0097_1'),
#  ('node_0009', 'node_0391_2'),
#  ('node_0009', 'node_0013'),
#  ('node_0009', 'node_0391_1'),
#  ('node_0009', 'node_0390'),
#  ('node_0010', 'node_0097'),
#  ('node_0010', 'node_0392'),
#  ('node_0011', 'node_0097'),
#  ('node_0011', 'node_0098'),
#  ('node_0011', 'node_0395_1'),
#  ('node_0011', 'node_0395_2'),
#  ('node_0011', 'node_0396'),
#  ('node_0011', 'node_0393_1'),
#  ('node_0011', 'node_0394'),
#  ('node_0011', 'node_0096'),
#  ('node_0011', 'node_0393_2'),
#  ('node_0011', 'node_0022'),
#  ('node_0011', 'node_0021_2'),
#  ('node_0011', 'node_0012_2'),
#  ('node_0011', 'node_0021_1'),
#  ('node_0011', 'node_0021_3'),
#  ('node_0011', 'node_0012_1'),
#  ('node_0012', 'node_0018'),
#  ('node_0012', 'node_0367'),
#  ('node_0012', 'node_0097'),
#  ('node_0012', 'node_0020'),
#  ('node_0012', 'node_0021'),
#  ('node_0012', 'node_0019'),
#  ('node_0013', 'node_0398'),
#  ('node_0013', 'node_0384'),
#  ('node_0013', 'node_0397'),
#  ('node_0014', 'node_0016'),
#  ('node_0014', 'node_0015'),
#  ('node_0014', 'node_0399'),
#  ('node_0014', 'node_0017'),
#  ('node_0015', 'node_0019'),
#  ('node_0015', 'node_0400'),
#  ('node_0015', 'node_0016'),
#  ('node_0016', 'node_0401'),
#  ('node_0016', 'node_0034_1'),
#  ('node_0016', 'node_0193'),
#  ('node_0016', 'node_0031'),
#  ('node_0016', 'node_0192'),
#  ('node_0016', 'node_0034_2'),
#  ('node_0017', 'node_0032'),
#  ('node_0017', 'node_0205'),
#  ('node_0017', 'node_0404'),
#  ('node_0017', 'node_0403'),
#  ('node_0017', 'node_0402'),
#  ('node_0018', 'node_0405'),
#  ('node_0018', 'node_0019'),
#  ('node_0018', 'node_0198'),
#  ('node_0018', 'node_0197'),
#  ('node_0018', 'node_0020'),
#  ('node_0019', 'node_0200'),
#  ('node_0019', 'node_0020'),
#  ('node_0019', 'node_0034'),
#  ('node_0020', 'node_0197'),
#  ('node_0020', 'node_0407'),
#  ('node_0020', 'node_0406'),
#  ('node_0021', 'node_0387'),
#  ('node_0021', 'node_0201_1'),
#  ('node_0021', 'node_0033'),
#  ('node_0021', 'node_0201_2'),
#  ('node_0022', 'node_0023'),
#  ('node_0022', 'node_0408'),
#  ('node_0023', 'node_0393'),
#  ('node_0023', 'node_0410'),
#  ('node_0023', 'node_0409'),
#  ('node_0023', 'node_0024_1'),
#  ('node_0023', 'node_0024_2'),
#  ('node_0024', 'node_0025'),
#  ('node_0025', 'node_0027_1'),
#  ('node_0025', 'node_0027_2'),
#  ('node_0025', 'node_0026'),
#  ('node_0026', 'node_0180'),
#  ('node_0026', 'node_0206'),
#  ('node_0026', 'node_0179'),
#  ('node_0026', 'node_0412'),
#  ('node_0026', 'node_0411'),
#  ('node_0027', 'node_0028'),
#  ('node_0027', 'node_0029'),
#  ('node_0028', 'node_0413'),
#  ('node_0028', 'node_0414'),
#  ('node_0029', 'node_0030'),
#  ('node_0029', 'node_0415'),
#  ('node_0029', 'node_0416'),
#  ('node_0030', 'node_0037'),
#  ('node_0030', 'node_0031'),
#  ('node_0031', 'node_0212_2'),
#  ('node_0031', 'node_0205'),
#  ('node_0031', 'node_0207'),
#  ('node_0031', 'node_0037'),
#  ('node_0031', 'node_0211'),
#  ('node_0031', 'node_0212_1'),
#  ('node_0031', 'node_0047'),
#  ('node_0031', 'node_0046'),
#  ('node_0031', 'node_0035'),
#  ('node_0031', 'node_0417'),
#  ('node_0031', 'node_0411'),
#  ('node_0032', 'node_0166'),
#  ('node_0032', 'node_0036_1'),
#  ('node_0032', 'node_0379'),
#  ('node_0032', 'node_0194'),
#  ('node_0032', 'node_0036_2'),
#  ('node_0032', 'node_0193'),
#  ('node_0032', 'node_0036_3'),
#  ('node_0032', 'node_0418'),
#  ('node_0032', 'node_0036_4'),
#  ('node_0033', 'node_0034'),
#  ('node_0033', 'node_0035'),
#  ('node_0034', 'node_0035'),
#  ('node_0035', 'node_0419'),
#  ('node_0036', 'node_0418'),
#  ('node_0036', 'node_0048'),
#  ('node_0036', 'node_0182'),
#  ('node_0037', 'node_0038'),
#  ('node_0037', 'node_0183'),
#  ('node_0037', 'node_0182'),
#  ('node_0037', 'node_0420'),
#  ('node_0038', 'node_0183'),
#  ('node_0038', 'node_0039'),
#  ('node_0038', 'node_0042'),
#  ('node_0038', 'node_0421'),
#  ('node_0039', 'node_0040'),
#  ('node_0040', 'node_0041'),
#  ('node_0040', 'node_0422'),
#  ('node_0041', 'node_0357'),
#  ('node_0041', 'node_0354'),
#  ('node_0041', 'node_0353'),
#  ('node_0041', 'node_0171'),
#  ('node_0041', 'node_0213'),
#  ('node_0041', 'node_0423'),
#  ('node_0042', 'node_0043'),
#  ('node_0043', 'node_0044'),
#  ('node_0043', 'node_0417'),
#  ('node_0043', 'node_0212'),
#  ('node_0043', 'node_0094'),
#  ('node_0043', 'node_0352'),
#  ('node_0043', 'node_0088'),
#  ('node_0043', 'node_0087'),
#  ('node_0043', 'node_0069'),
#  ('node_0044', 'node_0352_1'),
#  ('node_0044', 'node_0143'),
#  ('node_0044', 'node_0045'),
#  ('node_0044', 'node_0352_2'),
#  ('node_0044', 'node_0353'),
#  ('node_0044', 'node_0423_1'),
#  ('node_0044', 'node_0423_2'),
#  ('node_0045', 'node_0425'),
#  ('node_0045', 'node_0424'),
#  ('node_0046', 'node_0212_2'),
#  ('node_0046', 'node_0212_1'),
#  ('node_0046', 'node_0417'),
#  ('node_0046', 'node_0426'),
#  ('node_0047', 'node_0048'),
#  ('node_0047', 'node_0427'),
#  ('node_0048', 'node_0428'),
#  ('node_0049', 'node_0108'),
#  ('node_0049', 'node_0429_1'),
#  ('node_0049', 'node_0329'),
#  ('node_0049', 'node_0050'),
#  ('node_0049', 'node_0429_2'),
#  ('node_0050', 'node_0065'),
#  ('node_0050', 'node_0051'),
#  ('node_0050', 'node_0054'),
#  ('node_0051', 'node_0325'),
#  ('node_0051', 'node_0430'),
#  ('node_0051', 'node_0052_1'),
#  ('node_0051', 'node_0053'),
#  ('node_0051', 'node_0052_3'),
#  ('node_0051', 'node_0052_2'),
#  ('node_0052', 'node_0329'),
#  ('node_0052', 'node_0324'),
#  ('node_0052', 'node_0431'),
#  ('node_0053', 'node_0432'),
#  ('node_0053', 'node_0054'),
#  ('node_0054', 'node_0055'),
#  ('node_0054', 'node_0065'),
#  ('node_0054', 'node_0064'),
#  ('node_0055', 'node_0433'),
#  ('node_0055', 'node_0056'),
#  ('node_0056', 'node_0434'),
#  ('node_0056', 'node_0057'),
#  ('node_0057', 'node_0060'),
#  ('node_0057', 'node_0058'),
#  ('node_0057', 'node_0435'),
#  ('node_0057', 'node_0360'),
#  ('node_0057', 'node_0061'),
#  ('node_0058', 'node_0059'),
#  ('node_0058', 'node_0436'),
#  ('node_0059', 'node_0439'),
#  ('node_0059', 'node_0438'),
#  ('node_0059', 'node_0437'),
#  ('node_0060', 'node_0440'),
#  ('node_0061', 'node_0215'),
#  ('node_0061', 'node_0429'),
#  ('node_0061', 'node_0062'),
#  ('node_0061', 'node_0063'),
#  ('node_0061', 'node_0064'),
#  ('node_0061', 'node_0066'),
#  ('node_0062', 'node_0063'),
#  ('node_0062', 'node_0363'),
#  ('node_0062', 'node_0441_1'),
#  ('node_0062', 'node_0365'),
#  ('node_0062', 'node_0441_2'),
#  ('node_0062', 'node_0215'),
#  ('node_0062', 'node_0442'),
#  ('node_0062', 'node_0443'),
#  ('node_0063', 'node_0444'),
#  ('node_0064', 'node_0445'),
#  ('node_0065', 'node_0067'),
#  ('node_0065', 'node_0066'),
#  ('node_0065', 'node_0442'),
#  ('node_0066', 'node_0446'),
#  ('node_0067', 'node_0103_1'),
#  ('node_0067', 'node_0447_1'),
#  ('node_0067', 'node_0447_2'),
#  ('node_0067', 'node_0103_2'),
#  ('node_0068', 'node_0070'),
#  ('node_0068', 'node_0069'),
#  ('node_0069', 'node_0448'),
#  ('node_0070', 'node_0449'),
#  ('node_0070', 'node_0071'),
#  ('node_0071', 'node_0450_2'),
#  ('node_0071', 'node_0450_1'),
#  ('node_0071', 'node_0302_2'),
#  ('node_0071', 'node_0072'),
#  ('node_0071', 'node_0302_1'),
#  ('node_0072', 'node_0451'),
#  ('node_0072', 'node_0073'),
#  ('node_0073', 'node_0074'),
#  ('node_0074', 'node_0452'),
#  ('node_0074', 'node_0453_2'),
#  ('node_0074', 'node_0453_4'),
#  ('node_0074', 'node_0079'),
#  ('node_0074', 'node_0453_1'),
#  ('node_0074', 'node_0453_3'),
#  ('node_0074', 'node_0226'),
#  ('node_0074', 'node_0236_1'),
#  ('node_0074', 'node_0236_2'),
#  ('node_0074', 'node_0237'),
#  ('node_0075', 'node_0454'),
#  ('node_0075', 'node_0076'),
#  ('node_0076', 'node_0299'),
#  ('node_0076', 'node_0298'),
#  ('node_0076', 'node_0455_1'),
#  ('node_0076', 'node_0455_2'),
#  ('node_0076', 'node_0077'),
#  ('node_0076', 'node_0301'),
#  ('node_0077', 'node_0078'),
#  ('node_0077', 'node_0456'),
#  ('node_0078', 'node_0079'),
#  ('node_0078', 'node_0080'),
#  ('node_0079', 'node_0240'),
#  ('node_0079', 'node_0239'),
#  ('node_0079', 'node_0457'),
#  ('node_0080', 'node_0458'),
#  ('node_0080', 'node_0081'),
#  ('node_0081', 'node_0459'),
#  ('node_0081', 'node_0082'),
#  ('node_0082', 'node_0460'),
#  ('node_0082', 'node_0083'),
#  ('node_0083', 'node_0084'),
#  ('node_0083', 'node_0461'),
#  ('node_0084', 'node_0462'),
#  ('node_0084', 'node_0463'),
#  ('node_0084', 'node_0085'),
#  ('node_0085', 'node_0464'),
#  ('node_0085', 'node_0086'),
#  ('node_0086', 'node_0411'),
#  ('node_0086', 'node_0090'),
#  ('node_0086', 'node_0091'),
#  ('node_0086', 'node_0178'),
#  ('node_0087', 'node_0371_2'),
#  ('node_0087', 'node_0164'),
#  ('node_0087', 'node_0162_2'),
#  ('node_0087', 'node_0162_1'),
#  ('node_0087', 'node_0371_1'),
#  ('node_0088', 'node_0089'),
#  ('node_0088', 'node_0095'),
#  ('node_0088', 'node_0090'),
#  ('node_0089', 'node_0466'),
#  ('node_0089', 'node_0465'),
#  ('node_0090', 'node_0467'),
#  ('node_0091', 'node_0468'),
#  ('node_0091', 'node_0092'),
#  ('node_0092', 'node_0411'),
#  ('node_0092', 'node_0110_2'),
#  ('node_0092', 'node_0110_1'),
#  ('node_0092', 'node_0093'),
#  ('node_0093', 'node_0469'),
#  ('node_0093', 'node_0133'),
#  ('node_0094', 'node_0470'),
#  ('node_0095', 'node_0471'),
#  ('node_0095', 'node_0096'),
#  ('node_0096', 'node_0472'),
#  ('node_0097', 'node_0473_2'),
#  ('node_0097', 'node_0473_1'),
#  ('node_0097', 'node_0395_2'),
#  ('node_0097', 'node_0395_1'),
#  ('node_0098', 'node_0099_2'),
#  ('node_0098', 'node_0474'),
#  ('node_0098', 'node_0395'),
#  ('node_0098', 'node_0394'),
#  ('node_0098', 'node_0203'),
#  ('node_0098', 'node_0099_1'),
#  ('node_0099', 'node_0199'),
#  ('node_0099', 'node_0203'),
#  ('node_0099', 'node_0475'),
#  ('node_0099', 'node_0114_2'),
#  ('node_0099', 'node_0114_1'),
#  ('node_0100', 'node_0359'),
#  ('node_0100', 'node_0101_1'),
#  ('node_0100', 'node_0101_2'),
#  ('node_0100', 'node_0358'),
#  ('node_0101', 'node_0102_2'),
#  ('node_0101', 'node_0102_1'),
#  ('node_0102', 'node_0447_2'),
#  ('node_0102', 'node_0447_1'),
#  ('node_0103', 'node_0104_2'),
#  ('node_0103', 'node_0442'),
#  ('node_0103', 'node_0104_1'),
#  ('node_0104', 'node_0106_1'),
#  ('node_0104', 'node_0105'),
#  ('node_0104', 'node_0476'),
#  ('node_0104', 'node_0106_2'),
#  ('node_0105', 'node_0452'),
#  ('node_0105', 'node_0106'),
#  ('node_0106', 'node_0107'),
#  ('node_0106', 'node_0108'),
#  ('node_0106', 'node_0316'),
#  ('node_0106', 'node_0477'),
#  ('node_0107', 'node_0478'),
#  ('node_0107', 'node_0108'),
#  ('node_0108', 'node_0109_2'),
#  ('node_0108', 'node_0109_3'),
#  ('node_0108', 'node_0317'),
#  ('node_0108', 'node_0109_1'),
#  ('node_0109', 'node_0204'),
#  ('node_0109', 'node_0110_2'),
#  ('node_0109', 'node_0110_1'),
#  ('node_0109', 'node_0318'),
#  ('node_0110', 'node_0111'),
#  ('node_0110', 'node_0319'),
#  ('node_0110', 'node_0112'),
#  ('node_0110', 'node_0320'),
#  ('node_0111', 'node_0113_2'),
#  ('node_0111', 'node_0113_1'),
#  ('node_0111', 'node_0321'),
#  ('node_0111', 'node_0112'),
#  ('node_0111', 'node_0181'),
#  ('node_0111', 'node_0179'),
#  ('node_0112', 'node_0479'),
#  ('node_0113', 'node_0480'),
#  ('node_0113', 'node_0131_2'),
#  ('node_0113', 'node_0131_1'),
#  ('node_0114', 'node_0481'),
#  ('node_0114', 'node_0115_1'),
#  ('node_0114', 'node_0115_2'),
#  ('node_0115', 'node_0116_2'),
#  ('node_0115', 'node_0116_1'),
#  ('node_0116', 'node_0117_2'),
#  ('node_0116', 'node_0117_1'),
#  ('node_0117', 'node_0118_2'),
#  ('node_0117', 'node_0118_1'),
#  ('node_0118', 'node_0119_2'),
#  ('node_0118', 'node_0119_1'),
#  ('node_0119', 'node_0120_2'),
#  ('node_0119', 'node_0120_1'),
#  ('node_0120', 'node_0121_1'),
#  ('node_0120', 'node_0121_2'),
#  ('node_0121', 'node_0122_1'),
#  ('node_0121', 'node_0122_2'),
#  ('node_0122', 'node_0123_2'),
#  ('node_0122', 'node_0123_1'),
#  ('node_0123', 'node_0132_1'),
#  ('node_0123', 'node_0482_1'),
#  ('node_0123', 'node_0132_2'),
#  ('node_0123', 'node_0124_2'),
#  ('node_0123', 'node_0124_1'),
#  ('node_0123', 'node_0373'),
#  ('node_0123', 'node_0483'),
#  ('node_0123', 'node_0482_2'),
#  ('node_0124', 'node_0125_1'),
#  ('node_0124', 'node_0125_2'),
#  ('node_0125', 'node_0126_2'),
#  ('node_0125', 'node_0484'),
#  ('node_0125', 'node_0126_1'),
#  ('node_0126', 'node_0127_2'),
#  ('node_0126', 'node_0127_1'),
#  ('node_0127', 'node_0128_1'),
#  ('node_0127', 'node_0128_2'),
#  ('node_0128', 'node_0485_1'),
#  ('node_0128', 'node_0338'),
#  ('node_0128', 'node_0372'),
#  ('node_0128', 'node_0485_2'),
#  ('node_0128', 'node_0486'),
#  ('node_0129', 'node_0487'),
#  ('node_0129', 'node_0130_2'),
#  ('node_0129', 'node_0338_2'),
#  ('node_0129', 'node_0338_1'),
#  ('node_0129', 'node_0372_1'),
#  ('node_0129', 'node_0372_2'),
#  ('node_0129', 'node_0346'),
#  ('node_0129', 'node_0130_1'),
#  ('node_0130', 'node_0488'),
#  ('node_0130', 'node_0489'),
#  ('node_0131', 'node_0482_2'),
#  ('node_0131', 'node_0482_1'),
#  ('node_0132', 'node_0374'),
#  ('node_0133', 'node_0134'),
#  ('node_0133', 'node_0336'),
#  ('node_0133', 'node_0361'),
#  ('node_0133', 'node_0490'),
#  ('node_0134', 'node_0492'),
#  ('node_0134', 'node_0491'),
#  ('node_0135', 'node_0136'),
#  ('node_0135', 'node_0380_2'),
#  ('node_0135', 'node_0380_1'),
#  ('node_0136', 'node_0493_5'),
#  ('node_0136', 'node_0493_4'),
#  ('node_0136', 'node_0493_3'),
#  ('node_0136', 'node_0493_2'),
#  ('node_0136', 'node_0493_1'),
#  ('node_0136', 'node_0362'),
#  ('node_0136', 'node_0208'),
#  ('node_0136', 'node_0209'),
#  ('node_0137', 'node_0208'),
#  ('node_0137', 'node_0162'),
#  ('node_0137', 'node_0212'),
#  ('node_0137', 'node_0138'),
#  ('node_0137', 'node_0161'),
#  ('node_0138', 'node_0139'),
#  ('node_0139', 'node_0266'),
#  ('node_0139', 'node_0495'),
#  ('node_0139', 'node_0494_2'),
#  ('node_0139', 'node_0268_1'),
#  ('node_0139', 'node_0494_1'),
#  ('node_0139', 'node_0269'),
#  ('node_0139', 'node_0268_3'),
#  ('node_0139', 'node_0268_2'),
#  ('node_0140', 'node_0144'),
#  ('node_0140', 'node_0141'),
#  ('node_0140', 'node_0162'),
#  ('node_0140', 'node_0496_3'),
#  ('node_0140', 'node_0497'),
#  ('node_0140', 'node_0496_5'),
#  ('node_0140', 'node_0496_4'),
#  ('node_0140', 'node_0496_2'),
#  ('node_0140', 'node_0496_1'),
#  ('node_0141', 'node_0498_2'),
#  ('node_0141', 'node_0142'),
#  ('node_0141', 'node_0498_1'),
#  ('node_0142', 'node_0176_2'),
#  ('node_0142', 'node_0176_1'),
#  ('node_0142', 'node_0143'),
#  ('node_0142', 'node_0144'),
#  ('node_0142', 'node_0499'),
#  ('node_0143', 'node_0169'),
#  ('node_0143', 'node_0170'),
#  ('node_0144', 'node_0500'),
#  ('node_0145', 'node_0501'),
#  ('node_0145', 'node_0146_2'),
#  ('node_0145', 'node_0146_1'),
#  ('node_0146', 'node_0147'),
#  ('node_0147', 'node_0148'),
#  ('node_0147', 'node_0149'),
#  ('node_0147', 'node_0501'),
#  ('node_0148', 'node_0502'),
#  ('node_0149', 'node_0150'),
#  ('node_0150', 'node_0503'),
#  ('node_0150', 'node_0151'),
#  ('node_0151', 'node_0152'),
#  ('node_0151', 'node_0156'),
#  ('node_0152', 'node_0504'),
#  ('node_0152', 'node_0153'),
#  ('node_0153', 'node_0158'),
#  ('node_0153', 'node_0154'),
#  ('node_0154', 'node_0155'),
#  ('node_0154', 'node_0505'),
#  ('node_0155', 'node_0508'),
#  ('node_0155', 'node_0507'),
#  ('node_0155', 'node_0506'),
#  ('node_0156', 'node_0509'),
#  ('node_0156', 'node_0157_2'),
#  ('node_0156', 'node_0157_1'),
#  ('node_0157', 'node_0161_2'),
#  ('node_0157', 'node_0158'),
#  ('node_0157', 'node_0167'),
#  ('node_0157', 'node_0161_1'),
#  ('node_0158', 'node_0510'),
#  ('node_0158', 'node_0159'),
#  ('node_0159', 'node_0511'),
#  ('node_0159', 'node_0160'),
#  ('node_0160', 'node_0296'),
#  ('node_0160', 'node_0297'),
#  ('node_0161', 'node_0514'),
#  ('node_0161', 'node_0513'),
#  ('node_0161', 'node_0499'),
#  ('node_0161', 'node_0512'),
#  ('node_0162', 'node_0514'),
#  ('node_0162', 'node_0163'),
#  ('node_0163', 'node_0515'),
#  ('node_0163', 'node_0210'),
#  ('node_0164', 'node_0165_1'),
#  ('node_0164', 'node_0165_2'),
#  ('node_0164', 'node_0349'),
#  ('node_0164', 'node_0403'),
#  ('node_0164', 'node_0166_1'),
#  ('node_0164', 'node_0166_2'),
#  ('node_0164', 'node_0516'),
#  ('node_0164', 'node_0350'),
#  ('node_0165', 'node_0514'),
#  ('node_0165', 'node_0418'),
#  ('node_0166', 'node_0348'),
#  ('node_0166', 'node_0349'),
#  ('node_0166', 'node_0517'),
#  ('node_0166', 'node_0518'),
#  ('node_0166', 'node_0347'),
#  ('node_0167', 'node_0168_1'),
#  ('node_0167', 'node_0168_2'),
#  ('node_0167', 'node_0171'),
#  ('node_0167', 'node_0172'),
#  ('node_0168', 'node_0169'),
#  ('node_0169', 'node_0171'),
#  ('node_0170', 'node_0423'),
#  ('node_0171', 'node_0174'),
#  ('node_0171', 'node_0173'),
#  ('node_0172', 'node_0519'),
#  ('node_0172', 'node_0520'),
#  ('node_0173', 'node_0521'),
#  ('node_0173', 'node_0522'),
#  ('node_0174', 'node_0175'),
#  ('node_0174', 'node_0523'),
#  ('node_0175', 'node_0525_2'),
#  ('node_0175', 'node_0525_1'),
#  ('node_0175', 'node_0524'),
#  ('node_0176', 'node_0177'),
#  ('node_0177', 'node_0526'),
#  ('node_0177', 'node_0527'),
#  ('node_0178', 'node_0528'),
#  ('node_0179', 'node_0529'),
#  ('node_0180', 'node_0530'),
#  ('node_0180', 'node_0181'),
#  ('node_0181', 'node_0531'),
#  ('node_0182', 'node_0532'),
#  ('node_0183', 'node_0184'),
#  ('node_0184', 'node_0533'),
#  ('node_0184', 'node_0185'),
#  ('node_0185', 'node_0186'),
#  ('node_0185', 'node_0189'),
#  ('node_0185', 'node_0190'),
#  ('node_0186', 'node_0188'),
#  ('node_0186', 'node_0187'),
#  ('node_0187', 'node_0188'),
#  ('node_0187', 'node_0534'),
#  ('node_0188', 'node_0189_1'),
#  ('node_0188', 'node_0189_2'),
#  ('node_0188', 'node_0191'),
#  ('node_0189', 'node_0190'),
#  ('node_0189', 'node_0535'),
#  ('node_0190', 'node_0536'),
#  ('node_0191', 'node_0532'),
#  ('node_0191', 'node_0192'),
#  ('node_0192', 'node_0537'),
#  ('node_0193', 'node_0538'),
#  ('node_0193', 'node_0194'),
#  ('node_0194', 'node_0382'),
#  ('node_0195', 'node_0382'),
#  ('node_0195', 'node_0196'),
#  ('node_0195', 'node_0381'),
#  ('node_0196', 'node_0384'),
#  ('node_0197', 'node_0539'),
#  ('node_0198', 'node_0540'),
#  ('node_0198', 'node_0199'),
#  ('node_0199', 'node_0541'),
#  ('node_0200', 'node_0542'),
#  ('node_0201', 'node_0202_1'),
#  ('node_0201', 'node_0202_2'),
#  ('node_0202', 'node_0543'),
#  ('node_0203', 'node_0544'),
#  ('node_0203', 'node_0545_1'),
#  ('node_0203', 'node_0545_2'),
#  ('node_0204', 'node_0331'),
#  ('node_0204', 'node_0330'),
#  ('node_0205', 'node_0347'),
#  ('node_0206', 'node_0546'),
#  ('node_0206', 'node_0207'),
#  ('node_0207', 'node_0547'),
#  ('node_0208', 'node_0548'),
#  ('node_0209', 'node_0210'),
#  ('node_0209', 'node_0549'),
#  ('node_0210', 'node_0550'),
#  ('node_0211', 'node_0371'),
#  ('node_0212', 'node_0213'),
#  ('node_0213', 'node_0551'),
#  ('node_0214', 'node_0215'),
#  ('node_0214', 'node_0363'),
#  ('node_0215', 'node_0443'),
#  ('node_0215', 'node_0365'),
#  ('node_0216', 'node_0224'),
#  ('node_0216', 'node_0217_1'),
#  ('node_0216', 'node_0217_2'),
#  ('node_0216', 'node_0218'),
#  ('node_0217', 'node_0552'),
#  ('node_0218', 'node_0219_1'),
#  ('node_0218', 'node_0553'),
#  ('node_0218', 'node_0219_2'),
#  ('node_0219', 'node_0220_1'),
#  ('node_0219', 'node_0220_2'),
#  ('node_0220', 'node_0221_1'),
#  ('node_0220', 'node_0221_2'),
#  ('node_0220', 'node_0224'),
#  ('node_0221', 'node_0222'),
#  ('node_0221', 'node_0229'),
#  ('node_0221', 'node_0230_1'),
#  ('node_0221', 'node_0230_2'),
#  ('node_0222', 'node_0554'),
#  ('node_0222', 'node_0223'),
#  ('node_0223', 'node_0455'),
#  ('node_0223', 'node_0302'),
#  ('node_0223', 'node_0303'),
#  ('node_0224', 'node_0225'),
#  ('node_0225', 'node_0226'),
#  ('node_0225', 'node_0227'),
#  ('node_0225', 'node_0555'),
#  ('node_0226', 'node_0228_1'),
#  ('node_0226', 'node_0228_2'),
#  ('node_0226', 'node_0236_2'),
#  ('node_0226', 'node_0556_2'),
#  ('node_0226', 'node_0556_1'),
#  ('node_0226', 'node_0236_1'),
#  ('node_0226', 'node_0227'),
#  ('node_0227', 'node_0228_3'),
#  ('node_0227', 'node_0228_2'),
#  ('node_0227', 'node_0228_1'),
#  ('node_0228', 'node_0233_1'),
#  ('node_0228', 'node_0229'),
#  ('node_0228', 'node_0233_2'),
#  ('node_0228', 'node_0557'),
#  ('node_0229', 'node_0558'),
#  ('node_0230', 'node_0231_1'),
#  ('node_0230', 'node_0231_2'),
#  ('node_0231', 'node_0232_1'),
#  ('node_0231', 'node_0232_2'),
#  ('node_0231', 'node_0559'),
#  ('node_0232', 'node_0560'),
#  ('node_0232', 'node_0234_2'),
#  ('node_0232', 'node_0234_1'),
#  ('node_0233', 'node_0234_1'),
#  ('node_0233', 'node_0234_2'),
#  ('node_0233', 'node_0234_3'),
#  ('node_0233', 'node_0234_4'),
#  ('node_0233', 'node_0235'),
#  ('node_0234', 'node_0243_1'),
#  ('node_0234', 'node_0242'),
#  ('node_0234', 'node_0243_2'),
#  ('node_0234', 'node_0314_2'),
#  ('node_0234', 'node_0314_1'),
#  ('node_0234', 'node_0312'),
#  ('node_0235', 'node_0556_1'),
#  ('node_0235', 'node_0556_2'),
#  ('node_0236', 'node_0453'),
#  ('node_0237', 'node_0239'),
#  ('node_0237', 'node_0238'),
#  ('node_0238', 'node_0243'),
#  ('node_0238', 'node_0246'),
#  ('node_0238', 'node_0242'),
#  ('node_0238', 'node_0241'),
#  ('node_0239', 'node_0561'),
#  ('node_0240', 'node_0241'),
#  ('node_0240', 'node_0562'),
#  ('node_0241', 'node_0246'),
#  ('node_0242', 'node_0563'),
#  ('node_0243', 'node_0244'),
#  ('node_0243', 'node_0252'),
#  ('node_0244', 'node_0564'),
#  ('node_0244', 'node_0245'),
#  ('node_0245', 'node_0249_1'),
#  ('node_0245', 'node_0247'),
#  ('node_0245', 'node_0249_2'),
#  ('node_0245', 'node_0566'),
#  ('node_0245', 'node_0565'),
#  ('node_0245', 'node_0248'),
#  ('node_0245', 'node_0250'),
#  ('node_0246', 'node_0247_2'),
#  ('node_0246', 'node_0247_1'),
#  ('node_0247', 'node_0250_1'),
#  ('node_0247', 'node_0250_2'),
#  ('node_0248', 'node_0313_2'),
#  ('node_0248', 'node_0313_1'),
#  ('node_0248', 'node_0252'),
#  ('node_0248', 'node_0567_2'),
#  ('node_0248', 'node_0567_3'),
#  ('node_0248', 'node_0249'),
#  ('node_0248', 'node_0567_1'),
#  ('node_0249', 'node_0251_1'),
#  ('node_0249', 'node_0251_2'),
#  ('node_0249', 'node_0261'),
#  ('node_0249', 'node_0260_1'),
#  ('node_0249', 'node_0260_2'),
#  ('node_0250', 'node_0251_1'),
#  ('node_0250', 'node_0251_2'),
#  ('node_0250', 'node_0562_3'),
#  ('node_0250', 'node_0562_2'),
#  ('node_0250', 'node_0251_3'),
#  ('node_0250', 'node_0562_1'),
#  ('node_0251', 'node_0253_1'),
#  ('node_0251', 'node_0253_2'),
#  ('node_0251', 'node_0253_3'),
#  ('node_0252', 'node_0568'),
#  ('node_0253', 'node_0258_1'),
#  ('node_0253', 'node_0258_2'),
#  ('node_0253', 'node_0569_1'),
#  ('node_0253', 'node_0569_2'),
#  ('node_0253', 'node_0254'),
#  ('node_0254', 'node_0255'),
#  ('node_0255', 'node_0256'),
#  ('node_0255', 'node_0258'),
#  ('node_0256', 'node_0257'),
#  ('node_0256', 'node_0570'),
#  ('node_0257', 'node_0571'),
#  ('node_0257', 'node_0572'),
#  ('node_0258', 'node_0260_2'),
#  ('node_0258', 'node_0259'),
#  ('node_0258', 'node_0260_1'),
#  ('node_0259', 'node_0261'),
#  ('node_0260', 'node_0573'),
#  ('node_0261', 'node_0567'),
#  ('node_0261', 'node_0262_1'),
#  ('node_0261', 'node_0262_2'),
#  ('node_0261', 'node_0262_3'),
#  ('node_0261', 'node_0574'),
#  ('node_0262', 'node_0577'),
#  ('node_0262', 'node_0576'),
#  ('node_0262', 'node_0263_2'),
#  ('node_0262', 'node_0567'),
#  ('node_0262', 'node_0364'),
#  ('node_0262', 'node_0575'),
#  ('node_0262', 'node_0315'),
#  ('node_0262', 'node_0263_1'),
#  ('node_0263', 'node_0264_3'),
#  ('node_0263', 'node_0264_2'),
#  ('node_0263', 'node_0577_1'),
#  ('node_0263', 'node_0577_2'),
#  ('node_0263', 'node_0264_1'),
#  ('node_0264', 'node_0265_3'),
#  ('node_0264', 'node_0265_1'),
#  ('node_0264', 'node_0265_2'),
#  ('node_0264', 'node_0578'),
#  ('node_0264', 'node_0267'),
#  ('node_0264', 'node_0266_2'),
#  ('node_0264', 'node_0266_1'),
#  ('node_0265', 'node_0270'),
#  ('node_0265', 'node_0580'),
#  ('node_0265', 'node_0579'),
#  ('node_0266', 'node_0267'),
#  ('node_0267', 'node_0494_2'),
#  ('node_0267', 'node_0494_1'),
#  ('node_0268', 'node_0271'),
#  ('node_0268', 'node_0272'),
#  ('node_0269', 'node_0581'),
#  ('node_0269', 'node_0270'),
#  ('node_0270', 'node_0272'),
#  ('node_0270', 'node_0582'),
#  ('node_0270', 'node_0583'),
#  ('node_0271', 'node_0275'),
#  ('node_0271', 'node_0274'),
#  ('node_0271', 'node_0272'),
#  ('node_0271', 'node_0276'),
#  ('node_0272', 'node_0273'),
#  ('node_0273', 'node_0274'),
#  ('node_0273', 'node_0296'),
#  ('node_0273', 'node_0584'),
#  ('node_0274', 'node_0287'),
#  ('node_0275', 'node_0287'),
#  ('node_0275', 'node_0278'),
#  ('node_0276', 'node_0585'),
#  ('node_0276', 'node_0277'),
#  ('node_0277', 'node_0279_2'),
#  ('node_0277', 'node_0586'),
#  ('node_0277', 'node_0278'),
#  ('node_0277', 'node_0279_1'),
#  ('node_0278', 'node_0281'),
#  ('node_0279', 'node_0280'),
#  ('node_0279', 'node_0587'),
#  ('node_0280', 'node_0588'),
#  ('node_0280', 'node_0281'),
#  ('node_0280', 'node_0282'),
#  ('node_0281', 'node_0283'),
#  ('node_0281', 'node_0282'),
#  ('node_0282', 'node_0283'),
#  ('node_0283', 'node_0287'),
#  ('node_0283', 'node_0285'),
#  ('node_0284', 'node_0285'),
#  ('node_0284', 'node_0286'),
#  ('node_0284', 'node_0370'),
#  ('node_0285', 'node_0286'),
#  ('node_0286', 'node_0292'),
#  ('node_0286', 'node_0291'),
#  ('node_0286', 'node_0370'),
#  ('node_0287', 'node_0288'),
#  ('node_0288', 'node_0289'),
#  ('node_0288', 'node_0589'),
#  ('node_0289', 'node_0294'),
#  ('node_0289', 'node_0290'),
#  ('node_0290', 'node_0291'),
#  ('node_0290', 'node_0590'),
#  ('node_0291', 'node_0292'),
#  ('node_0291', 'node_0368'),
#  ('node_0292', 'node_0293'),
#  ('node_0292', 'node_0591'),
#  ('node_0293', 'node_0377'),
#  ('node_0293', 'node_0592'),
#  ('node_0294', 'node_0295'),
#  ('node_0295', 'node_0593'),
#  ('node_0295', 'node_0296'),
#  ('node_0296', 'node_0310'),
#  ('node_0296', 'node_0297'),
#  ('node_0297', 'node_0298_1'),
#  ('node_0297', 'node_0298_2'),
#  ('node_0298', 'node_0301'),
#  ('node_0298', 'node_0299'),
#  ('node_0298', 'node_0300'),
#  ('node_0299', 'node_0594'),
#  ('node_0300', 'node_0595'),
#  ('node_0301', 'node_0596'),
#  ('node_0302', 'node_0303'),
#  ('node_0303', 'node_0304'),
#  ('node_0303', 'node_0305'),
#  ('node_0303', 'node_0306'),
#  ('node_0304', 'node_0598'),
#  ('node_0304', 'node_0597'),
#  ('node_0305', 'node_0599'),
#  ('node_0305', 'node_0584'),
#  ('node_0305', 'node_0308'),
#  ('node_0306', 'node_0307'),
#  ('node_0306', 'node_0600'),
#  ('node_0307', 'node_0312_2'),
#  ('node_0307', 'node_0308'),
#  ('node_0307', 'node_0311'),
#  ('node_0307', 'node_0309'),
#  ('node_0307', 'node_0312_1'),
#  ('node_0308', 'node_0309'),
#  ('node_0309', 'node_0584_2'),
#  ('node_0309', 'node_0584_1'),
#  ('node_0310', 'node_0366'),
#  ('node_0310', 'node_0584'),
#  ('node_0311', 'node_0313'),
#  ('node_0311', 'node_0601'),
#  ('node_0312', 'node_0313_1'),
#  ('node_0312', 'node_0313_2'),
#  ('node_0312', 'node_0313_3'),
#  ('node_0312', 'node_0313_4'),
#  ('node_0313', 'node_0315'),
#  ('node_0314', 'node_0450_1'),
#  ('node_0314', 'node_0450_2'),
#  ('node_0315', 'node_0602'),
#  ('node_0316', 'node_0603'),
#  ('node_0316', 'node_0317'),
#  ('node_0317', 'node_0604'),
#  ('node_0318', 'node_0605'),
#  ('node_0318', 'node_0319'),
#  ('node_0319', 'node_0606'),
#  ('node_0320', 'node_0608'),
#  ('node_0320', 'node_0607'),
#  ('node_0320', 'node_0321'),
#  ('node_0321', 'node_0609'),
#  ('node_0322', 'node_0326_2'),
#  ('node_0322', 'node_0326_1'),
#  ('node_0322', 'node_0325'),
#  ('node_0322', 'node_0611'),
#  ('node_0322', 'node_0610'),
#  ('node_0322', 'node_0323'),
#  ('node_0323', 'node_0324_1'),
#  ('node_0323', 'node_0324_2'),
#  ('node_0324', 'node_0612'),
#  ('node_0324', 'node_0613'),
#  ('node_0324', 'node_0329'),
#  ('node_0324', 'node_0330'),
#  ('node_0325', 'node_0614'),
#  ('node_0326', 'node_0327_1'),
#  ('node_0326', 'node_0327_2'),
#  ('node_0327', 'node_0328'),
#  ('node_0327', 'node_0340'),
#  ('node_0327', 'node_0615'),
#  ('node_0328', 'node_0617'),
#  ('node_0328', 'node_0616'),
#  ('node_0329', 'node_0618'),
#  ('node_0330', 'node_0612'),
#  ('node_0331', 'node_0619'),
#  ('node_0331', 'node_0332'),
#  ('node_0332', 'node_0333_2'),
#  ('node_0332', 'node_0333_1'),
#  ('node_0333', 'node_0620'),
#  ('node_0333', 'node_0334'),
#  ('node_0334', 'node_0337_1'),
#  ('node_0334', 'node_0335_2'),
#  ('node_0334', 'node_0337_2'),
#  ('node_0334', 'node_0335_1'),
#  ('node_0335', 'node_0336_1'),
#  ('node_0335', 'node_0336_2'),
#  ('node_0335', 'node_0621'),
#  ('node_0336', 'node_0622'),
#  ('node_0337', 'node_0343'),
#  ('node_0337', 'node_0485'),
#  ('node_0338', 'node_0339'),
#  ('node_0338', 'node_0372'),
#  ('node_0339', 'node_0340'),
#  ('node_0340', 'node_0341'),
#  ('node_0341', 'node_0624'),
#  ('node_0341', 'node_0342'),
#  ('node_0341', 'node_0623'),
#  ('node_0342', 'node_0625'),
#  ('node_0342', 'node_0612'),
#  ('node_0342', 'node_0345'),
#  ('node_0343', 'node_0344'),
#  ('node_0343', 'node_0626'),
#  ('node_0344', 'node_0627'),
#  ('node_0344', 'node_0345'),
#  ('node_0345', 'node_0628'),
#  ('node_0346', 'node_0630'),
#  ('node_0346', 'node_0631'),
#  ('node_0346', 'node_0629'),
#  ('node_0347', 'node_0350'),
#  ('node_0348', 'node_0632'),
#  ('node_0349', 'node_0350'),
#  ('node_0350', 'node_0351'),
#  ('node_0351', 'node_0516_1'),
#  ('node_0351', 'node_0352'),
#  ('node_0351', 'node_0516_2'),
#  ('node_0352', 'node_0633'),
#  ('node_0353', 'node_0354'),
#  ('node_0354', 'node_0355'),
#  ('node_0354', 'node_0634'),
#  ('node_0355', 'node_0635'),
#  ('node_0355', 'node_0356'),
#  ('node_0356', 'node_0637'),
#  ('node_0356', 'node_0636'),
#  ('node_0357', 'node_0638'),
#  ('node_0357', 'node_0639'),
#  ('node_0358', 'node_0640'),
#  ('node_0358', 'node_0359'),
#  ('node_0359', 'node_0641'),
#  ('node_0360', 'node_0369'),
#  ('node_0360', 'node_0642'),
#  ('node_0361', 'node_0643_2'),
#  ('node_0361', 'node_0643_1'),
#  ('node_0362', 'node_0644'),
#  ('node_0363', 'node_0645'),
#  ('node_0364', 'node_0646'),
#  ('node_0365', 'node_0647'),
#  ...]

# %%
# Create variables
flow = m.addVars(commodities, edges, vtype=GRB.CONTINUOUS, name="flow")
# variable for capacity investment
investment = m.addVars(commodities, edges, vtype=GRB.CONTINUOUS, name="investment")
# Variable for converted capacity
converted_capacity = m.addVars(commodities, edges, vtype=GRB.CONTINUOUS, name="converted_capacity")
# Binary variable to indicate if conversion is active
conversion_indicator = m.addVars(commodities, edges, vtype=GRB.BINARY, name="conversion_indicator")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 2
#       1 # Create variables
# ----> 2 flow = m.addVars(commodities, edges, vtype=GRB.CONTINUOUS, name="flow")
#       3 # variable for capacity investment
#       4 investment = m.addVars(commodities, edges, vtype=GRB.CONTINUOUS, name="investment")
#
# File src\\gurobipy\\model.pxi:3064, in gurobipy.Model.addVars()
#
# KeyError: 'Duplicate keys in Model.addVars()'

# %% [markdown]
# ### Define objective

# %%
# Set objective function
m.setObjective(
    gp.quicksum(flow[h, i, j] * cost[h, i, j] for h in commodities for i, j in edges) +
    gp.quicksum(investment[h, i, j] * investment_cost[h, i, j] for h in commodities for i, j in edges_base) +
    gp.quicksum(converted_capacity[h, i, j] * conversion_cost[h, j, i] for h in commodities for i, j in edges_base),
    GRB.MINIMIZE
)

# %% [markdown]
# ### Define constraints

# %%
# Edge-capacity constraints with investment
m.addConstrs((flow[h, i, j] <= converted_capacity[h, i, j] + investment[h, i, j] for h in commodities for i, j in edges), "cap")

# Edge-capacity total limit
m.addConstrs((investment[h, i, j] + converted_capacity[h, i, j] 
              <= capacity_limit[h, i, j] for h in commodities for i, j in edges_base), "cap")

# Investment constraints
m.addConstrs((investment[h, i, j] == investment[h, j, i] for h in commodities for i, j in edges), "conversion")

#conversion binary constraint
m.addConstrs((gp.quicksum(conversion_indicator[h, i, j] for h in commodities) == 1 for i, j in edges), "conversion_indicator_sum_one")

#link the converted capacity to the initial capacity
m.addConstrs((capacity[commodities[0], i, j] * conversion_indicator[h, i, j] 
              == converted_capacity[h, i, j] for h in commodities[1:] for i, j in edges), "capacity_relationship")
m.addConstrs((capacity[commodities[0], i, j] * conversion_indicator[commodities[0], i, j]
        == converted_capacity[commodities[0], i, j]
        for i, j in edges), "capacity_relationship_first_commodity")

# Conversion constraints
m.addConstrs((converted_capacity[h, i, j] == converted_capacity[h, j, i] for h in commodities for i, j in edges), "conversion")

# Flow-conservation constraints
m.addConstrs(
    (
        flow.sum(h, "*", j) + inflow[h, j] == flow.sum(h, j, "*")
        for h in commodities
        for j in nodes
    ),
    "node",
)

print('Constraints createt')
# Out:
# Constraints createt

# %% [markdown]
# ### Optimize the model

# %%
# Compute optimal solution
m.optimize()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i5-8265U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 306 rows, 224 columns and 728 nonzeros
# Model fingerprint: 0x66b7893c
# Variable types: 168 continuous, 56 integer (56 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [5e-01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 10401.000000
# Presolve removed 271 rows and 184 columns
# Presolve time: 0.00s
# Presolved: 35 rows, 40 columns, 116 nonzeros
# Found heuristic solution: objective 6464.0000000
# Variable types: 34 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 4.589000e+03, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4589.00000    0    5 6464.00000 4589.00000  29.0%     -    0s
# H    0     0                    5509.0000000 4589.00000  16.7%     -    0s
# H    0     0                    5459.0000000 4589.00000  15.9%     -    0s
#      0     0 5241.50000    0    6 5459.00000 5241.50000  3.98%     -    0s
#      0     0 5459.00000    0    5 5459.00000 5459.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 5
#   RLT: 4
#   Relax-and-lift: 2
#
# Explored 1 nodes (34 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 5459 5509 6464 10401
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.459000000000e+03, best bound 5.459000000000e+03, gap 0.0000%

# %% [markdown]
# ## Outputs

# %%
if m.Status == GRB.OPTIMAL:
    solution = m.getAttr("X", flow)
    investment_solution = m.getAttr("X", investment)
    converted_capacity_solution = m.getAttr("X", converted_capacity)
    conversion_indicator_solution = m.getAttr("X", conversion_indicator)

    print("****************************")
    print(f"Total cost: {m.objVal}")
    print("****************************")
    
    for h in commodities:
        print(f"\nOptimal flows for {h}:")
        for i, j in edges:
            if solution[h, i, j] > 0:
                print(f"{i} -> {j}: {solution[h, i, j]:g}")

        print(f"\nOptimal investments for {h}:")
        for i, j in edges_base:
            if investment_solution[h, i, j] > 0:
                print(f"Investment for {h} in edge ({i} -> {j}): {investment_solution[h, i, j]:g}")

        print(f"\nOptimal converted capacities for {h}:")
        for i, j in edges_base:
            if converted_capacity_solution[h, i, j] > 0:
                print(f"Converted capacity for {h} from {i} to {j}: {converted_capacity_solution[h, i, j]:g}")

    print("\nOptimal conversion indicators:")
    for h in commodities:
        for i, j in edges_base:
            #
                print(f"Conversion of {h} from {i} to {j} is: {conversion_indicator_solution[h, i, j]:g}")
else:
    print("No optimal solution found.")
# Out:
# ****************************
# Total cost: 5459.0
# ****************************
#
# Optimal flows for Methane:
# S1 -> D1: 20
# S2 -> D3: 80
# S3 -> D1: 15
# D1 -> D2: 20
# D3 -> D4: 55
# D4 -> D5: 44
# D4 -> D6: 10
# D6 -> D7: 10
# D5 -> D8: 10
# D5 -> D9: 10
# D7 -> D10: 5
#
# Optimal investments for Methane:
# Investment for Methane in edge (S2 -> D3): 80
# Investment for Methane in edge (D3 -> D4): 55
# Investment for Methane in edge (D4 -> D5): 44
#
# Optimal converted capacities for Methane:
# Converted capacity for Methane from S1 to D1: 500
# Converted capacity for Methane from S1 to D2: 500
# Converted capacity for Methane from S2 to D2: 500
# Converted capacity for Methane from S3 to D1: 500
# Converted capacity for Methane from D1 to D2: 500
# Converted capacity for Methane from D4 to D6: 500
# Converted capacity for Methane from D6 to D7: 500
# Converted capacity for Methane from D5 to D8: 500
# Converted capacity for Methane from D5 to D9: 500
# Converted capacity for Methane from D9 to D10: 500
# Converted capacity for Methane from D7 to D10: 500
#
# Optimal flows for Hydrogen:
# S1 -> D2: 20
# S2 -> D3: 81
# S3 -> D1: 15
# D3 -> D4: 56
# D4 -> D5: 45
# D4 -> D6: 10
# D6 -> D7: 5
# D5 -> D8: 10
# D5 -> D9: 15
# D9 -> D10: 5
#
# Optimal investments for Hydrogen:
# Investment for Hydrogen in edge (S1 -> D2): 20
# Investment for Hydrogen in edge (S3 -> D1): 15
# Investment for Hydrogen in edge (D4 -> D6): 10
# Investment for Hydrogen in edge (D6 -> D7): 5
# Investment for Hydrogen in edge (D5 -> D8): 10
# Investment for Hydrogen in edge (D5 -> D9): 15
# Investment for Hydrogen in edge (D9 -> D10): 5
#
# Optimal converted capacities for Hydrogen:
# Converted capacity for Hydrogen from S2 to D3: 500
# Converted capacity for Hydrogen from D3 to D4: 500
# Converted capacity for Hydrogen from D4 to D5: 500
#
# Optimal conversion indicators:
# Conversion of Methane from S1 to D1 is: 1
# Conversion of Methane from S1 to D2 is: 1
# Conversion of Methane from S2 to D2 is: 1
# Conversion of Methane from S2 to D3 is: 0
# Conversion of Methane from S3 to D1 is: 1
# Conversion of Methane from D1 to D2 is: 1
# Conversion of Methane from D3 to D4 is: 0
# Conversion of Methane from D4 to D5 is: -0
# Conversion of Methane from D4 to D6 is: 1
# Conversion of Methane from D6 to D7 is: 1
# Conversion of Methane from D5 to D8 is: 1
# Conversion of Methane from D5 to D9 is: 1
# Conversion of Methane from D9 to D10 is: 1
# Conversion of Methane from D7 to D10 is: 1
# Conversion of Hydrogen from S1 to D1 is: 0
# Conversion of Hydrogen from S1 to D2 is: 0
# Conversion of Hydrogen from S2 to D2 is: 0
# Conversion of Hydrogen from S2 to D3 is: 1
# Conversion of Hydrogen from S3 to D1 is: 0
# Conversion of Hydrogen from D1 to D2 is: 0
# Conversion of Hydrogen from D3 to D4 is: 1
# Conversion of Hydrogen from D4 to D5 is: 1
# Conversion of Hydrogen from D4 to D6 is: 0
# Conversion of Hydrogen from D6 to D7 is: 0
# Conversion of Hydrogen from D5 to D8 is: 0
# Conversion of Hydrogen from D5 to D9 is: 0
# Conversion of Hydrogen from D9 to D10 is: 0
# Conversion of Hydrogen from D7 to D10 is: 0
