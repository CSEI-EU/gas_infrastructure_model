# %% [markdown]
# # Model to transform the gas to an hydrogen grid

# %% [markdown]
# ### Import packages

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# %% [markdown]
# ### Import Data

# %%
# Specify the path to your Excel file
input_file_path = '../01_data/01_input_data/02_processed/'
excel_file_path = 'Data_update_V02.xlsx'  

# Read the Excel file into a DataFrame
df_nodes = pd.read_excel(input_file_path + excel_file_path, sheet_name='Nodes')
df_commodities = pd.read_excel(input_file_path + excel_file_path, sheet_name='Commodities')
df_edges = pd.read_excel(input_file_path + excel_file_path, sheet_name='Edges')
df_parameter = pd.read_excel(input_file_path + excel_file_path, sheet_name='Parameters')
df_supply_values = pd.read_excel(input_file_path + excel_file_path, sheet_name='Supply')

# %% [markdown]
# ### Create input data structure

# %%
# Extract nodes, edges and commodities from the DataFrames
Network_nodes = df_nodes['Nodes'].dropna().tolist()
Commodities = df_commodities['Commodities'].dropna().tolist()
Edges = list(zip(df_edges['Source'], df_edges['Destination']))

# Create a nested dictionary for initial capacities
Initial_capacities = {}
for index, row in df_parameter.iterrows():
    commodity = row['Commodity']
    source = row['Source']
    destination = row['Destination']
    initial_capacity = row['initial_capacities']

    edge = f"{source}{destination}"

    if commodity not in Initial_capacities:
        Initial_capacities[commodity] = {}

    Initial_capacities[commodity][edge] = initial_capacity

# Create a nested dictionary for max capacities
Max_capacities = {}
for index, row in df_parameter.iterrows():
    commodity = row['Commodity']
    source = row['Source']
    destination = row['Destination']
    max_capacity = row['max_capacities']

    edge = f"{source}{destination}"

    if commodity not in Max_capacities:
        Max_capacities[commodity] = {}

    Max_capacities[commodity][edge] = max_capacity

# Create a nested dictionary for edge cost
Edge_cost = {}
for index, row in df_parameter.iterrows():
    commodity = row['Commodity']
    source = row['Source']
    destination = row['Destination']
    edge_cost = row['costs_edge']

    edge = f"{source}{destination}"

    if commodity not in Edge_cost:
        Edge_cost[commodity] = {}

    Edge_cost[commodity][edge] = edge_cost

# Create a nested dictionary for new pipelines
Pipe_new_cost = {}
for index, row in df_parameter.iterrows():
    commodity = row['Commodity']
    source = row['Source']
    destination = row['Destination']
    new_cost = row['new_build_cost']

    edge = f"{source}{destination}"

    if commodity not in Pipe_new_cost:
        Pipe_new_cost[commodity] = {}

    Pipe_new_cost[commodity][edge] = new_cost

# Create a nested dictionary for pipeline conversion
Pipe_conv_cost = {}
for index, row in df_parameter.iterrows():
    commodity = row['Commodity']
    source = row['Source']
    destination = row['Destination']
    conv_cost = row['conversion_cost']

    edge = f"{source}{destination}"

    if commodity not in Pipe_conv_cost:
        Pipe_conv_cost[commodity] = {}

    Pipe_conv_cost[commodity][edge] = conv_cost

# Create a nested dictionary for adjusting the capacity when pipeline conversion
Pipe_conv_factor = {}
for index, row in df_parameter.iterrows():
    commodity = row['Commodity']
    source = row['Source']
    destination = row['Destination']
    conv_cap_factor = row['conversion_capacity_factor']

    edge = f"{source}{destination}"

    if commodity not in Pipe_conv_factor:
        Pipe_conv_factor[commodity] = {}

    Pipe_conv_factor[commodity][edge] = conv_cap_factor

# Create a nested dictionary for supply values, skipping 0 and NaN values
Supply_values = {}
for index, row in df_supply_values.iterrows():
    commodity = row['Commodity']
    supply_node = row['Node']
    supply_value = row['Supply']

    if commodity not in Supply_values:
        Supply_values[commodity] = {}

    # Skip 0 and NaN values
    if not pd.isna(supply_value) and supply_value != 0:
        Supply_values[commodity][supply_node] = supply_value

# Create a nested dictionary for node values, skipping 0 and NaN values
Node_values = {}
for index, row in df_supply_values.iterrows():
    commodity = row['Commodity']
    demand_node = row['Node']
    node_value = row['Supply']

    if commodity not in Node_values:
        Node_values[commodity] = {}

    # Skip 0 and NaN values
    #if not pd.isna(node_value) and node_value != 0:
    if not pd.isna(node_value):
        Node_values[commodity][demand_node] = node_value

# %%
'''
Create slack nodes for all supply nodes
link a node to supply in case of shortage in the system to all supply nodes
the capacity is infinite but at infinite (super high) cost
'''

# Create a new dictionary for positive values
positive_values_dict = {}

# Iterate through the outer dictionary
for node, values in Node_values.items():
    # Filter out positive values from the inner dictionary
    positive_values = {key: value for key, value in values.items() if value >= 0}
    
    # Check if there are positive values before adding to the new dictionary
    if positive_values:
        positive_values_dict[node] = positive_values

print("Dictionary with positive values:", positive_values_dict)

# Get all keys from the inner dictionaries
all_keys = [key for values in positive_values_dict.values() for key in values.keys()]

# Remove duplicates to get unique keys
unique_keys = list(set(all_keys))

print("Unique keys:", unique_keys)

# Create a list with names "shortage_" followed by each key
shortage_list = [f'shortage_{key}' for key in unique_keys]

print("Shortage list:", shortage_list)

#shortage_edges_list = [(key, shortage) for key, shortage in zip(unique_keys, shortage_list)]
shortage_edges_list = [(key, shortage) for key, shortage in zip(shortage_list, unique_keys)]


print("Edges list:", shortage_edges_list)

shoratege_capacity_dict = {commodity: {f'{key}{shortage}': 1000 for key, shortage in zip(shortage_list, unique_keys)} for commodity in Commodities}
shoratege_max_capacity_dict = shoratege_capacity_dict
print("Nested dictionary with capacities:", shoratege_capacity_dict)

shoratege_cost_dict = {commodity: {f'{key}{shortage}': 10000000 for key, shortage in zip(shortage_list, unique_keys)} for commodity in Commodities}
print("Shortage cost:", shoratege_cost_dict)
# Out:
# Dictionary with positive values: {'Methane': {'node_0001': 0.01, 'node_0003': 0.0, 'node_0004': 0.0, 'node_0005': 0.0, 'node_0006': 0.0, 'node_0007': 0.0, 'node_0008': 0.0, 'node_0009': 0.0, 'node_0010': 0.0, 'node_0011': 0.0, 'node_0012': 0.0, 'node_0013': 0.0, 'node_0014': 0.0, 'node_0015': 0.0, 'node_0016': 0.0, 'node_0017': 0.0, 'node_0018': 0.0, 'node_0019': 0.0, 'node_0020': 0.0, 'node_0021': 0.0, 'node_0022': 0.0, 'node_0023': 0.0, 'node_0024': 0.0, 'node_0025': 0.0, 'node_0026': 0.0, 'node_0027': 0.0, 'node_0028': 0.0, 'node_0029': 0.0, 'node_0030': 0.0, 'node_0031': 0.0, 'node_0032': 0.0, 'node_0033': 0.0, 'node_0034': 0.0, 'node_0035': 0.0, 'node_0036': 0.0, 'node_0037': 0.0, 'node_0038': 0.0, 'node_0039': 0.0, 'node_0040': 0.0, 'node_0041': 0.0, 'node_0042': 0.0, 'node
 'shortage_node_0176_2', 'shortage_node_0003', 'shortage_node_0569_2', 'shortage_node_0286', 'shortage_node_0230_1', 'shortage_node_0262_2', 'shortage_node_0483', 'shortage_node_0131_2', 'shortage_node_0608', 'shortage_node_0321', 'shortage_node_0453_2', 'shortage_node_0249_2', 'shortage_node_0312', 'shortage_node_0654', 'shortage_node_0016', 'shortage_node_0036_1', 'shortage_node_0400', 'shortage_node_0523', 'shortage_node_0115_1', 'shortage_node_0285', 'shortage_node_0132_2', 'shortage_node_0658', 'shortage_node_0130', 'shortage_node_0120_2', 'shortage_node_0195_3', 'shortage_node_0393_2', 'shortage_node_0217_1', 'shortage_node_0493_4', 'shortage_node_0417', 'shortage_node_0220_1', 'shortage_node_0440', 'shortage_node_0302_2', 'shortage_node_0429_1', 'shortage_node_0639', 'shortage_node_0369', 'shortage_node_0498', 'shortage_node_0556_1', 'shortage_node_0489', 'shortage_node_0450_1', 'shortage_node_0495', 'shortage_node_0284', 'shortage_node_0491', 'shortage_node_0127_2', 'shortage_node_0225', 'shortage_node_0140', 'shortage_node_0059', 'shortage_node_0576', 'shortage_node_0146_1', 'shortage_node_0230_2', 'shortage_node_0530', 'shortage_node_0104_2', 'shortage_node_0265_3', 'shortage_node_0193', 'shortage_node_0081', 'shortage_node_0304', 'shortage_node_0426', 'shortage_node_0260', 'shortage_node_0326', 'shortage_node_0146', 'shortage_node_0546', 'shortage_node_0574', 'shortage_node_0252', 'shortage_node_0036_3', 'shortage_node_0200', 'shortage_node_0102_2', 'shortage_node_0187', 'shortage_node_0250_1', 'shortage_node_0124', 'shortage_node_0314_1', 'shortage_node_0232', 'shortage_node_0100', 'shortage_node_0391_2', 'shortage_node_0636', 'shortage_node_0443', 'shortage_node_0547', 'shortage_node_0123_2', 'shortage_node_0340', 'shortage_node_0050', 'shortage_node_0162_2', 'shortage_node_0136', 'shortage_node_0206', 'shortage_node_0074', 'shortage_node_0013_2', 'shortage_node_0124_1', 'shortage_node_0314_2', 'shortage_node_0402', 'shortage_node_0476', 'shortage_node_0415', 'shortage_node_0085', 'shortage_node_0168_1', 'shortage_node_0266_1', 'shortage_node_0008', 'shortage_node_0450', 'shortage_node_0461', 'shortage_node_0533', 'shortage_node_0508', 'shortage_node_0078', 'shortage_node_0119_1', 'shortage_node_0156', 'shortage_node_0504', 'shortage_node_0246', 'shortage_node_0625', 'shortage_node_0611', 'shortage_node_0124_2', 'shortage_node_0522', 'shortage_node_0073', 'shortage_node_0371_2', 'shortage_node_0549', 'shortage_node_0310', 'shortage_node_0452', 'shortage_node_0526', 'shortage_node_0121_1', 'shortage_node_0485_1', 'shortage_node_0485', 'shortage_node_0288', 'shortage_node_0210', 'shortage_node_0197', 'shortage_node_0334', 'shortage_node_0453_4', 'shortage_node_0457', 'shortage_node_0202_2', 'shortage_node_0568', 'shortage_node_0413', 'shortage_node_0099', 'shortage_node_0279_1', 'shortage_node_0180', 'shortage_node_0036_2', 'shortage_node_0021', 'shortage_node_0327', 'shortage_node_0554', 'shortage_node_0157', 'shortage_node_0637', 'short
', 'node_0284'), ('shortage_node_0491', 'node_0491'), ('shortage_node_0127_2', 'node_0127_2'), ('shortage_node_0225', 'node_0225'), ('shortage_node_0140', 'node_0140'), ('shortage_node_0059', 'node_0059'), ('shortage_node_0576', 'node_0576'), ('shortage_node_0146_1', 'node_0146_1'), ('shortage_node_0230_2', 'node_0230_2'), ('shortage_node_0530', 'node_0530'), ('shortage_node_0104_2', 'node_0104_2'), ('shortage_node_0265_3', 'node_0265_3'), ('shortage_node_0193', 'node_0193'), ('shortage_node_0081', 'node_0081'), ('shortage_node_0304', 'node_0304'), ('shortage_node_0426', 'node_0426'), ('shortage_node_0260', 'node_0260'), ('shortage_node_0326', 'node_0326'), ('shortage_node_0146', 'node_0146'), ('shortage_node_0546', 'node_0546'), ('shortage_node_0574', 'node_0574'), ('shortage_node_0252', 'node_0252'), ('shortage_node_0036_3', 'node_0036_3'), ('shortage_node_0200', 'node_0200'), ('shortage_node_0102_2', 'node_0102_2'), ('shortage_node_0187', 'node_0187'), ('shortage_node_0250_1', 'node_0250_1'), ('shortage_node_0124', 'node_0124'), ('shortage_node_0314_1', 'node_0314_1'), ('shortage_node_0232', 'node_0232'), ('shortage_node_0100', 'node_0100'), ('shortage_node_0391_2', 'node_0391_2'), ('shortage_node_0636', 'node_0636'), ('shortage_node_0443', 'node_0443'), ('shortage_node_0547', 'node_0547'), ('shortage_node_0123_2', 'node_0123_2'), ('shortage_node_0340', 'node_0340'), ('shortage_node_0050', 'node_0050'), ('shortage_node_0162_2', 'node_0162_2'), ('shortage_node_0136', 'node_0136'), ('shortage_node_0206', 'node_0206'), ('shortage_node_0074', 'node_0074'), ('shortage_node_ ...
# Nested dictionary with capacities: {'Methane': {'shortage_node_0604node_0604': 1000, 'shortage_node_0170node_0170': 1000, 'shortage_node_0220node_0220': 1000, 'shortage_node_0134node_0134': 1000, 'shortage_node_0294node_0294': 1000, 'shortage_node_0122_1node_0122_1': 1000, 'shortage_node_0372_2node_0372_2': 1000, 'shortage_node_0519node_0519': 1000, 'shortage_node_0264_3node_0264_3': 1000, 'shortage_node_0393_1node_0393_1': 1000, 'shortage_node_0303node_0303': 1000, 'shortage_node_0027node_0027': 1000, 'shortage_node_0326_2node_0326_2': 1000, 'shortage_node_0049node_0049': 1000, 'shortage_node_0564node_0564': 1000, 'shortage_node_0627node_0627': 1000, 'shortage_node_0157_2node_0157_2': 1000, 'shortage_node_0104_1node_0104_1': 1000, 'shortage_node_0038node_0038': 1000, 'shortage_node_0276node_0276': 1000, 'shortage_node_0324_1node_0324_1': 1000, 'shortage_node_0176_2node_0176_2': 1000, 'shortage_node_0003node_0003': 1000, 'shortage_node_0569_2node_0569_2': 1000, 'shortage_node_0286node_0286': 1000, 'shortage_node_0230_1node_0230_1': 1000, 'shortage_node_0262_2node_0262_2': 1000, 'shortage_node_0483node_0483': 1000, 'shortage_node_0131_2node_0131_2': 1000, 'shortage_node_0608node_0608': 1000, 'shortage_node_0321node_0321': 1000, 'shortage_node_0453_2node_0453_2': 1000, 'shortage_node_0249_2node_0249_2': 1000, 'shortage_node_0312node_0312': 1000, 'shortage_node_0654node_0654': 1000, 'shortage_node_0016node_0016': 1000, 'shortage_node_0036_1node_0036_1': 1000, 'shortage_node_0400node_0400': 1000, 'shortage_node_0523node_0523': 1000, 'shortage_node_0115_1node_0115_1': 1000, 'shortage_node_0285node_0285': 1000, 'shortage_node_0132_2node_0132_2': 1000, 'shortage_node_0658node_0658': 1000, 'shortage_node_0130node_0130': 1000, 'shortage_node_0120_2node_0120_2': 1000, 'shortage_node_0195_3node_0195_3': 1000, 'shortage_node_0393_2node_0393_2': 1000, 'shortage_node_0217_1node_0217_1': 1000, 'shortage_node_0493_4node_0493_4': 1000, 'shortage_node_0417node_0417': 1000, 'shortage_node_0220_1node_0220_1': 1000, 'shortage_node_0440node_0440': 1000, 'shortage_node_0302_2node_0302_2': 1000, 'shortage_node_0429_1node_0429_1': 1000, 'shortage_node_0639node_0639': 1000, 'shortage_node_0369node_0369': 1000, 'shortage_node_0498node_0498': 1000, 'shortage_node_0556_1node_0556_1': 1000, 'shortage_node_0489node_0489': 1000, 'shortage_node_0450_1node_0450_1': 1000, 'shortage_node_0495node_0495': 1000, 'shortage_node_0284node_0284': 1000, 'shortage_node_0491node_0491': 1000, 'shortage_node_0127_2node_0127_2': 1000, 'shortage_node_0225node_0225': 1000, 'shortage_node_0140node_0140': 1000, 'shortage_node_0059node_0059': 1000, 'shortage_node_0576node_0576': 1000, 'shortage_node_0146_1node_0146_1': 1000, 'shortage_node_0230_2node_0230_2': 1000, 'shortage_node_0530node_0530': 1000, 'shortage_node_0104_2node_0104_2': 1000, 'shortage_node_0265_3node_0265_3': 1000, 'shortage_node_0193node_0193': 1000, 'shortage_node_0081node_0081': 1000, 'shortage_node_0304node_0304': 1000, 'shortage_node_0426node_0426': 1000, 'shortage_node_0260node_0260': 1000, 'shortage_node_0326node_0326': 1000, 'shortage_node_0146node_0146': 1000, 'shortage_node_0546node_0546': 1000, 'shortage_node_0574node_0574': 1000, 'shortage_node_0252node_0252': 1000, 'shortage_node_0036_3node_0036_3': 1000, 'shortage_node_0200node_0200': 1000, 'shortage_node_0102_2node_0102_2': 1000, 'shortage_node_0187node_0187': 1000, 'shortage_node_0250_1node_0250_1': 1000, 'shortage_node_0124node_0124': 1000, 'shortage_node_0314_1node_0314_1': 1000, 'shortage_node_0232node_0232': 1000, 'shortage_node_0100node_0100': 1000, 'shortage_node_0391_2node_0391_2': 1000, 'shortage_node_0636node_0636': 1000, 'shortage_node_0443node_0443': 1000, 'shortage_node_0547node_0547': 1000, 'shortage_node_0123_2node_0123_2': 1000, 'shortage_node_0340node_0340': 1000, 'shortage_node_0050node_0050': 1000, 'shortage_node_0162_2node_0162_2': 1000, 'shortage_node_0136node_0136': 1000, 'shortage_node_0206node_0206': 1000, 'shortage_node_007 ...
, 'shortage_node_0426node_0426': 10000000, 'shortage_node_0260node_0260': 10000000, 'shortage_node_0326node_0326': 10000000, 'shortage_node_0146node_0146': 10000000, 'shortage_node_0546node_0546': 10000000, 'shortage_node_0574node_0574': 10000000, 'shortage_node_0252node_0252': 10000000, 'shortage_node_0036_3node_0036_3': 10000000, 'shortage_node_0200node_0200': 10000000, 'shortage_node_0102_2node_0102_2': 10000000, 'shortage_node_0187node_0187': 10000000, 'shortage_node_0250_1node_0250_1': 10000000, 'shortage_node_0124node_0124': 10000000, 'shortage_node_0314_1node_0314_1': 10000000, 'shortage_node_0232node_0232': 10000000, 'shortage_node_0100node_0100': 10000000, 'shortage_node_0391_2node_0391_2': 10000000, 'shorta ...

# %% [markdown]
# Print data structure for control

# %%
# Print the data for control
#print("Network Nodes:", Network_nodes)
#print("Commodities:", Commodities)
#print("Edges:", Edges)
#print("Initial Capacities:", Initial_capacities)
#print("Max Capacities:", Max_capacities)
#print("Costs per edge Capacities:", Edge_cost)
#print("Costs for new pipelines:", Pipe_new_cost)
#print("Costs for convert pipelines:", Pipe_conv_cost)
#print("Conversion capacity factor:", Pipe_conv_factor)
print("Node Values:", Node_values)
# Out:
# Node Values: {'Methane': {'node_0001': 0.01, 'node_0002': -10.0, 'node_0003': 0.0, 'node_0004': 0.0, 'node_0005': 0.0, 'node_0006': 0.0, 'node_0007': 0.0, 'node_0008': 0.0, 'node_0009': 0.0, 'node_0010': 0.0, 'node_0011': 0.0, 'node_0012': 0.0, 'node_0013': 0.0, 'node_0014': 0.0, 'node_0015': 0.0, 'node_0016': 0.0, 'node_0017': 0.0, 'node_0018': 0.0, 'node_0019': 0.0, 'node_0020': 0.0, 'node_0021': 0.0, 'node_0022': 0.0, 'node_0023': 0.0, 'node_0024': 0.0, 'node_0025': 0.0, 'node_0026': 0.0, 'node_0027': 0.0, 'node_0028': 0.0, 'node_0029': 0.0, 'node_0030': 0.0, 'node_0031': 0.0, 'node_0032': 0.0, 'node_0033': 0.0, 'node_0034': 0.0, 'node_0035': 0.0, 'node_0036': 0.0, 'node_0037': 0.0, 'node_0038': 0.0, 'node_0039': 0.0, 'node_0040': 0.0, 'node_0041': 0.0, 'node_0042': 0.0, 'node_0043': 0.0, 'node_0044': 0.0, 'node_0045': 0.0, 'node_0046': 0.0, 'node_0047': 0.0, 'node_0048': 0.0, 'node_0049': 0.0, 'node_0050': 0.0, 'node_0051': 0.0, 'node_0052': 0.0, 'node_0053': 0.0, 'node_0054': 0.0, 'node_0055': 0.0, 'node_0056': 0.0, 'node_0057': 0.0, 'node_0058': 0.0, 'node_0059': 0.0, 'node_0060': 0.0, 'node_0061': 0.0, 'node_0062': 0.0, 'node_0063': 0.0, 'node_0064': 0.0, 'node_0065': 0.0, 'node_0066': 0.0, 'node_0067': 0.0, 'node_0068': 0.0, 'node_0069': 0.0, 'node_0070': 0.0, 'node_0071': 0.0, 'node_0072': 0.0, 'node_0073': 0.0, 'node_0074': 0.0, 'node_0075': 0.0, 'node_0076': 0.0, 'node_0077': 0.0, 'node_0
# %%
#implement factor to adjust capacity when conversion from methane to hydrogen
#TODO Implement it from the input file and use a correct factor
conversion_factor = Pipe_conv_factor

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create model

# %%
# Create a new model
model = gp.Model("Grid_Transformation")

# %% [markdown]
# ### Define parameters

# %%
# Parameters
commodities = Commodities  # Commodity types
#real network elements
network_nodes = Network_nodes # Nodes of the system
network_edges = Edges  # Edges
initial_capacities = Initial_capacities # Initial capacities
max_capacities = Max_capacities  # Maximum capacities
costs_edge = Edge_cost  # Cost to transport from node to node
capacity_new_cost = Pipe_new_cost  # Cost to increase capacity
capacity_change_cost = Pipe_conv_cost  # Cost to increase capacity
node_value = Node_values #contains supply and demand values

#slack parameters
slack_nodes = shortage_list
slack_edges = shortage_edges_list
slack_capacities = shoratege_capacity_dict
slack_cost = shoratege_cost_dict

#complete network of the model
all_edges = network_edges + shortage_edges_list

# %% [markdown]
# ### Define decision variables

# %%
# Decision variables
x_flow = {} #flow of commodity on an edge
x_flow_shortage = {}
y_new_cap = {} #new build capacity for a commodity on an edge between two edges
z_conv_cap = {} #capacity of a commodity converted on an edge between two nodes
Change = {} # Binary variable for switching

for commodity in commodities:
    x_flow[commodity] = {}
    x_flow_shortage[commodity] = {}
    y_new_cap[commodity] = {}
    z_conv_cap[commodity] = {}
    Change[commodity] = {}
    for edge in all_edges:
        x_flow[commodity][edge] = model.addVar(vtype=GRB.CONTINUOUS, name=f"x_flow_{commodity}_{edge[0]}_{edge[1]}")
        y_new_cap[commodity][edge] = model.addVar(vtype=GRB.CONTINUOUS, name=f"y_new_cap{commodity}_{edge[0]}_{edge[1]}")
        z_conv_cap[commodity][edge] = model.addVar(vtype=GRB.CONTINUOUS, name=f"z_conv_cap{commodity}_{edge[0]}_{edge[1]}")
        Change[commodity][edge] = model.addVar(vtype=GRB.BINARY, name=f"change_{commodity}_{edge[0]}_{edge[1]}")
    for edge in slack_edges:
        x_flow_shortage[commodity][edge] = model.addVar(vtype=GRB.CONTINUOUS, name=f"x_flow_shortage_{commodity}_{edge[0]}_{edge[1]}")
model.update()

# %% [markdown]
# ### Define objective and constraints

# %%
# Objective function (minimize total transportation cost + cost to increase and convert capacity)
model.setObjective(
    gp.quicksum(x_flow[commodity][edge] * costs_edge[commodity][f"{edge[0]}{edge[1]}"] for commodity in commodities for edge in network_edges) +
    gp.quicksum(y_new_cap[commodity][edge] * capacity_new_cost[commodity][f"{edge[0]}{edge[1]}"] for commodity in commodities for edge in network_edges) +
    gp.quicksum(z_conv_cap[commodity][edge] * capacity_change_cost[commodity][f"{edge[0]}{edge[1]}"] for commodity in commodities for edge in network_edges),
    #gp.quicksum(x_flow_shortage[commodity][edge] * slack_cost[commodity][f"{edge[0]}{edge[1]}"] for commodity in commodities for edge in slack_edges),
    GRB.MINIMIZE
)

# Constraints

#inflow of a node must equal the outflow of a node
for node in network_nodes:  
    for commodity in commodities:  
        # Flow conservation constraint for the current node and commodity
        model.addConstr(gp.quicksum(x_flow[commodity][edge] for edge in all_edges if edge[1] == node) 
                                    - gp.quicksum(x_flow[commodity][edge] for edge in network_edges if edge[0] == node)
                                    + node_value[commodity][node] 
                                    == 0, f"flow_constraint_{commodity}_{node}")

#slack node at the sources to avoid infeasible problems.        

# Supply constraints for the second commodity
for node in slack_nodes:
    for commodity in commodities: 
        model.addConstr(gp.quicksum(x_flow[commodity][edge] for edge in all_edges if edge[0] == node) >= 0, f"supply_shortage_{commodity}_{node}")


# Add constraint for equality between x_flow and x_flow_shortage for the same edge
for commodity in commodities:
    for edge in slack_edges:
        if (edge[0], edge[1]) in slack_edges or (edge[1], edge[0]) in slack_edges:
            # Ensure equality for the corresponding edges
            model.addConstr(x_flow[commodity][edge] == x_flow_shortage[commodity][(edge[0], edge[1])], 
                            f"equality_constraint_{commodity}_{edge}")


#Capacity constraint for flow
for commodity in commodities:
    for edge in network_edges:
        model.addConstr(x_flow[commodity][edge] 
                        <= y_new_cap[commodity][edge] + z_conv_cap[commodity][edge] #+ initial_capacities[commodity][f"{edge[0]}{edge[1]}"]
                        , f"used_capacity_{commodity}_{edge[0]}_{edge[1]}")

# Capacity constraint for maximal capacity
for commodity in commodities:
    for edge in network_edges:
        model.addConstr(y_new_cap[commodity][edge] + z_conv_cap[commodity][edge] 
                        <= max_capacities[commodity][f"{edge[0]}{edge[1]}"], f"capacity_{commodity}_{edge[0]}_{edge[1]}")

#Constraints for edge conversion
for edge in network_edges:
    model.addConstr(Change[Commodities[0]][edge] + Change[Commodities[1]][edge] == 1, f"switching_constraint_{edge[0]}_{edge[1]}")

for commodity in commodities:
    for edge in network_edges:
        model.addConstr(initial_capacities[Commodities[0]][f"{edge[0]}{edge[1]}"] * Change[commodity][edge] #* conversion_factor[commodity][node]
                        == z_conv_cap[commodity][edge], f"changed_capacity_{commodity}_{edge[0]}_{edge[1]}")

#Constraing no negative flow
for commodity in commodities:
    for edge in all_edges:
        model.addConstr(x_flow[commodity][edge] >= 0, f"non_negativity_x_{commodity}_{edge[0]}_{edge[1]}")

# %% [markdown]
# ### Optimize the model

# %%
# Optimize the model
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i5-8265U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19465 rows, 20012 columns and 38498 nonzeros
# Model fingerprint: 0x7469d2b7
# Variable types: 15478 continuous, 4534 integer (4534 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-02, 5e+07]
# Found heuristic solution: objective 1525843.6919
# Presolve removed 19465 rows and 20012 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 0.07 1.52584e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e-02, best bound 7.000000000000e-02, gap 0.0000%

# %% [markdown]
# ### Results processing

# %%
# Print the results
if model.status == GRB.OPTIMAL:
    print("Optimal solution found!")
    for commodity in commodities:
        for edge in network_edges:
            print(f"{commodity}, {edge}: "
                  f"Flow of Commodity = {x_flow[commodity][edge].x}, "
                  f"New Capacity = {y_new_cap[commodity][edge].x}, "
                  f"Switched = {Change[commodity][edge].x}, "
): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 2.549933272444444,
# Methane, ('node_0051', 'node_0052_3'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 5.673398079561833,
# Methane, ('node_0051', 'node_0052_2'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 3.852038590666667,
# Methane, ('node_0052', 'node_0329'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 3.852038590666667,
# Methane, ('node_0052', 'node_0324'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 3.852038590666667,
# Methane, ('node_0052', 'node_0431'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 3.852038590666667,
# Methane, ('node_0053', 'node_0432'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 2.549933272444444,
# Methane, ('node_0053', 'node_0054'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0054', 'node_0055'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0054', 'node_0065'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 61.36789729733329,
# Methane, ('node_0054', 'node_0064'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 2.549933272444444,
# Methane, ('node_0055', 'node_0433'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 5.673398079561833,
# Methane, ('node_0055', 'node_0056'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0056', 'node_0434'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0056', 'node_0057'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0057', 'node_0060'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0057', 'node_0058'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0057', 'node_0435'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 61.36789729733329,
# Methane, ('node_0057', 'node_0360'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0057', 'node_0061'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0058', 'node_0059'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0058', 'node_0436'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0059', 'node_0439'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0059', 'node_0438'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 5.673398079561833,
# Methane, ('node_0059', 'node_0437'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0060', 'node_0440'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 2.023442887897806,
# Methane, ('node_0061', 'node_0215'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 56.76155012711106,
# Methane, ('node_0061', 'node_0429'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0061', 'node_0062'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 61.36789729733329,
# Methane, ('node_0061', 'node_0063'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 15.47177291944894,
# Methane, ('node_0061', 'node_0064'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 90.789101532,
# Methane, ('node_0061', 'node_0066'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 15.36057079247639,
# Methane, ('node_0062', 'node_0063'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 5.673398079561833,
# Methane, ('node_0062', 'node_0363'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 34.70123063066669,
# Methane, ('node_0062', 'node_0441_1'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0062', 'node_0365'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 34.70123063066669,
# Methane, ('node_0062', 'node_0441_2'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 15.36057079247639,
# Methane, ('node_0062', 'node_0215'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 26.3839357426327,
# Methane, ('node_0062', 'node_0442'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 5.673398079561833,
# Methane, ('node_0062', 'node_0443'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0063', 'node_0444'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0064', 'node_0445'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0065', 'node_0067'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 4.078227497778987,
# Methane, ('node_0065', 'node_0066'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 5.673398079561833,
# Methane, ('node_0065', 'node_0442'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 4.078227497778987,
# Methane, ('node_0066', 'node_0446'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 5.673398079561833,
# Methane, ('node_0067', 'node_0103_1'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 61.37956396400001,
# Methane, ('node_0067', 'node_0447_1'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 28.80510625278224,
# Methane, ('node_0067', 'node_0447_2'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 61.37956396400001,
# Methane, ('node_0067', 'node_0103_2'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 28.80510625278224,
# Methane, ('node_0068', 'node_0070'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 120.1986391,
# Methane, ('node_0068', 'node_0069'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 120.1986391,
# Methane, ('node_0069', 'node_0448'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0070', 'node_0449'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 120.1986391,
# Methane, ('node_0070', 'node_0071'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0071', 'node_0450_2'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 120.1986391,
# Methane, ('node_0071', 'node_0450_1'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0071', 'node_0302_2'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0071', 'node_0072'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0071', 'node_0302_1'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0072', 'node_0451'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 120.1986391,
# Methane, ('node_0072', 'node_0073'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0073', 'node_0074'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 115.4066252323627,
# Methane, ('node_0074', 'node_0452'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 115.4066252323627,
# Methane, ('node_0074', 'node_0453_2'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 115.4066252323627,
# Methane, ('node_0074', 'node_0453_4'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 115.4066252323627,
# Methane, ('node_0074', 'node_0079'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 115.4066252323627,
# Methane, ('node_0074', 'node_0453_1'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 115.4066252323627,
# Methane, ('node_0074', 'node_0453_3'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 115.4066252323627,
# Methane, ('node_0074', 'node_0226'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 8.357698884795287,
# Methane, ('node_0074', 'node_0236_1'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 8.357698884795287,
# Methane, ('node_0074', 'node_0236_2'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 8.357698884795287,
# Methane, ('node_0074', 'node_0237'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 8.357698884795287,
# Methane, ('node_0075', 'node_0454'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 81.94943695986116,
# Methane, ('node_0075', 'node_0076'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 81.94943695986116,
# Methane, ('node_0076', 'node_0299'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 90.789101532,
# Methane, ('node_0076', 'node_0298'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 45.27075566186664,
# Methane, ('node_0076', 'node_0455_1'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0076', 'node_0455_2'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0076', 'node_0077'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 45.27075566186664,
# Methane, ('node_0076', 'node_0301'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 90.789101532,
# Methane, ('node_0077', 'node_0078'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 90.789101532,
# Methane, ('node_0077', 'node_0456'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0078', 'node_0079'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0078', 'node_0080'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0079', 'node_0240'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 34.70123063066669,
# Methane, ('node_0079', 'node_0239'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 15.926874516,
# Methane, ('node_0079', 'node_0457'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 11.407561044,
# Methane, ('node_0080', 'node_0458'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_0080', 'node_0081'): Flow of Commodity = 0.0, New Capacity = 0.0, Switched = 1.0, Changed Capacity = 27.80914334193531,
# Methane, ('node_
): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0258_2', 'node_0258_2'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0599', 'node_0599'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0359', 'node_0359'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0596', 'node_0596'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0007', 'node_0007'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0583', 'node_0583'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0314', 'node_0314'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0178', 'node_0178'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0436', 'node_0436'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0123', 'node_0123'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0113_2', 'node_0113_2'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0405', 'node_0405'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0228_1', 'node_0228_1'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0543', 'node_0543'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0150', 'node_0150'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0036', 'node_0036'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0548', 'node_0548'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0116_2', 'node_0116_2'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0228_3', 'node_0228_3'): Flow of Shortage = 0.0
# Hydrogen, ('shortage_node_0552', 'node_0552'): Flow of Shortage = 0.0
# ****************************
# Total cost: 0.07

# %%
# Assuming commodities, edges, x_flow, y_new_cap, Change, and z_conv_cap are defined in your code

# Create lists to store the data
results_data = []
columns = ["Commodity", "Edge", "Flow", "New Capacity", "Switched", "Changed Capacity"]
shortage_data = []
shortage_columns = ["Commodity", "Edge", "Flow"]

# Check if the model has an optimal solution
if model.status == GRB.OPTIMAL:
    for commodity in commodities:
        for edge in network_edges:
            # Append data to the list
            results_data.append([commodity,
                                 edge, 
                                 x_flow[commodity][edge].x, 
                                 y_new_cap[commodity][edge].x, 
                                 Change[commodity][edge].x, 
                                 z_conv_cap[commodity][edge].x])
        for edge in slack_edges:    
            shortage_data.append([commodity, 
                              edge, 
                              x_flow_shortage[commodity][edge].x])
else:
    print("No optimal solution found.")

if model.status == GRB.OPTIMAL:
    # Create a DataFrame
    results_df = pd.DataFrame(results_data, columns=columns)
    shortage_df = pd.DataFrame(shortage_data, columns=shortage_columns)
    # Print the DataFrame
    print(results_df)
    print('********************************')
    print(shortage_df)
# Out:
#      Commodity                      Edge  Flow  New Capacity  Switched  \
# 0      Methane  (node_0001, node_0002_2)  0.01           0.0       1.0
# 1      Methane  (node_0001, node_0002_1)  0.00           0.0       1.0
# 2      Methane    (node_0002, node_0362)  0.00           0.0       1.0
# 3      Methane    (node_0003, node_0004)  0.00           0.0       1.0
# 4      Methane    (node_0003, node_0196)  0.00           0.0       1.0
# ...        ...                       ...   ...           ...       ...
# 2653  Hydrogen  (node_0577_2, node_0577)  0.00           0.0       0.0
# 2654  Hydrogen  (node_0584_1, node_0584)  0.00           0.0       0.0
# 2655  Hydrogen  (node_0584_2, node_0584)  0.00           0.0       0.0
# 2656  Hydrogen  (node_0643_1, node_0643)  0.00           0.0       0.0
# 2657  Hydrogen  (node_0643_2, node_0643)  0.00           0.0       0.0
#
#       Changed Capacity
# 0            27.809143
# 1            27.809143
# 2            65.753400
# 3            27.809143
# 4             6.329657
# ...                ...
# 2653          0.000000
# 2654          0.000000
# 2655          0.000000
# 2656          0.000000
# 2657          0.000000
#
# [2658 rows x 6 columns]
# ********************************
#      Commodity                                 Edge  Flow
# 0      Methane      (shortage_node_0604, node_0604)   0.0
# 1      Methane      (shortage_node_0170, node_0170)   0.0
# 2      Methane      (shortage_node_0220, node_0220)   0.0
# 3      Methane      (shortage_node_0134, node_0134)   0.0
# 4      Methane      (shortage_node_0294, node_0294)   0.0
# ...        ...                                  ...   ...
# 1871  Hydrogen      (shortage_node_0036, node_0036)   0.0
# 1872  Hydrogen      (shortage_node_0548, node_0548)   0.0
# 1873  Hydrogen  (shortage_node_0116_2, node_0116_2)   0.0
# 1874  Hydrogen  (shortage_node_0228_3, node_0228_3)   0.0
# 1875  Hydrogen      (shortage_node_0552, node_0552)   0.0
#
# [1876 rows x 3 columns]

# %%
#model.write()

# %%
results_df
# Out:
#      Commodity                      Edge  Flow  New Capacity  Switched  \
# 0      Methane  (node_0001, node_0002_2)  0.01           0.0       1.0
# 1      Methane  (node_0001, node_0002_1)  0.00           0.0       1.0
# 2      Methane    (node_0002, node_0362)  0.00           0.0       1.0
# 3      Methane    (node_0003, node_0004)  0.00           0.0       1.0
# 4      Methane    (node_0003, node_0196)  0.00           0.0       1.0
# ...        ...                       ...   ...           ...       ...
# 2653  Hydrogen  (node_0577_2, node_0577)  0.00           0.0       0.0
# 2654  Hydrogen  (node_0584_1, node_0584)  0.00           0.0       0.0
# 2655  Hydrogen  (node_0584_2, node_0584)  0.00           0.0       0.0
# 2656  Hydrogen  (node_0643_1, node_0643)  0.00           0.0       0.0
# 2657  Hydrogen  (node_0643_2, node_0643)  0.00           0.0       0.0
#
#       Changed Capacity
# 0            27.809143
# 1            27.809143
# 2            65.753400
# 3            27.809143
# 4             6.329657
# ...                ...
# 2653          0.000000
# 2654          0.000000
# 2655          0.000000
# 2656          0.000000
# 2657          0.000000
#
# [2658 rows x 6 columns]

# %%
search_element = 'node_0001'

# Filter rows based on whether the search element is present in 'Column1'
string_df = results_df[results_df['Edge'].astype(str).str.contains(search_element, case=False, na=False)]

# Display the resulting DataFrame
string_df
# Out:
# Empty DataFrame
# Columns: [Commodity, Edge, Flow, New Capacity, Switched, Changed Capacity]
# Index: []

# %%
shortage_df
# Out:
#      Commodity                                 Edge  Flow
# 0      Methane      (shortage_node_0604, node_0604)   0.0
# 1      Methane      (shortage_node_0170, node_0170)   0.0
# 2      Methane      (shortage_node_0220, node_0220)   0.0
# 3      Methane      (shortage_node_0134, node_0134)   0.0
# 4      Methane      (shortage_node_0294, node_0294)   0.0
# ...        ...                                  ...   ...
# 1871  Hydrogen      (shortage_node_0036, node_0036)   0.0
# 1872  Hydrogen      (shortage_node_0548, node_0548)   0.0
# 1873  Hydrogen  (shortage_node_0116_2, node_0116_2)   0.0
# 1874  Hydrogen  (shortage_node_0228_3, node_0228_3)   0.0
# 1875  Hydrogen      (shortage_node_0552, node_0552)   0.0
#
# [1876 rows x 3 columns]

# %%
search_element = 'node_0002'

# Filter rows based on whether the search element is present in 'Column1'
string_df = shortage_df[shortage_df['Edge'].astype(str).str.contains(search_element, case=False, na=False)]

# Display the resulting DataFrame
string_df
# Out:
#      Commodity                                 Edge  Flow
# 419    Methane  (shortage_node_0002_1, node_0002_1)  0.00
# 469    Methane      (shortage_node_0002, node_0002)  9.99
# 786    Methane  (shortage_node_0002_2, node_0002_2)  0.00
# 1357  Hydrogen  (shortage_node_0002_1, node_0002_1)  0.00
# 1407  Hydrogen      (shortage_node_0002, node_0002)  0.00
# 1724  Hydrogen  (shortage_node_0002_2, node_0002_2)  0.00
