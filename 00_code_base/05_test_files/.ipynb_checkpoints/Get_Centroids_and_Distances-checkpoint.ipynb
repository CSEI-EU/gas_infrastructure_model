# %%
import geopandas as gpd
import pandas as pd
import os
from haversine import haversine, Unit
import matplotlib.pyplot as plt
from shapely.geometry import MultiPolygon, Polygon
from itertools import combinations

# %%
def generate_country_connections(shape_gdf):
    """Generate a list of connections (country pairs) for neighboring countries."""
    connections = []  # List to store connections
    
    # Iterate through each country in the GeoDataFrame
    for idx1, row1 in shape_gdf.iterrows():
        country1 = row1['NUTS_ID']
        geometry1 = row1['geometry']
        
        # Compare with other countries (excluding self-comparison)
        for idx2, row2 in shape_gdf.iterrows():
            country2 = row2['NUTS_ID']
            if country1 != country2 and geometry1.touches(row2['geometry']):
                # Add the connection (sorted to avoid duplicates)
                connection = tuple(sorted((country1, country2)))
                if connection not in connections:
                    connections.append(connection)
    
    return connections

def calculate_polygon_areas(countries_gdf):
    """
    Calculate the areas of polygons in a GeoDataFrame, handling MultiPolygons and single Polygons.
    
    Parameters:
    - countries_gdf: GeoDataFrame with polygon geometries.

    Returns:
    - A GeoDataFrame with columns ['NUTS_ID', 'Polygon Number', 'Area', 'geometry'], where:
        - 'Area' is in the CRS's units (square meters for projected CRS).
        - 'geometry' contains individual polygons.
    """
    if not isinstance(countries_gdf, gpd.GeoDataFrame):
        raise ValueError("Input must be a GeoDataFrame.")
    
    # Ensure the GeoDataFrame has a CRS
    if countries_gdf.crs is None:
        raise ValueError("Input GeoDataFrame must have a defined CRS.")
    
    original_crs = countries_gdf.crs  # Save the original CRS

    # Reproject to a projected CRS for accurate area calculations
    projected_gdf = countries_gdf.to_crs(epsg=3035)  # ETRS89 / LAEA Europe

    # Create an empty list to store the data
    data = []

    # Loop through each row in the GeoDataFrame
    for idx, row in projected_gdf.iterrows():
        nuts_id = row['NUTS_ID']
        geometry = row['geometry']
        
        # Handle MultiPolygons
        if geometry.geom_type == "MultiPolygon":
            for polygon_idx, poly in enumerate(geometry.geoms):
                # Calculate the area (in square meters)
                area = poly.area
                # Append the data to the list
                data.append({'NUTS_ID': nuts_id, 
                             'Polygon Number': polygon_idx + 1, 
                             'Area': area, 
                             'geometry': poly})
        elif geometry.geom_type == "Polygon":
            # For a single polygon, calculate the area
            area = geometry.area
            # Append the data to the list
            data.append({'NUTS_ID': nuts_id, 
                         'Polygon Number': 1, 
                         'Area': area, 
                         'geometry': geometry})

    # Convert the data list into a GeoDataFrame
    result_gdf = gpd.GeoDataFrame(data, crs=projected_gdf.crs)

    # Reproject the result back to the original CRS
    result_gdf = result_gdf.to_crs(original_crs)

    return result_gdf

# Function to get the n-largest polygons for specific countries and the largest for the rest
def get_custom_largest_polygons(result_gdf, nuts_dict):
    """
    Get the n-largest polygons for specific countries specified in `nuts_dict`
    and the largest polygon for all other countries.

    Parameters:
    - result_gdf: GeoDataFrame containing polygon information, including 'geometry' and 'Area'.
    - nuts_dict: Dictionary where keys are NUTS_IDs and values are integers specifying the number of polygons.

    Returns:
    - A GeoDataFrame with the selected polygons.
    """
    if not isinstance(result_gdf, gpd.GeoDataFrame):
        raise ValueError("Input must be a GeoDataFrame.")
    
    # Sort the GeoDataFrame by 'NUTS_ID' and 'Area' (in descending order)
    sorted_gdf = result_gdf.sort_values(by=['NUTS_ID', 'Area'], ascending=[True, False])
    
    # Initialize an empty list to store results
    selected_rows = []
    
    # Group by 'NUTS_ID'
    for nuts_id, group in sorted_gdf.groupby('NUTS_ID'):
        # Check if the NUTS_ID is in the dictionary
        if nuts_id in nuts_dict:
            # Get the n-largest polygons for this country
            n = nuts_dict[nuts_id]
            selected_rows.append(group.head(n))
        else:
            # Get only the largest polygon for this country
            selected_rows.append(group.head(1))
    
    # Concatenate the results into a single GeoDataFrame
    result = gpd.GeoDataFrame(pd.concat(selected_rows), crs=result_gdf.crs).reset_index(drop=True)
    
    return result

# Function to merge polygons with the same NUTS_ID into a single MultiPolygon
def merge_polygons_by_country(df):
    """
    Merge all polygons with the same NUTS_ID into a single MultiPolygon.
    If there's only one polygon, it will be kept as a Polygon.

    Parameters:
    - df: GeoDataFrame with columns ['NUTS_ID', 'Coordinates'] where 'Coordinates' are Polygon objects.

    Returns:
    - A GeoDataFrame with merged MultiPolygons (or a single Polygon if only one exists) for each NUTS_ID,
      maintaining the CRS of the input GeoDataFrame.
    """
    if not isinstance(df, gpd.GeoDataFrame):
        raise ValueError("Input must be a GeoDataFrame.")
    
    # Ensure the GeoDataFrame has a CRS
    if df.crs is None:
        raise ValueError("Input GeoDataFrame must have a defined CRS.")
    
    original_crs = df.crs  # Save the original CRS
    
    merged_data = []
    
    # Group by 'NUTS_ID' and merge all polygons for each country
    for nuts_id, group in df.groupby('NUTS_ID'):
        polygons = [Polygon(coords) for coords in group['geometry']]
        
        # If there's more than one polygon, create a MultiPolygon
        if len(polygons) > 1:
            merged_geometry = MultiPolygon(polygons)
        else:
            # If there's only one polygon, keep it as a Polygon
            merged_geometry = polygons[0]
        
        merged_data.append({'NUTS_ID': nuts_id, 'geometry': merged_geometry})
    
    # Create a GeoDataFrame with the merged geometries, using the original CRS
    merged_gdf = gpd.GeoDataFrame(merged_data, crs=original_crs)
    return merged_gdf

def generate_all_country_distances(shape_gdf):
    """Generate all possible combinations of countries with distances between centroids using the Haversine formula."""
    
    # Reproject to a projected coordinate system (EPSG:3035 for Europe)
    shape_gdf = shape_gdf.to_crs(epsg=3035)
    
    # Calculate centroids in the projected CRS (in meters)
    shape_gdf['centroid'] = shape_gdf.geometry.centroid
    
    # Reproject centroids to geographic coordinates (EPSG:4326) to account for Earth's curvature
    centroids_gdf = shape_gdf.copy()
    centroids_gdf = centroids_gdf.set_geometry('centroid').to_crs(epsg=4326)
    
    # Create a dictionary with NUTS_IDs and their centroid coordinates in EPSG:4326 (latitude, longitude)
    country_centroids = {
        row['NUTS_ID']: (row['centroid'].y, row['centroid'].x)  # (latitude, longitude)
        for idx, row in centroids_gdf.iterrows()
    }
    
    # Generate all possible combinations of country pairs
    country_ids = list(country_centroids.keys())
    connections = list(combinations(country_ids, 2))
    
    # Calculate Haversine distances for each pair of countries in kilometers
    distances = []
    for country1, country2 in connections:
        coord1 = country_centroids[country1]
        coord2 = country_centroids[country2]
        
        # Calculate distance using the Haversine formula (accounting for Earth's curvature)
        distance = haversine(coord1, coord2, unit=Unit.KILOMETERS)
        distances.append((country1, country2, distance))
    
    return distances

# %%
input_file_path = os.path.join('..', '..','01_data', '01_input_data', '02_processed')
input_shape_EU_file_path = os.path.join('..', '..','01_data', '01_input_data', '01_raw', 'eu_shape_file')
shape_file_EU = '/NUTS_RG_20M_2021_3035.shp'

#get path
current_folder_path = os.getcwd()
parent_folder_path = os.path.abspath(os.path.join(current_folder_path, os.pardir))

shape_EU = gpd.read_file(input_shape_EU_file_path + shape_file_EU)

# %%
shape_EU_countries = shape_EU[shape_EU['LEVL_CODE'] == 0]
shape_EU_countries
# Out:
#    NUTS_ID  LEVL_CODE CNTR_CODE                NAME_LATN  \
# 0       FR          0        FR                   France
# 1       HR          0        HR                 Hrvatska
# 2       HU          0        HU             Magyarország
# 3       AL          0        AL                Shqipëria
# 4       AT          0        AT               Österreich
# 5       BE          0        BE          Belgique/België
# 6       BG          0        BG                 Bulgaria
# 7       CH          0        CH  Schweiz/Suisse/Svizzera
# 8       CY          0        CY                   Kýpros
# 9       CZ          0        CZ                    Česko
# 10      DE          0        DE              Deutschland
# 11      DK          0        DK                  Danmark
# 12      EE          0        EE                    Eesti
# 21      EL          0        EL                   Elláda
# 22      IE          0        IE             Éire/Ireland
# 23      ES          0        ES                   España
# 24      FI          0        FI            Suomi/Finland
# 25      IS          0        IS                   Ísland
# 27      PT          0        PT                 Portugal
# 28      RO          0        RO                  România
# 29      RS          0        RS                   Serbia
# 30      SE          0        SE                  Sverige
# 31      SI          0        SI                Slovenija
# 32      SK          0        SK                Slovensko
# 33      TR          0        TR                  Türkiye
# 42      UK          0        UK           United Kingdom
# 44      NO          0        NO                    Norge
# 61      IT          0        IT                   Italia
# 62      LI          0        LI            Liechtenstein
# 63      LT          0        LT                  Lietuva
# 64      LU          0        LU               Luxembourg
# 65      LV          0        LV                  Latvija
# 66      ME          0        ME                Crna Gora
# 67      MK          0        MK       Severna Makedonija
# 68      MT          0        MT                    Malta
# 69      NL          0        NL                Nederland
# 84      PL          0        PL                   Polska
#
#                   NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE FID  \
# 0                    France         0.0          0           0  FR
# 1                  Hrvatska         0.0          0           0  HR
# 2              Magyarország         0.0          0           0  HU
# 3                 Shqipëria         0.0          0           0  AL
# 4                Österreich         0.0          0           0  AT
# 5           Belgique/België         0.0          0           0  BE
# 6                  България         0.0          0           0  BG
# 7   Schweiz/Suisse/Svizzera         0.0          0           0  CH
# 8                    Κύπρος         0.0          0           0  CY
# 9                     Česko         0.0          0           0  CZ
# 10              Deutschland         0.0          0           0  DE
# 11                  Danmark         0.0          0           0  DK
# 12                    Eesti         0.0          0           0  EE
# 21                   Ελλάδα         0.0          0           0  EL
# 22             Éire/Ireland         0.0          0           0  IE
# 23                   España         0.0          0           0  ES
# 24            Suomi/Finland         0.0          0           0  FI
# 25                   Ísland         0.0          0           0  IS
# 27                 Portugal         0.0          0           0  PT
# 28                  România         0.0          0           0  RO
# 29            Srbija/Сpбија         0.0          0           0  RS
# 30                  Sverige         0.0          0           0  SE
# 31                Slovenija         0.0          0           0  SI
# 32                Slovensko         0.0          0           0  SK
# 33                  Türkiye         0.0          0           0  TR
# 42           United Kingdom         0.0          0           0  UK
# 44                    Norge         0.0          0           0  NO
# 61                   Italia         0.0          0           0  IT
# 62            Liechtenstein         0.0          0           0  LI
# 63                  Lietuva         0.0          0           0  LT
# 64               Luxembourg         0.0          0           0  LU
# 65                  Latvija         0.0          0           0  LV
# 66                Црна Гора         0.0          0           0  ME
# 67       Северна Македонија         0.0          0           0  MK
# 68                    Malta         0.0          0           0  MT
# 69                Nederland         0.0          0           0  NL
# 84                   Polska         0.0          0           0  PL
#
#                                              geometry
# 0   MULTIPOLYGON (((9954236.116 -3059379.316, 9961...
# 1   MULTIPOLYGON (((4827385.889 2618351.326, 48483...
# 2   POLYGON ((5214660.069 2880853.832, 5216710.220...
# 3   POLYGON ((5129579.170 2204098.752, 5148385.473...
# 4   POLYGON ((4742889.368 2876362.725, 4783217.798...
# 5   POLYGON ((3957506.818 3167694.476, 3964175.126...
# 6   POLYGON ((5363358.686 2390534.464, 5395245.631...
# 7   POLYGON ((4221123.476 2731035.919, 4230514.931...
# 8   POLYGON ((6342668.882 1629618.498, 6342926.802...
# 9   POLYGON ((4645979.160 3093185.023, 4656689.778...
# 10  MULTIPOLYGON (((4264045.786 3530123.440, 42755...
# 11  MULTIPOLYGON (((4649970.056 3564245.706, 46461...
# 12  MULTIPOLYGON (((5209290.379 4151086.253, 52115...
# 21  MULTIPOLYGON (((5933660.592 1621535.498, 59219...
# 22  MULTIPOLYGON (((3230329.820 3682748.467, 31996...
# 23  MULTIPOLYGON (((3828319.814 1893178.953, 38317...
# 24  MULTIPOLYGON (((5073773.420 5207018.495, 50659...
# 25  POLYGON ((2801938.567 4882218.079, 2796614.316...
# 27  MULTIPOLYGON (((2822605.491 2261163.044, 28317...
# 28  POLYGON ((5616141.550 2872864.277, 5661531.895...
# 29  POLYGON ((5112369.786 2611777.777, 5147917.997...
# 30  MULTIPOLYGON (((4968500.376 4802688.699, 49724...
# 31  POLYGON ((4807826.153 2644113.739, 4827385.889...
# 32  POLYGON ((5038951.099 2947340.447, 5053038.090...
# 33  MULTIPOLYGON (((6409166.817 2417609.250, 64213...
# 42  MULTIPOLYGON (((3643416.574 3198789.397, 36397...
# 44  MULTIPOLYGON (((5073773.420 5207018.495, 50670...
# 61  MULTIPOLYGON (((4510728.830 2621660.509, 45270...
# 62  POLYGON ((4281155.780 2659947.764, 4285464.426...
# 63  POLYGON ((5298223.159 3769132.577, 5303983.134...
# 64  POLYGON ((4044953.867 3009232.573, 4046925.344...
# 65  POLYGON ((5350178.139 3949790.862, 5360225.824...
# 66  POLYGON ((5066457.268 2314658.245, 5106789.821...
# 67  POLYGON ((5338319.640 2217739.395, 5347083.127...
# 68  MULTIPOLYGON (((4737037.613 1433526.447, 47322...
# 69  MULTIPOLYGON (((4113226.333 3371154.950, 41159...
# 84  POLYGON ((4901276.725 3508415.463, 4926344.597...

# %%
countries_gdf = shape_EU_countries

# %%
#for testing to se where reduction is necessary. 
countries_gdf['num_polygons'] = countries_gdf['geometry'].apply(lambda geom: len(geom.geoms) if geom.geom_type == 'MultiPolygon' else 1)

# This adds a new column 'num_polygons' to the GeoDataFrame showing the number of polygons per geometry
print(countries_gdf[['NUTS_ID', 'num_polygons']])
# Out:
#    NUTS_ID  num_polygons
# 0       FR            13
# 1       HR            16
# 2       HU             1
# 3       AL             1
# 4       AT             1
# 5       BE             1
# 6       BG             1
# 7       CH             1
# 8       CY             1
# 9       CZ             1
# 10      DE            10
# 11      DK            15
# 12      EE             6
# 21      EL            64
# 22      IE             4
# 23      ES            14
# 24      FI            17
# 25      IS             1
# 27      PT            13
# 28      RO             1
# 29      RS             1
# 30      SE            13
# 31      SI             1
# 32      SK             1
# 33      TR            11
# 42      UK            25
# 44      NO            59
# 61      IT            14
# 62      LI             1
# 63      LT             1
# 64      LU             1
# 65      LV             1
# 66      ME             1
# 67      MK             1
# 68      MT             2
# 69      NL             5
# 84      PL             1
# C:\Users\jfg.eco\AppData\Local\anaconda3\envs\network\Lib\site-packages\geopandas\geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
#get the area of each polygon of the countries
result_df = calculate_polygon_areas(countries_gdf)

# Display the result
result_df
# Out:
#     NUTS_ID  Polygon Number          Area  \
# 0        FR               1  2.504704e+09
# 1        FR               2  3.543977e+08
# 2        FR               3  8.522574e+09
# 3        FR               4  5.403194e+11
# 4        FR               5  1.769418e+07
# ..      ...             ...           ...
# 316      NL               2  3.811388e+07
# 317      NL               3  5.967475e+07
# 318      NL               4  7.480247e+07
# 319      NL               5  6.961660e+08
# 320      PL               1  3.124849e+11
#
#                                               geometry
# 0    POLYGON ((9954236.116 -3059379.316, 9961022.58...
# 1    POLYGON ((8737673.169 -2781863.518, 8730534.70...
# 2    POLYGON ((4204641.590 2142132.030, 4218982.040...
# 3    POLYGON ((3767290.578 3128769.785, 3781813.076...
# 4    POLYGON ((3439459.782 2634601.418, 3441784.186...
# ..                                                 ...
# 316  POLYGON ((4101081.246 3385853.822, 4096713.358...
# 317  POLYGON ((4037303.975 3378618.114, 4030721.992...
# 318  POLYGON ((4003907.318 3378893.960, 4005930.016...
# 319  POLYGON ((3919814.395 3153328.456, 3900841.306...
# 320  POLYGON ((4901276.725 3508415.463, 4926344.597...
#
# [321 rows x 4 columns]

# %%
# get the n-largest polygons for specific countries and the largest for the rest
nuts_selection = {'DK': 3, 'HR':2, 'TR': 2, 'EE':3, 'EL':2, 'IT':2, 'NL':2}
largest_polygons_df = get_custom_largest_polygons(result_df, nuts_selection)

# Display the result
largest_polygons_df
# Out:
#    NUTS_ID  Polygon Number          Area  \
# 0       AL               1  2.866265e+10
# 1       AT               1  8.385113e+10
# 2       BE               1  3.075490e+10
# 3       BG               1  1.113900e+11
# 4       CH               1  4.105576e+10
# 5       CY               1  9.240976e+09
# 6       CZ               1  7.889687e+10
# 7       DE               1  3.567203e+11
# 8       DK               9  2.965273e+10
# 9       DK               3  9.279380e+09
# 10      DK              10  3.018938e+09
# 11      EE               1  4.118863e+10
# 12      EE               4  2.900587e+09
# 13      EE               6  9.573647e+08
# 14      EL              22  1.097661e+11
# 15      EL              13  8.115833e+09
# 16      ES               2  4.935108e+11
# 17      FI               1  3.363231e+11
# 18      FR               4  5.403194e+11
# 19      HR               1  5.411188e+10
# 20      HR               2  5.435646e+08
# 21      HU               1  9.296786e+10
# 22      IE               1  6.943828e+10
# 23      IS               1  1.023249e+11
# 24      IT               1  2.516647e+11
# 25      IT               2  2.544614e+10
# 26      LI               1  1.601060e+08
# 27      LT               1  6.458440e+10
# 28      LU               1  2.627466e+09
# 29      LV               1  6.464656e+10
# 30      ME               1  1.396885e+10
# 31      MK               1  2.539249e+10
# 32      MT               1  1.948578e+08
# 33      NL               1  3.634356e+10
# 34      NL               5  6.961660e+08
# 35      NO               1  3.307595e+11
# 36      PL               1  3.124849e+11
# 37      PT               1  8.925915e+10
# 38      RO               1  2.380225e+11
# 39      RS               1  7.723589e+10
# 40      SE               2  4.476694e+11
# 41      SI               1  2.014800e+10
# 42      SK               1  4.891886e+10
# 43      TR               1  7.550814e+11
# 44      TR               5  2.361007e+10
# 45      UK               1  2.215355e+11
#
#                                              geometry
# 0   POLYGON ((5129579.170 2204098.752, 5148385.473...
# 1   POLYGON ((4742889.368 2876362.725, 4783217.798...
# 2   POLYGON ((3957506.818 3167694.476, 3964175.126...
# 3   POLYGON ((5363358.686 2390534.464, 5395245.631...
# 4   POLYGON ((4221123.476 2731035.919, 4230514.931...
# 5   POLYGON ((6342668.882 1629618.498, 6342926.802...
# 6   POLYGON ((4645979.160 3093185.023, 4656689.778...
# 7   POLYGON ((4264045.786 3530123.440, 4275595.699...
# 8   POLYGON ((4332922.532 3731303.092, 4339826.980...
# 9   POLYGON ((4483003.908 3636653.240, 4483442.702...
# 10  POLYGON ((4346789.441 3609710.882, 4355965.532...
# 11  POLYGON ((5209290.379 4151086.253, 5211504.484...
# 12  POLYGON ((5093063.177 4019591.237, 5096515.843...
# 13  POLYGON ((5041562.109 4062334.915, 5065501.847...
# 14  POLYGON ((5670221.352 2102712.082, 5661479.175...
# 15  POLYGON ((5627380.472 1488246.139, 5681341.669...
# 16  POLYGON ((2954461.558 2426794.999, 3013289.118...
# 17  POLYGON ((5073773.420 5207018.495, 5065993.914...
# 18  POLYGON ((3767290.578 3128769.785, 3781813.076...
# 19  POLYGON ((4827385.889 2618351.326, 4848359.353...
# 20  POLYGON ((5014573.760 2200024.633, 5023279.372...
# 21  POLYGON ((5214660.069 2880853.832, 5216710.220...
# 22  POLYGON ((3230329.820 3682748.467, 3199681.292...
# 23  POLYGON ((2801938.567 4882218.079, 2796614.316...
# 24  POLYGON ((4510728.830 2621660.509, 4527096.498...
# 25  POLYGON ((4787071.748 1652570.066, 4774864.571...
# 26  POLYGON ((4281155.780 2659947.764, 4285464.426...
# 27  POLYGON ((5298223.159 3769132.577, 5303983.134...
# 28  POLYGON ((4044953.867 3009232.573, 4046925.344...
# 29  POLYGON ((5350178.139 3949790.862, 5360225.824...
# 30  POLYGON ((5066457.268 2314658.245, 5106789.821...
# 31  POLYGON ((5338319.640 2217739.395, 5347083.127...
# 32  POLYGON ((4737037.613 1433526.447, 4732202.789...
# 33  POLYGON ((4113226.333 3371154.950, 4115951.862...
# 34  POLYGON ((3919814.395 3153328.456, 3900841.306...
# 35  POLYGON ((5073773.420 5207018.495, 5067047.421...
# 36  POLYGON ((4901276.725 3508415.463, 4926344.597...
# 37  POLYGON ((2822605.491 2261163.044, 2831796.087...
# 38  POLYGON ((5616141.550 2872864.277, 5661531.895...
# 39  POLYGON ((5112369.786 2611777.777, 5147917.997...
# 40  POLYGON ((4967895.593 4811191.227, 4946337.943...
# 41  POLYGON ((4807826.153 2644113.739, 4827385.889...
# 42  POLYGON ((5038951.099 2947340.447, 5053038.090...
# 43  POLYGON ((6409166.817 2417609.250, 6421318.970...
# 44  POLYGON ((5804912.665 2276442.795, 5805255.075...
# 45  POLYGON ((3643416.574 3198789.397, 3639715.928...

# %%
# merge polygons with the same NUTS_ID into a single MultiPolygon
merged_gdf = merge_polygons_by_country(largest_polygons_df)

# %%
# Example usage
connections_list = generate_country_connections(shape_EU_countries)

# %%
# calculate distances
distances = generate_all_country_distances(merged_gdf)

# Output the distances
for country1, country2, distance in distances:
    print(f"Distance between {country1} and {country2}: {distance:.2f} km")
# Out:
# Distance between AL and AT: 859.14 km
# Distance between AL and BE: 1587.07 km
# Distance between AL and BG: 463.67 km
# Distance between AL and CH: 1136.12 km
# Distance between AL and CY: 1333.20 km
# Distance between AL and CZ: 1024.98 km
# Distance between AL and DE: 1329.27 km
# Distance between AL and DK: 1803.96 km
# Distance between AL and EE: 1987.06 km
# Distance between AL and EL: 318.49 km
# Distance between AL and ES: 1985.64 km
# Distance between AL and FI: 2598.89 km
# Distance between AL and FR: 1530.84 km
# Distance between AL and HR: 530.00 km
# Distance between AL and HU: 672.94 km
# Distance between AL and IE: 2493.45 km
# Distance between AL and IS: 3595.54 km
# Distance between AL and IT: 656.73 km
# Distance between AL and LI: 1070.59 km
# Distance between AL and LT: 1604.00 km
# Distance between AL and LU: 1448.30 km
# Distance between AL and LV: 1783.17 km
# Distance between AL and ME: 195.29 km
# Distance between AL and MK: 146.07 km
# Distance between AL and MT: 762.02 km
# Distance between AL and NL: 1652.03 km
# Distance between AL and NO: 2585.69 km
# Distance between AL and PL: 1221.24 km
# Distance between AL and PT: 2370.04 km
# Distance between AL and RO: 656.22 km
# Distance between AL and RS: 348.66 km
# Distance between AL and SE: 2379.05 km
# Distance between AL and SI: 696.80 km
# Distance between AL and SK: 843.78 km
# Distance between AL and TR: 1301.30 km
# Distance between AL and UK: 2191.38 km
# Distance between AT and BE: 766.12 km
# Distance between AT and BG: 1021.79 km
# Distance between AT and CH: 454.63 km
# Distance between AT and CY: 2108.27 km
# Distance between AT and CZ: 254.40 km
# Distance between AT and DE: 470.24 km
# Distance between AT and DK: 972.85 km
# Distance between AT and EE: 1443.61 km
# Distance between AT and EL: 1169.09 km
# Distance between AT and ES: 1621.65 km
# Distance between AT and FI: 1988.71 km
# Distance between AT and FR: 888.90 km
# Distance between AT and HR: 329.52 km
# Distance between AT and HU: 399.69 km
# Distance between AT and IE: 1687.88 km
# Distance between AT and IS: 2736.88 km
# Distance between AT and IT: 532.11 km
# Distance between AT and LI: 348.41 km
# Distance between AT and LT: 1093.48 km
# Distance between AT and LU: 636.71 km
# Distance between AT and LV: 1262.90 km
# Distance between AT and ME: 668.75 km
# Distance between AT and MK: 895.88 km
# Distance between AT and MT: 1302.15 km
# Distance between AT and NL: 800.72 km
# Distance between AT and NO: 1820.77 km
# Distance between AT and PL: 629.05 km
# Distance between AT and PT: 1976.63 km
# Distance between AT and RO: 850.23 km
# Distance between AT and RS: 638.53 km
# Distance between AT and SE: 1652.55 km
# Distance between AT and SI: 171.98 km
# Distance between AT and SK: 415.60 km
# Distance between AT and TR: 1933.80 km
# Distance between AT and UK: 1356.67 km
# Distance between BE and BG: 1787.64 km
# Distance between BE and CH: 500.09 km
# Distance between BE and CY: 2872.40 km
# Distance between BE and CZ: 765.27 km
# Distance between BE and DE: 402.80 km
# Distance between BE and DK: 689.43 km
# Distance between BE and EE: 1602.57 km
# Distance between BE and EL: 1905.00 km
# Distance between BE and ES: 1307.69 km
# Distance between BE and FI: 1964.97 km
# Distance between BE and FR: 479.74 km
# Distance between BE and HR: 1070.09 km
# Distance between BE and HU: 1141.25 km
# Distance between BE and IE: 921.77 km
# Distance between BE and IS: 2081.91 km
# Distance between BE and IT: 1040.72 km
# Distance between BE and LI: 528.01 km
# Distance between BE and LT: 1384.30 km
# Distance between BE and LU: 139.93 km
# Distance between BE and LV: 1493.42 km
# Distance between BE and ME: 1409.54 km
# Distance between BE and MK: 1646.65 km
# Distance between BE and MT: 1816.91 km
# Distance between BE and NL: 190.26 km
# Distance between BE and NO: 1544.84 km
# Distance between BE and PL: 1035.30 km
# Distance between BE and PT: 1569.02 km
# Distance between BE and RO: 1590.72 km
# Distance between BE and RS: 1403.87 km
# Distance between BE and SE: 1484.38 km
# Distance between BE and SI: 901.00 km
# Distance between BE and SK: 1084.70 km
# Distance between BE and TR: 2693.92 km
# Distance between BE and UK: 605.17 km
# Distance between BG and CH: 1412.32 km
# Distance between BG and CY: 1100.12 km
# Distance between BG and CZ: 1085.23 km
# Distance between BG and DE: 1452.65 km
# Distance between BG and DK: 1828.60 km
# Distance between BG and EE: 1769.03 km
# Distance between BG and EL: 452.51 km
# Distance between BG and ES: 2398.11 km
# Distance between BG and FI: 2389.31 km
# Distance between BG and FR: 1842.38 km
# Distance between BG and HR: 750.91 km
# Distance between BG and HU: 671.22 km
# Distance between BG and IE: 2709.24 km
# Distance between BG and IS: 3661.74 km
# Distance between BG and IT: 1037.47 km
# Distance between BG and LI: 1323.75 km
# Distance between BG and LT: 1401.83 km
# Distance between BG and LU: 1658.18 km
# Distance between BG and LV: 1568.21 km
# Distance between BG and ME: 488.12 km
# Distance between BG and MK: 317.94 km
# Distance between BG and MT: 1201.42 km
# Distance between BG and NL: 1805.41 km
# Distance between BG and NO: 2496.43 km
# Distance between BG and PL: 1126.84 km
# Distance between BG and PT: 2781.10 km
# Distance between BG and RO: 342.72 km
# Distance between BG and RS: 391.96 km
# Distance between BG and SE: 2262.51 km
# Distance between BG and SI: 906.36 km
# Distance between BG and SK: 798.12 km
# Distance between BG and TR: 925.21 km
# Distance between BG and UK: 2370.38 km
# Distance between CH and CY: 2457.09 km
# Distance between CH and CZ: 619.42 km
# Distance between CH and DE: 497.65 km
# Distance between CH and DK: 1026.66 km
# Distance between CH and EE: 1751.20 km
# Distance between CH and EL: 1453.43 km
# Distance between CH and ES: 1185.89 km
# Distance between CH and FI: 2225.94 km
# Distance between CH and FR: 439.38 km
# Distance between CH and HR: 661.72 km
# Distance between CH and HU: 848.02 km
# Distance between CH and IE: 1363.30 km
# Distance between CH and IS: 2581.88 km
# Distance between CH and IT: 544.32 km
# Distance between CH and LI: 107.42 km
# Distance between CH and LT: 1444.38 km
# Distance between CH and LU: 366.22 km
# Distance between CH and LV: 1595.23 km
# Distance between CH and ME: 976.89 km
# Distance between CH and MK: 1217.81 km
# Distance between CH and MT: 1318.13 km
# Distance between CH and NL: 635.72 km
# Distance between CH and NO: 1921.80 km
# Distance between CH and PL: 1000.37 km
# Distance between CH and PT: 1529.77 km
# Distance between CH and RO: 1289.64 km
# Distance between CH and RS: 1020.58 km
# Distance between CH and SE: 1808.10 km
# Distance between CH and SI: 510.77 km
# Distance between CH and SK: 866.74 km
# Distance between CH and TR: 2337.13 km
# Distance between CH and UK: 1091.93 km
# Distance between CY and CZ: 2185.32 km
# Distance between CY and DE: 2551.20 km
# Distance between CY and DK: 2917.75 km
# Distance between CY and EE: 2685.88 km
# Distance between CY and EL: 1032.67 km
# Distance between CY and ES: 3264.86 km
# Distance between CY and FI: 3280.91 km
# Distance between CY and FR: 2863.10 km
# Distance between CY and HR: 1807.48 km
# Distance between CY and HU: 1771.33 km
# Distance between CY and IE: 3792.91 km
# Distance between CY and IS: 4751.33 km
# Distance between CY and IT: 1987.63 km
# Distance between CY and LI: 2380.93 km
# Distance between CY and LT: 2365.83 km
# Distance between CY and LU: 2738.67 km
# Distance between CY and LV: 2504.13 km
# Distance between CY and ME: 1480.21 km
# Distance between CY and MK: 1239.31 km
# Distance between CY and MT: 1702.03 km
# Distance between CY and NL: 2901.78 km
# Distance between CY and NO: 3513.61 km
# Distance between CY and PL: 2190.03 km
# Distance between CY and PT: 3644.90 km
# Distance between CY and RO: 1385.19 km
# Distance between CY and RS: 1469.87 km
# Distance between CY and SE: 3263.39 km
# Distance between CY and SI: 1974.26 km
# Distance between CY and SK: 1891.86 km
# Distance between CY and TR: 488.98 km
# Distance between CY and UK: 3464.01 km
# Distance between CZ and DE: 380.68 km
# Distance between CZ and DK: 779.40 km
# Distance between CZ and EE: 1191.71 km
# Distance between CZ and EL: 1315.91 km
# Distance between CZ and ES: 1805.15 km
# Distance between CZ and FI: 1734.67 km
# Distance between CZ and FR: 1015.56 km
# Distance between CZ and HR: 523.06 km
# Distance between CZ and HU: 414.01 km
# Distance between CZ and IE: 1663.16 km
# Distance between CZ and IS: 2592.26 km
# Distance between CZ and IT: 785.70 km
# Distance between CZ and LI: 515.63 km
# Distance between CZ and LT: 849.52 km
# Distance between CZ and LU: 663.20 km
# Distance between CZ and LV: 1014.72 km
# Distance between CZ and ME: 829.70 km
# Distance between CZ and MK: 1030.41 km
# Distance between CZ and MT: 1542.05 km
# Distance between CZ and NL: 737.16 km
# Distance between CZ and NO: 1589.46 km
# Distance between CZ and PL: 389.15 km
# Distance between CZ and PT: 2143.69 km
# Distance between CZ and RO: 840.78 km
# Distance between CZ and RS: 740.39 km
# Distance between CZ and SE: 1409.91 km
# Distance between CZ and SI: 403.88 km
# Distance between CZ and SK: 321.46 km
# Distance between CZ and TR: 1955.57 km
# Distance between CZ and UK: 1304.06 km
# Distance between DE and DK: 547.68 km
# Distance between DE and EE: 1284.13 km
# Distance between DE and EL: 1637.66 km
# Distance between DE and ES: 1600.69 km
# Distance between DE and FI: 1731.13 km
# Distance between DE and FR: 762.03 km
# Distance between DE and HR: 799.75 km
# Distance between DE and HU: 785.12 km
# Distance between DE and IE: 1282.81 km
# Distance between DE and IS: 2266.68 km
# Distance between DE and IT: 914.45 km
# Distance between DE and LI: 438.96 km
# Distance between DE and LT: 1018.13 km
# Distance between DE and LU: 334.13 km
# Distance between DE and LV: 1147.79 km
# Distance between DE and ME: 1138.02 km
# Distance between DE and MK: 1360.66 km
# Distance between DE and MT: 1716.37 km
# Distance between DE and NL: 356.81 km
# Distance between DE and NO: 1437.75 km
# Distance between DE and PL: 636.25 km
# Distance between DE and PT: 1903.73 km
# Distance between DE and RO: 1221.09 km
# Distance between DE and RS: 1087.82 km
# Distance between DE and SE: 1312.28 km
# Distance between DE and SI: 637.44 km
# Distance between DE and SK: 701.46 km
# Distance between DE and TR: 2334.99 km
# Distance between DE and UK: 924.20 km
# Distance between DK and EE: 979.07 km
# Distance between DK and EL: 2094.14 km
# Distance between DK and ES: 1996.21 km
# Distance between DK and FI: 1276.89 km
# Distance between DK and FR: 1166.28 km
# Distance between DK and HR: 1290.43 km
# Distance between DK and HU: 1172.49 km
# Distance between DK and IE: 1206.14 km
# Distance between DK and IS: 1833.98 km
# Distance between DK and IT: 1458.40 km
# Distance between DK and LI: 982.44 km
# Distance between DK and LT: 874.85 km
# Distance between DK and LU: 736.14 km
# Distance between DK and LV: 922.71 km
# Distance between DK and ME: 1608.68 km
# Distance between DK and MK: 1807.61 km
# Distance between DK and MT: 2257.76 km
# Distance between DK and NL: 502.95 km
# Distance between DK and NO: 895.16 km
# Distance between DK and PL: 749.73 km
# Distance between DK and PT: 2241.89 km
# Distance between DK and RO: 1534.82 km
# Distance between DK and RS: 1512.98 km
# Distance between DK and SE: 799.68 km
# Distance between DK and SI: 1144.67 km
# Distance between DK and SK: 1030.58 km
# Distance between DK and TR: 2629.45 km
# Distance between DK and UK: 828.12 km
# Distance between EE and EL: 2180.11 km
# Distance between EE and ES: 2882.42 km
# Distance between EE and FI: 620.51 km
# Distance between EE and FR: 2039.55 km
# Distance between EE and HR: 1630.62 km
# Distance between EE and HU: 1342.21 km
# Distance between EE and IE: 2161.55 km
# Distance between EE and IS: 2365.31 km
# Distance between EE and IT: 1965.92 km
# Distance between EE and LI: 1663.56 km
# Distance between EE and LT: 383.38 km
# Distance between EE and LU: 1595.59 km
# Distance between EE and LV: 204.18 km
# Distance between EE and ME: 1819.12 km
# Distance between EE and MK: 1916.53 km
# Distance between EE and MT: 2660.24 km
# Distance between EE and NL: 1439.38 km
# Distance between EE and NO: 917.99 km
# Distance between EE and PL: 824.80 km
# Distance between EE and PT: 3169.18 km
# Distance between EE and RO: 1427.21 km
# Distance between EE and RS: 1638.41 km
# Distance between EE and SE: 655.85 km
# Distance between EE and SI: 1569.00 km
# Distance between EE and SK: 1175.94 km
# Distance between EE and TR: 2274.57 km
# Distance between EE and UK: 1795.16 km
# Distance between EL and ES: 2245.40 km
# Distance between EL and FI: 2799.53 km
# Distance between EL and FR: 1841.41 km
# Distance between EL and HR: 842.40 km
# Distance between EL and HU: 932.84 km
# Distance between EL and IE: 2811.87 km
# Distance between EL and IS: 3900.77 km
# Distance between EL and IT: 958.29 km
# Distance between EL and LI: 1389.03 km
# Distance between EL and LT: 1802.73 km
# Distance between EL and LU: 1766.41 km
# Distance between EL and LV: 1976.54 km
# Distance between EL and ME: 500.53 km
# Distance between EL and MK: 287.68 km
# Distance between EL and MT: 818.69 km
# Distance between EL and NL: 1966.33 km
# Distance between EL and NO: 2842.74 km
# Distance between EL and PL: 1464.52 km
# Distance between EL and PT: 2628.29 km
# Distance between EL and RO: 766.33 km
# Distance between EL and RS: 587.51 km
# Distance between EL and SE: 2624.09 km
# Distance between EL and SI: 1011.02 km
# Distance between EL and SK: 1095.78 km
# Distance between EL and TR: 1070.10 km
# Distance between EL and UK: 2508.91 km
# Distance between ES and FI: 3272.60 km
# Distance between ES and FR: 843.75 km
# Distance between ES and HR: 1709.52 km
# Distance between ES and HU: 1983.00 km
# Distance between ES and IE: 1464.46 km
# Distance between ES and IS: 2900.00 km
# Distance between ES and IT: 1361.78 km
# Distance between ES and LI: 1291.18 km
# Distance between ES and LT: 2610.55 km
# Distance between ES and LU: 1289.44 km
# Distance between ES and LV: 2747.80 km
# Distance between ES and ME: 1910.10 km
# Distance between ES and MK: 2117.12 km
# Distance between ES and MT: 1646.64 km
# Distance between ES and NL: 1493.43 km
# Distance between ES and NO: 2815.61 km
# Distance between ES and PL: 2181.62 km
# Distance between ES and PT: 384.40 km
# Distance between ES and RO: 2381.96 km
# Distance between ES and RS: 2041.47 km
# Distance between ES and SE: 2784.18 km
# Distance between ES and SI: 1615.38 km
# Distance between ES and SK: 2036.50 km
# Distance between ES and TR: 3286.89 km
# Distance between ES and UK: 1505.04 km
# Distance between FI and FR: 2437.45 km
# Distance between FI and HR: 2212.91 km
# Distance between FI and HU: 1942.27 km
# Distance between FI and IE: 2290.31 km
# Distance between FI and IS: 2089.30 km
# Distance between FI and IT: 2520.36 km
# Distance between FI and LI: 2152.82 km
# Distance between FI and LT: 997.72 km
# Distance between FI and LU: 1996.77 km
# Distance between FI and LV: 823.18 km
# Distance between FI and ME: 2425.77 km
# Distance between FI and MK: 2533.40 km
# Distance between FI and MT: 3249.77 km
# Distance between FI and NL: 1779.80 km
# Distance between FI and NO: 674.86 km
# Distance between FI and PL: 1403.45 km
# Distance between FI and PT: 3514.02 km
# Distance between FI and RO: 2047.67 km
# Distance between FI and RS: 2250.83 km
# Distance between FI and SE: 533.18 km
# Distance between FI and SI: 2131.34 km
# Distance between FI and SK: 1772.30 km
# Distance between FI and TR: 2850.62 km
# Distance between FI and UK: 1973.54 km
# Distance between FR and HR: 1092.30 km
# Distance between FR and HU: 1285.95 km
# Distance between FR and IE: 1054.40 km
# Distance between FR and IS: 2406.88 km
# Distance between FR and IT: 887.33 km
# Distance between FR and LI: 541.70 km
# Distance between FR and LT: 1778.84 km
# Distance between FR and LU: 445.80 km
# Distance between FR and LV: 1909.46 km
# Distance between FR and ME: 1389.00 km
# Distance between FR and MK: 1627.57 km
# Distance between FR and MT: 1549.53 km
# Distance between FR and NL: 669.95 km
# Distance between FR and NO: 2022.17 km
# Distance between FR and PL: 1369.32 km
# Distance between FR and PT: 1143.46 km
# Distance between FR and RO: 1729.02 km
# Distance between FR and RS: 1452.22 km
# Distance between FR and SE: 1963.54 km
# Distance between FR and SI: 948.29 km
# Distance between FR and SK: 1293.00 km
# Distance between FR and TR: 2767.47 km
# Distance between FR and UK: 885.06 km
# Distance between HR and HU: 324.90 km
# Distance between HR and IE: 1987.09 km
# Distance between HR and IS: 3066.40 km
# Distance between HR and IT: 394.51 km
# Distance between HR and LI: 576.45 km
# Distance between HR and LT: 1255.60 km
# Distance between HR and LU: 933.79 km
# Distance between HR and LV: 1434.97 km
# Distance between HR and ME: 342.18 km
# Distance between HR and MK: 576.63 km
# Distance between HR and MT: 1037.49 km
# Distance between HR and NL: 1123.96 km
# Distance between HR and NO: 2111.59 km
# Distance between HR and PL: 810.40 km
# Distance between HR and PT: 2084.66 km
# Distance between HR and RO: 672.47 km
# Distance between HR and RS: 359.93 km
# Distance between HR and SE: 1925.40 km
# Distance between HR and SI: 169.52 km
# Distance between HR and SK: 464.05 km
# Distance between HR and TR: 1676.06 km
# Distance between HR and UK: 1670.73 km
# Distance between HU and IE: 2057.16 km
# Distance between HU and IS: 2999.33 km
# Distance between HU and IT: 716.42 km
# Distance between HU and LI: 744.25 km
# Distance between HU and LT: 960.60 km
# Distance between HU and LU: 1020.81 km
# Distance between HU and LV: 1141.48 km
# Distance between HU and ME: 487.70 km
# Distance between HU and MK: 645.40 km
# Distance between HU and MT: 1320.10 km
# Distance between HU and NL: 1140.65 km
# Distance between HU and NO: 1915.37 km
# Distance between HU and PL: 549.43 km
# Distance between HU and PT: 2348.85 km
# Distance between HU and RO: 452.75 km
# Distance between HU and RS: 345.39 km
# Distance between HU and SE: 1706.14 km
# Distance between HU and SI: 368.12 km
# Distance between HU and SK: 171.76 km
# Distance between HU and TR: 1554.30 km
# Distance between HU and UK: 1707.79 km
# Distance between IE and IS: 1437.78 km
# Distance between IE and IT: 1897.55 km
# Distance between IE and LI: 1422.86 km
# Distance between IE and LT: 2078.00 km
# Distance between IE and LU: 1054.24 km
# Distance between IE and LV: 2126.85 km
# Distance between IE and ME: 2322.82 km
# Distance between IE and MK: 2562.12 km
# Distance between IE and MT: 2603.52 km
# Distance between IE and NL: 928.83 km
# Distance between IE and NO: 1669.51 km
# Distance between IE and PL: 1852.80 km
# Distance between IE and PT: 1502.92 km
# Distance between IE and RO: 2501.65 km
# Distance between IE and RS: 2325.42 km
# Distance between IE and SE: 1757.45 km
# Distance between IE and SI: 1819.12 km
# Distance between IE and SK: 1984.26 km
# Distance between IE and TR: 3611.46 km
# Distance between IE and UK: 383.31 km
# Distance between IS and IT: 3118.14 km
# Distance between IS and LI: 2598.97 km
# Distance between IS and LT: 2521.12 km
# Distance between IS and LU: 2216.85 km
# Distance between IS and LV: 2458.42 km
# Distance between IS and ME: 3403.15 km
# Distance between IS and MK: 3619.06 km
# Distance between IS and MT: 3898.14 km
# Distance between IS and NL: 1965.63 km
# Distance between IS and NO: 1467.40 km
# Distance between IS and PL: 2568.52 km
# Distance between IS and PT: 2897.87 km
# Distance between IS and RO: 3367.04 km
# Distance between IS and RS: 3332.63 km
# Distance between IS and SE: 1717.23 km
# Distance between IS and SI: 2903.22 km
# Distance between IS and SK: 2863.67 km
# Distance between IS and TR: 4446.52 km
# Distance between IS and UK: 1523.45 km
# Distance between IT and LI: 519.65 km
# Distance between IT and LT: 1603.73 km
# Distance between IT and LU: 902.94 km
# Distance between IT and LV: 1778.68 km
# Distance between IT and ME: 550.74 km
# Distance between IT and MK: 771.85 km
# Distance between IT and MT: 802.59 km
# Distance between IT and NL: 1155.93 km
# Distance between IT and NO: 2333.83 km
# Distance between IT and PL: 1142.41 km
# Distance between IT and PT: 1744.04 km
# Distance between IT and RO: 1042.04 km
# Distance between IT and RS: 684.24 km
# Distance between IT and SE: 2177.72 km
# Distance between IT and SI: 398.13 km
# Distance between IT and SK: 837.67 km
# Distance between IT and TR: 1941.66 km
# Distance between IT and UK: 1636.25 km
# Distance between LI and LT: 1348.59 km
# Distance between LI and LU: 388.30 km
# Distance between LI and LV: 1502.89 km
# Distance between LI and ME: 902.78 km
# Distance between LI and MK: 1143.39 km
# Distance between LI and MT: 1314.29 km
# Distance between LI and NL: 636.52 km
# Distance between LI and NO: 1875.68 km
# Distance between LI and PL: 899.74 km
# Distance between LI and PT: 1636.87 km
# Distance between LI and RO: 1188.93 km
# Distance between LI and RS: 931.87 km
# Distance between LI and SE: 1749.83 km
# Distance between LI and SI: 417.82 km
# Distance between LI and SK: 759.44 km
# Distance between LI and TR: 2247.11 km
# Distance between LI and UK: 1131.48 km
# Distance between LT and LU: 1348.58 km
# Distance between LT and LV: 180.90 km
# Distance between LT and ME: 1435.79 km
# Distance between LT and MK: 1535.72 km
# Distance between LT and MT: 2280.12 km
# Distance between LT and NL: 1247.94 km
# Distance between LT and NO: 1155.69 km
# Distance between LT and PL: 464.53 km
# Distance between LT and PT: 2921.66 km
# Distance between LT and RO: 1059.12 km
# Distance between LT and RS: 1255.41 km
# Distance between LT and SE: 899.68 km
# Distance between LT and SI: 1205.60 km
# Distance between LT and SK: 796.37 km
# Distance between LT and TR: 1983.59 km
# Distance between LT and UK: 1696.66 km
# Distance between LU and LV: 1471.17 km
# Distance between LU and ME: 1272.05 km
# Distance between LU and MK: 1509.95 km
# Distance between LU and MT: 1684.33 km
# Distance between LU and NL: 278.07 km
# Distance between LU and NO: 1616.97 km
# Distance between LU and PL: 967.57 km
# Distance between LU and PT: 1577.28 km
# Distance between LU and RO: 1472.66 km
# Distance between LU and RS: 1271.97 km
# Distance between LU and SE: 1535.69 km
# Distance between LU and SI: 765.23 km
# Distance between LU and SK: 976.85 km
# Distance between LU and TR: 2569.31 km
# Distance between LU and UK: 744.89 km
# Distance between LV and ME: 1616.17 km
# Distance between LV and MK: 1712.38 km
# Distance between LV and MT: 2460.87 km
# Distance between LV and NL: 1343.29 km
# Distance between LV and NO: 1047.31 km
# Distance between LV and PL: 636.53 km
# Distance between LV and PT: 3048.40 km
# Distance between LV and RO: 1225.89 km
# Distance between LV and RS: 1434.51 km
# Distance between LV and SE: 784.91 km
# Distance between LV and SI: 1380.72 km
# Distance between LV and SK: 976.88 km
# Distance between LV and TR: 2105.00 km
# Distance between LV and UK: 1750.72 km
# Distance between ME and MK: 240.97 km
# Distance between ME and MT: 871.41 km
# Distance between ME and NL: 1466.07 km
# Distance between ME and NO: 2394.42 km
# Distance between ME and PL: 1037.08 km
# Distance between ME and PT: 2293.29 km
# Distance between ME and RO: 568.75 km
# Distance between ME and RS: 203.58 km
# Distance between ME and SE: 2191.07 km
# Distance between ME and SI: 511.33 km
# Distance between ME and SK: 659.46 km
# Distance between ME and TR: 1394.03 km
# Distance between ME and UK: 2011.78 km
# Distance between MK and MT: 894.81 km
# Distance between MK and NL: 1696.39 km
# Distance between MK and NO: 2557.48 km
# Distance between MK and PL: 1181.00 km
# Distance between MK and PT: 2501.42 km
# Distance between MK and RO: 539.76 km
# Distance between MK and RS: 300.34 km
# Distance between MK and SE: 2341.53 km
# Distance between MK and SI: 746.01 km
# Distance between MK and SK: 809.59 km
# Distance between MK and TR: 1171.85 km
# Distance between MK and UK: 2247.07 km
# Distance between MT and NL: 1948.81 km
# Distance between MT and NO: 3122.57 km
# Distance between MT and PL: 1846.41 km
# Distance between MT and PT: 2007.20 km
# Distance between MT and RO: 1416.10 km
# Distance between MT and RS: 1073.51 km
# Distance between MT and SE: 2951.81 km
# Distance between MT and SI: 1138.72 km
# Distance between MT and SK: 1484.32 km
# Distance between MT and TR: 1861.55 km
# Distance between MT and UK: 2390.25 km
# Distance between NL and NO: 1355.41 km
# Distance between NL and PL: 942.80 km
# Distance between NL and PT: 1743.57 km
# Distance between NL and RO: 1577.83 km
# Distance between NL and RS: 1433.88 km
# Distance between NL and SE: 1294.89 km
# Distance between NL and SI: 955.49 km
# Distance between NL and SK: 1057.06 km
# Distance between NL and TR: 2691.77 km
# Distance between NL and UK: 567.47 km
# Distance between NO and PL: 1379.48 km
# Distance between NO and PT: 3007.42 km
# Distance between NO and RO: 2162.08 km
# Distance between NO and RS: 2257.62 km
# Distance between NO and SE: 263.45 km
# Distance between NO and SI: 1987.22 km
# Distance between NO and SK: 1748.08 km
# Distance between NO and TR: 3139.27 km
# Distance between NO and UK: 1394.50 km
# Distance between PL and PT: 2509.67 km
# Distance between PL and RO: 806.63 km
# Distance between PL and RS: 882.91 km
# Distance between PL and SE: 1160.66 km
# Distance between PL and SI: 744.74 km
# Distance between PL and SK: 377.78 km
# Distance between PL and TR: 1881.85 km
# Distance between PL and UK: 1472.89 km
# Distance between PT and RO: 2756.87 km
# Distance between PT and RS: 2421.33 km
# Distance between PT and SE: 3006.37 km
# Distance between PT and SI: 1983.01 km
# Distance between PT and SK: 2392.19 km
# Distance between PT and TR: 3671.29 km
# Distance between PT and UK: 1636.02 km
# Distance between RO and RS: 374.14 km
# Distance between RO and SE: 1924.56 km
# Distance between RO and SI: 785.86 km
# Distance between RO and SK: 524.54 km
# Distance between RO and TR: 1115.70 km
# Distance between RO and UK: 2144.84 km
# Distance between RS and SE: 2043.51 km
# Distance between RS and SI: 514.78 km
# Distance between RS and SK: 509.54 km
# Distance between RS and TR: 1316.56 km
# Distance between RS and UK: 1994.31 km
# Distance between SE and SI: 1813.13 km
# Distance between SE and SK: 1535.96 km
# Distance between SE and TR: 2881.99 km
# Distance between SE and UK: 1442.29 km
# Distance between SI and SK: 453.07 km
# Distance between SI and TR: 1829.29 km
# Distance between SI and UK: 1501.22 km
# Distance between SK and TR: 1640.12 km
# Distance between SK and UK: 1622.84 km
# Distance between TR and UK: 3259.18 km

# %%
# Filter the GeoDataFrame to get only France
france_gdf = merged_gdf[merged_gdf['NUTS_ID'] == 'FR']

# Plot the shape of France
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
france_gdf.plot(ax=ax, color='lightblue', edgecolor='black')
ax.set_title("Shape of France", fontsize=16)
plt.show()

# %%
# Filter the GeoDataFrame to get only France
france_gdf = merged_gdf[merged_gdf['NUTS_ID'] == 'FR']

# Ensure the GeoDataFrame is in EPSG:4326 (WGS84)
france_gdf = france_gdf.to_crs(epsg=4326)

# Calculate the centroid of France
france_centroid = france_gdf.geometry.centroid.iloc[0]

# Plot the shape of France and its centroid
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
france_gdf.plot(ax=ax, color='lightblue', edgecolor='black')
ax.scatter(france_centroid.x, france_centroid.y, color='red', marker='o', s=100, label='Centroid')
ax.set_title("Shape of France with Centroid", fontsize=16)
ax.legend()
plt.show()
# Out:
# C:\Users\jfg.eco\AppData\Local\Temp\ipykernel_9508\2419535010.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   france_centroid = france_gdf.geometry.centroid.iloc[0]

# %%
# Plot the merged_gdf GeoDataFrame
merged_gdf.plot(color='lightblue', edgecolor='black')
# Out:
# <Axes: >
