# %% [markdown]
# # Model to transform infrastructure
#
# - enables to transform the methane into a hydrogen network
# - allows for new investments on defined edges
# - bidirectional net flows on edges possible

# %% [markdown]
# ### Import packages

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd
import networkx as nx
import os
from collections import Counter

# %% [markdown]
# ### Model run definitions

# %%
#use shortage nodes to avoid infeasibilities
model_with_shortage = False #True or False

# %% [markdown]
# ### Import data

# %%
# Specify the path to your Excel file
input_file_path = os.path.join('..', '..','01_data', '01_input_data', '02_processed')
excel_file_path = '\Data_full_network.xlsx'  

input_file_path  = input_file_path + excel_file_path
full_input_path = os.path.abspath(os.path.join(os.getcwd(), input_file_path))

# Read the Excel file into a DataFrame
df_nodes = pd.read_excel(full_input_path, sheet_name='Nodes')
df_commodities = pd.read_excel(full_input_path, sheet_name='Commodities')
df_edges = pd.read_excel(full_input_path, sheet_name='Edges')
df_parameter = pd.read_excel(full_input_path, sheet_name='Parameters')
df_supply_values = pd.read_excel(full_input_path, sheet_name='Supply')

# %% [markdown]
# ### Create input data structure

# %%
#commodities
commodities = df_commodities['Commodities'].tolist()

#nodes
nodes = df_nodes['Nodes'].tolist()

#edges
edges_base = list(zip(df_edges['Source'], df_edges['Destination']))

#initial capacities
capacity_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['initial_capacities'] 
                 for _, row in df_parameter.iterrows()}

#maximal capacities
capacity_limit_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['max_capacities'] 
                 for _, row in df_parameter.iterrows()}

#variable transportation cost
cost_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['costs_edge'] 
                 for _, row in df_parameter.iterrows()}

#investment cost new capacity
investment_cost_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['new_build_cost'] 
                 for _, row in df_parameter.iterrows()}

#investment cost convert capacity
conversion_cost_base = {tuple(row[['Commodity', 'Source', 'Destination']]): row['conversion_cost'] 
                 for _, row in df_parameter.iterrows()}

#converseion capacity factor
conversion_capacity_factor = {tuple(row[['Commodity', 'Source', 'Destination']]): row['conversion_capacity_factor'] 
                 for _, row in df_parameter.iterrows()}

#demand and supply
inflow = {tuple(row[['Commodity', 'Node']]): row['Supply'] 
                 for _, row in df_supply_values.iterrows()}

# %% [markdown]
# ### adjust input data

# %%
#create node types for different model configurations
if model_with_shortage == True:
    #create shortage nodes
    supply_nodes = []
    for (commodity, node), value in inflow.items():
        if value > 0:
            supply_nodes.append(node)
    unique_supply_nodes = list(set(supply_nodes))
    # Add '_shortage' to each element in the list
    unique_supply_nodes_shortage = [node + '_shortage' for node in unique_supply_nodes]
    nodes_shortage = unique_supply_nodes_shortage
    #create new edges for all shortage nodes to the actual node with high-capacity
    # Create a new list by zipping the two lists
    edges_shortage = list(zip(unique_supply_nodes_shortage, unique_supply_nodes))
    # Create a new data structure using the result_list and commodities
    edge_shortage_cap = {}

    for (commodity, suffix, original) in [(c, s, o) for c in commodities for s, o in zip(unique_supply_nodes_shortage, unique_supply_nodes)]:
        edge_shortage_cap[(commodity, suffix, original)] = 10000000

    nodes_network = nodes #+ nodes_shortage
else:
    nodes_network = nodes

# %%
# Reverse edges
edges_reverse = [(destination, source) for source, destination in edges_base]

# Combined edges
edges = edges_base + edges_reverse

# Reverse cap
capacity_reverse = {(k, j, i): cap for (k, i, j), cap in capacity_base.items()}

capacity = {**capacity_base, **capacity_reverse}

# Reverse cap
capacity_limit_reverse = {(k, j, i): cap for (k, i, j), cap in capacity_limit_base.items()}

capacity_limit = {**capacity_limit_base, **capacity_limit_reverse}

# Reverse cost
cost_reverse = {(k, j, i): cost for (k, i, j), cost in cost_base.items()}

cost = {**cost_base, **cost_reverse}

# Reverse cost
investment_cost_reverse = {(k, j, i): cost for (k, i, j), cost in investment_cost_base.items()}

investment_cost = {**investment_cost_base, **investment_cost_reverse}

# Reverse cost
conversion_cost_reverse = {(k, j, i): cost for (k, i, j), cost in conversion_cost_base.items()}

conversion_cost = {**conversion_cost_base, **conversion_cost_reverse}

# %% [markdown]
# ### Network control

# %%
#check in all nodes are connected via edges

G = nx.Graph()
G.add_edges_from(edges_base)

# Check if the graph is connected
if nx.is_connected(G):
    print("The graph is connected.")
else:
    print("The graph is not connected.")
# Out:
# The graph is connected.

# %%
# Check if all nodes are connected
if set(nodes) in nx.connected_components(G):
    print("All nodes are connected.")
else:
    print("Not all nodes are connected.")
# Out:
# All nodes are connected.

# %%
if len(edges) != len(set(edges)):
    print("There are duplicates in the list of tuples.")

    # Count occurrences of each edge
    edge_count = Counter(edges)

    # Find duplicates
    duplicates = [edge for edge, count in edge_count.items() if count > 1]
    #print duplicated edges if they exist
    for dup in duplicates:
        print(dup)
else:
    print("No duplicates found in the list of tuples.")
# Out:
# No duplicates found in the list of tuples.

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create model

# %%
# Create optimization model
m = gp.Model("Grid_Transformation")

# %% [markdown]
# ### Define variables

# %%
# Create variables
if model_with_shortage == True: 
    flow = m.addVars(commodities, edges+edges_shortage, vtype=GRB.CONTINUOUS, name="flow")
else:
    flow = m.addVars(commodities, edges, vtype=GRB.CONTINUOUS, name="flow")
# variable for capacity investment
investment = m.addVars(commodities, edges, vtype=GRB.CONTINUOUS, name="investment")
# Variable for converted capacity
converted_capacity = m.addVars(commodities, edges, vtype=GRB.CONTINUOUS, name="converted_capacity")
# Binary variable to indicate if conversion is active
conversion_indicator = m.addVars(commodities, edges, vtype=GRB.BINARY, name="conversion_indicator")

# %% [markdown]
# ### Define objective

# %%
# Set objective function
m.setObjective(
    gp.quicksum(flow[h, i, j] * cost[h, i, j] for h in commodities for i, j in edges) +
    gp.quicksum(investment[h, i, j] * investment_cost[h, i, j] for h in commodities for i, j in edges_base) +
    gp.quicksum(converted_capacity[h, i, j] * conversion_cost[h, j, i] for h in commodities for i, j in edges_base),
    GRB.MINIMIZE
)

# %% [markdown]
# ### Define constraints

# %%
# Edge-capacity constraints with investment
m.addConstrs((flow[h, i, j] <= converted_capacity[h, i, j] + investment[h, i, j] for h in commodities for i, j in edges), "cap")

# Edge-capacity total limit
m.addConstrs((investment[h, i, j] + converted_capacity[h, i, j] 
              <= capacity_limit[h, i, j] for h in commodities for i, j in edges_base), "cap")

# Investment constraints
m.addConstrs((investment[h, i, j] == investment[h, j, i] for h in commodities for i, j in edges), "conversion")

#conversion binary constraint
m.addConstrs((gp.quicksum(conversion_indicator[h, i, j] for h in commodities) == 1 for i, j in edges), "conversion_indicator_sum_one")

#link the converted capacity to the initial capacity
m.addConstrs((capacity[commodities[0], i, j] * conversion_indicator[h, i, j] 
              == converted_capacity[h, i, j] for h in commodities[1:] for i, j in edges), "capacity_relationship")
m.addConstrs((capacity[commodities[0], i, j] * conversion_indicator[commodities[0], i, j]
        == converted_capacity[commodities[0], i, j]
        for i, j in edges), "capacity_relationship_first_commodity")

# Conversion constraints
m.addConstrs((converted_capacity[h, i, j] == converted_capacity[h, j, i] for h in commodities for i, j in edges), "conversion")

# balanced node flows: Kirchhoff's 1st law
m.addConstrs(
    (
        flow.sum(h, "*", j) + inflow[h, j] == flow.sum(h, j, "*")
        for h in commodities
        for j in nodes_network
    ),
    "node",
)

# Flow-conservation constraints
if model_with_shortage == True: 
    m.addConstrs(
        (
            flow.sum(h, "*", j) - flow.sum(h, j, "*") <= 0
            for h in commodities
            for j in nodes_shortage
        ),
        "node",
    )

    # Edge-capacity constraints between shortage nodes and network nodes
    m.addConstrs((flow[h, i, j] <= edge_shortage_cap[h, i, j] for h in commodities for i, j in edges_shortage), "cap")

print('Constraints createt')
# Out:
# Constraints createt

# %% [markdown]
# ### Optimize the model

# %%
# Compute optimal solution
m.optimize()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i5-8265U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28516 rows, 21264 columns and 69108 nonzeros
# Model fingerprint: 0x79e0b6fc
# Variable types: 15948 continuous, 5316 integer (5316 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [5e-01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 24971 rows and 16807 columns
# Presolve time: 0.10s
# Presolved: 3545 rows, 4457 columns, 13248 nonzeros
# Variable types: 3821 continuous, 636 integer (636 binary)
# Found heuristic solution: objective 1090.0000000
#
# Root relaxation: objective 3.225000e+02, 349 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  322.50000    0   10 1090.00000  322.50000  70.4%     -    0s
# H    0     0                    1078.1072775  322.50000  70.1%     -    0s
# H    0     0                    1048.7970595  322.50000  69.3%     -    0s
# H    0     0                     977.3320017  394.12243  59.7%     -    0s
#      0     0  394.12243    0   24  977.33200  394.12243  59.7%     -    0s
# H    0     0                     929.5736976  401.46531  56.8%     -    0s
# H    0     0                     542.1309759  401.46531  25.9%     -    0s
# H    0     0                     510.1640600  401.46531  21.3%     -    0s
#      0     0  414.83200    0   12  510.16406  414.83200  18.7%     -    0s
#      0     0  443.52986    0   13  510.16406  443.52986  13.1%     -    0s
#      0     0  456.72194    0   18  510.16406  456.72194  10.5%     -    0s
#      0     0  458.71157    0   23  510.16406  458.71157  10.1%     -    0s
#      0     0  475.46108    0   18  510.16406  475.46108  6.80%     -    0s
#      0     0  475.46108    0   24  510.16406  475.46108  6.80%     -    0s
#      0     0  492.85024    0   23  510.16406  492.85024  3.39%     -    0s
# H    0     0                     505.7515768  492.85024  2.55%     -    0s
#      0     0  505.75158    0   27  505.75158  505.75158  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 46
#   RLT: 8
#   Relax-and-lift: 2
#
# Explored 1 nodes (938 simplex iterations) in 0.63 seconds (0.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 505.752 510.164 542.131 ... 1090
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.057515768369e+02, best bound 5.057515768369e+02, gap 0.0000%

# %% [markdown]
# ## Outputs

# %%
if m.Status == GRB.OPTIMAL:
    solution = m.getAttr("X", flow)
    investment_solution = m.getAttr("X", investment)
    converted_capacity_solution = m.getAttr("X", converted_capacity)
    conversion_indicator_solution = m.getAttr("X", conversion_indicator)

    print("****************************")
    print(f"Total cost: {m.objVal}")
    print("****************************")
    
    for h in commodities:
        print(f"\nOptimal flows for {h}:")
        for i, j in edges:
            if solution[h, i, j] > 0:
                print(f"{i} -> {j}: {solution[h, i, j]:g}")

        if model_with_shortage == True:
            for i, j in edges_shortage:
                if solution[h, i, j] > 0:
                    print(f"{i} -> {j}: {solution[h, i, j]:g}")

        print(f"\nOptimal investments for {h}:")
        for i, j in edges_base:
            if investment_solution[h, i, j] > 0:
                print(f"Investment for {h} in edge ({i} -> {j}): {investment_solution[h, i, j]:g}")

        print(f"\nOptimal converted capacities for {h}:")
        for i, j in edges_base:
            if converted_capacity_solution[h, i, j] > 0:
                print(f"Converted capacity for {h} from {i} to {j}: {converted_capacity_solution[h, i, j]:g}")

    print("\nOptimal conversion indicators:")
    for h in commodities:
        for i, j in edges_base:
            #
                print(f"Conversion of {h} from {i} to {j} is: {conversion_indicator_solution[h, i, j]:g}")
else:
    print("No optimal solution found.")
# Out:
# ****************************
# Total cost: 505.7515768369208
# ****************************
#
# Optimal flows for Methane:
# node_0009 -> node_0011: 5
# node_0011 -> node_0096: 5
# node_0043 -> node_0069: 5
# node_0068 -> node_0070: 5
# node_0070 -> node_0071: 5
# node_0071 -> node_0072: 5
# node_0072 -> node_0451: 5
# node_0088 -> node_0043: 5
# node_0069 -> node_0068: 5
# node_0095 -> node_0088: 5
# node_0096 -> node_0095: 5
#
# Optimal flows for Hydrogen:
# node_0078 -> node_0079: 5
# node_0079 -> node_0240: 5
# node_0234 -> node_0314_2: 5
# node_0238 -> node_0242: 5
# node_0240 -> node_0241: 5
# node_0080 -> node_0078: 5
# node_0081 -> node_0080: 5
# node_0082 -> node_0081: 5
# node_0083 -> node_0082: 5
# node_0084 -> node_0083: 5
# node_0085 -> node_0084: 5
# node_0086 -> node_0085: 5
# node_0091 -> node_0086: 5
# node_0092 -> node_0091: 5
# node_0093 -> node_0092: 5
# node_0242 -> node_0234: 5
# node_0241 -> node_0238: 5
#
# Optimal conversion indicators:
# Conversion of Methane from node_0001 to node_0002_2 is: 1
# Conversion of Methane from node_0001 to node_0002_1 is: 1
# Conversion of Methane from node_0002 to node_0362 is: 1
# Conversion of Methane from node_0003 to node_0004 is: 1
# Conversion of Methane from node_0003 to node_0196 is: 1
# Conversion of Methane from node_0003 to node_0383 is: 1
# Conversion of Methane from node_0003 to node_0381 is: 1
# Conversion of Methane from node_0003 to node_0006_2 is: 1
# Conversion of Methane from node_0003 to node_0382 is: 1
# Conversion of Methane from node_0003 to node_0006_1 is: 1
# Conversion of Methane from node_0004 to node_0005 is: 1
# Conversion of Methane from node_0005 to node_0006 is: 1
# Conversion of Methane from node_0006 to node_0007 is: 1
# Conversion of Methane from node_0006 to node_0200 is: 1
# Conversion of Methane from node_0006 to node_0384_1 is: 1
# Conversion of Methane from node_0006 to node_0384_2 is: 1
# Conversion of Methane from node_0006 to node_0195 is: 1
# Conversion of Methane from node_0006 to node_0385 is: 1
# Conversion of Methane from node_0006 to node_0008 is: 1
# Conversion of Methane from node_0007 to node_0013 is: 1
# Conversion of Methane from node_0007 to node_0389 is: 1
# Conversion of Methane from node_0007 to node_0386 is: 1
# Conversion of Methane from node_0007 to node_0384_4 is: 1
# Conversion of Methane from node_0007 to node_0384_3 is: 1
# Conversion of Methane from node_0007 to node_0009_4 is: 1
# Conversion of Methane from node_0007 to node_0010 is: 1
# Conversion of Methane from node_0007 to node_0387 is: 1
# Conversion of Methane from node_0007 to node_0009_3 is: 1
# Conversion of Methane from node_0007 to node_0009_2 is: 1
# Conversion of Methane from node_0007 to node_0009_1 is: 1
# Conversion of Methane from node_0007 to node_0388 is: 1
# Conversion of Methane from node_0008 to node_0195_2 is: 1
# Conversion of Methane from node_0008 to node_0019 is: 1
# Conversion of Methane from node_0008 to node_0018_2 is: 1
# Conversion of Methane from node_0008 to node_0018_1 is: 1
# Conversion of Methane from node_0008 to node_0195_1 is: 1
# Conversion of Methane from node_0008 to node_0194 is: 1
# Conversion of Methane from node_0008 to node_0195_3 is: 1
# Conversion of Methane from node_0008 to node_0013_2 is: 1
# Conversion of Methane from node_0008 to node_0015_1 is: 1
# Conversion of Methane from node_0008 to node_0014 is: 1
# Conversion of Methane from node_0008 to node_0015_2 is: 1
# Conversion of Methane from node_0008 to node_0013_1 is: 1
# Conversion of Methane from node_0009 to node_0010 is: 1
# Conversion of Methane from node_0009 to node_0011 is: 1
# Conversion of Methane from node_0009 to node_0097_2 is: 1
# Conversion of Methane from node_0009 to node_0012 is: 1
# Conversion of Methane from node_0009 to node_0097_1 is: 1
# Conversion of Methane from node_0009 to node_0391_2 is: 1
# Conversion of Methane from node_0009 to node_0013 is: 1
# Conversion of Methane from node_0009 to node_0391_1 is: 1
# Conversion of Methane from node_0009 to node_0390 is: 1
# Conversion of Methane from node_0010 to node_0097 is: 1
# Conversion of Methane from node_0010 to node_0392 is: 1
# Conversion of Methane from node_0011 to node_0097 is: 1
# Conversion of Methane from node_0011 to node_0098 is: 1
# Conversion of Methane from node_0011 to node_0395_1 is: 1
# Conversion of Methane from node_0011 to node_0395_2 is: 1
# Conversion of Methane from node_0011 to node_0396 is: 1
# Conversion of Methane from node_0011 to node_0393_1 is: 1
# Conversion of Methane from node_0011 to node_0394 is: 1
# Conversion of Methane from node_0011 to node_0096 is: 1
# Conversion of Methane from node_0011 to node_0393_2 is: 1
# Conversion of Methane from node_0011 to node_0012_2 is: 1
# Conversion of Methane from node_0011 to node_0012_1 is: 1
# Conversion of Methane from node_0011 to node_0021_3 is: 1
# Conversion of Methane from node_0011 to node_0022 is: 1
# Conversion of Methane from node_0011 to node_0021_2 is: 1
# Conversion of Methane from node_0011 to node_0021_1 is: 1
# Conversion of Methane from node_0012 to node_0367 is: 1
# Conversion of Methane from node_0012 to node_0018 is: 1
# Conversion of Methane from node_0012 to node_0020 is: 1
# Conversion of Methane from node_0012 to node_0021 is: 1
# Conversion of Methane from node_0012 to node_0019 is: 1
# Conversion of Methane from node_0012 to node_0097 is: 1
# Conversion of Methane from node_0013 to node_0384 is: 1
# Conversion of Methane from node_0013 to node_0397 is: 1
# Conversion of Methane from node_0013 to node_0398 is: 1
# Conversion of Methane from node_0014 to node_0015 is: 1
# Conversion of Methane from node_0014 to node_0017 is: 1
# Conversion of Methane from node_0014 to node_0399 is: 1
# Conversion of Methane from node_0014 to node_0016 is: 1
# Conversion of Methane from node_0015 to node_0400 is: 1
# Conversion of Methane from node_0015 to node_0019 is: 1
# Conversion of Methane from node_0015 to node_0016 is: 1
# Conversion of Methane from node_0016 to node_0193 is: 1
# Conversion of Methane from node_0016 to node_0401 is: 1
# Conversion of Methane from node_0016 to node_0192 is: 1
# Conversion of Methane from node_0016 to node_0031 is: 1
# Conversion of Methane from node_0016 to node_0034_1 is: 1
# Conversion of Methane from node_0016 to node_0034_2 is: 1
# Conversion of Methane from node_0017 to node_0032 is: 1
# Conversion of Methane from node_0017 to node_0403 is: 1
# Conversion of Methane from node_0017 to node_0205 is: 1
# Conversion of Methane from node_0017 to node_0402 is: 1
# Conversion of Methane from node_0017 to node_0404 is: 1
# Conversion of Methane from node_0018 to node_0405 is: 1
# Conversion of Methane from node_0018 to node_0197 is: 1
# Conversion of Methane from node_0018 to node_0020 is: 1
# Conversion of Methane from node_0018 to node_0019 is: 1
# Conversion of Methane from node_0018 to node_0198 is: 1
# Conversion of Methane from node_0019 to node_0200 is: 1
# Conversion of Methane from node_0019 to node_0034 is: 1
# Conversion of Methane from node_0019 to node_0020 is: 1
# Conversion of Methane from node_0020 to node_0407 is: 1
# Conversion of Methane from node_0020 to node_0197 is: 1
# Conversion of Methane from node_0020 to node_0406 is: 1
# Conversion of Methane from node_0021 to node_0201_2 is: 1
# Conversion of Methane from node_0021 to node_0201_1 is: 1
# Conversion of Methane from node_0021 to node_0033 is: 1
# Conversion of Methane from node_0021 to node_0387 is: 1
# Conversion of Methane from node_0022 to node_0408 is: 1
# Conversion of Methane from node_0022 to node_0023 is: 1
# Conversion of Methane from node_0023 to node_0024_2 is: 1
# Conversion of Methane from node_0023 to node_0410 is: 1
# Conversion of Methane from node_0023 to node_0409 is: 1
# Conversion of Methane from node_0023 to node_0024_1 is: 1
# Conversion of Methane from node_0023 to node_0393 is: 1
# Conversion of Methane from node_0024 to node_0025 is: 1
# Conversion of Methane from node_0025 to node_0027_1 is: 1
# Conversion of Methane from node_0025 to node_0026 is: 1
# Conversion of Methane from node_0025 to node_0027_2 is: 1
# Conversion of Methane from node_0026 to node_0206 is: 1
# Conversion of Methane from node_0026 to node_0180 is: 1
# Conversion of Methane from node_0026 to node_0179 is: 1
# Conversion of Methane from node_0026 to node_0411 is: 1
# Conversion of Methane from node_0026 to node_0412 is: 1
# Conversion of Methane from node_0027 to node_0028 is: 1
# Conversion of Methane from node_0027 to node_0029 is: 1
# Conversion of Methane from node_0028 to node_0414 is: 1
# Conversion of Methane from node_0028 to node_0413 is: 1
# Conversion of Methane from node_0029 to node_0030 is: 1
# Conversion of Methane from node_0029 to node_0416 is: 1
# Conversion of Methane from node_0029 to node_0415 is: 1
# Conversion of Methane from node_0030 to node_0031 is: 1
# Conversion of Methane from node_0030 to node_0037 is: 1
# Conversion of Methane from node_0031 to node_0211 is: 1
# Conversion of Methane from node_0031 to node_0411 is: 1
# Conversion of Methane from node_0031 to node_0205 is: 1
# Conversion of Methane from node_0031 to node_0207 is: 1
# Conversion of Methane from node_0031 to node_0212_2 is: 1
# Conversion of Methane from node_0031 to node_0212_1 is: 1
# Conversion of Methane from node_0031 to node_0417 is: 1
# Conversion of Methane from node_0031 to node_0046 is: 1
# Conversion of Methane from node_0031 to node_0037 is: 1
# Conversion of Methane from node_0031 to node_0035 is: 1
# Conversion of Methane from node_0031 to node_0047 is: 1
# Conversion of Methane from node_0032 to node_0379 is: 1
# Conversion of Methane from node_0032 to node_0036_4 is: 1
# Conversion of Methane from node_0032 to node_0166 is: 1
# Conversion of Methane from node_0032 to node_0194 is: 1
# Conversion of Methane from node_0032 to node_0036_3 is: 1
# Conversion of Methane from node_0032 to node_0193 is: 1
# Conversion of Methane from node_0032 to node_0036_2 is: 1
# Conversion of Methane from node_0032 to node_0418 is: 1
# Conversion of Methane from node_0032 to node_0036_1 is: 1
# Conversion of Methane from node_0033 to node_0034 is: 1
# Conversion of Methane from node_0033 to node_0035 is: 1
# Conversion of Methane from node_0034 to node_0035 is: 1
# Conversion of Methane from node_0035 to node_0419 is: 1
# Conversion of Methane from node_0036 to node_0418 is: 1
# Conversion of Methane from node_0036 to node_0048 is: 1
# Conversion of Methane from node_0036 to node_0182 is: 1
# Conversion of Methane from node_0037 to node_0038 is: 1
# Conversion of Methane from node_0037 to node_0182 is: 1
# Conversion of Methane from node_0037 to node_0183 is: 1
# Conversion of Methane from node_0037 to node_0420 is: 1
# Conversion of Methane from node_0038 to node_0421 is: 1
# Conversion of Methane from node_0038 to node_0183 is: 1
# Conversion of Methane from node_0038 to node_0042 is: 1
# Conversion of Methane from node_0038 to node_0039 is: 1
# Conversion of Methane from node_0039 to node_0040 is: 1
# Conversion of Methane from node_0040 to node_0041 is: 1
# Conversion of Methane from node_0040 to node_0422 is: 1
# Conversion of Methane from node_0041 to node_0353 is: 1
# Conversion of Methane from node_0041 to node_0354 is: 1
# Conversion of Methane from node_0041 to node_0423 is: 1
# Conversion of Methane from node_0041 to node_0357 is: 1
# Conversion of Methane from node_0041 to node_0213 is: 1
# Conversion of Methane from node_0041 to node_0171 is: 1
# Conversion of Methane from node_0042 to node_0043 is: 1
# Conversion of Methane from node_0043 to node_0044 is: 1
# Conversion of Methane from node_0043 to node_0069 is: 1
# Conversion of Methane from node_0043 to node_0352 is: 1
# Conversion of Methane from node_0043 to node_0417 is: 1
# Conversion of Methane from node_0043 to node_0212 is: 1
# Conversion of Methane from node_0043 to node_0094 is: 1
# Conversion of Methane from node_0043 to node_0088 is: 1
# Conversion of Methane from node_0043 to node_0087 is: 1
# Conversion of Methane from node_0044 to node_0423_1 is: 1
# Conversion of Methane from node_0044 to node_0352_2 is: 1
# Conversion of Methane from node_0044 to node_0143 is: 1
# Conversion of Methane from node_0044 to node_0352_1 is: 1
# Conversion of Methane from node_0044 to node_0423_2 is: 1
# Conversion of Methane from node_0044 to node_0353 is: 1
# Conversion of Methane from node_0044 to node_0045 is: 1
# Conversion of Methane from node_0045 to node_0425 is: 1
# Conversion of Methane from node_0045 to node_0424 is: 1
# Conversion of Methane from node_0046 to node_0417 is: 1
# Conversion of Methane from node_0046 to node_0212_3 is: 1
# Conversion of Methane from node_0046 to node_0212_4 is: 1
# Conversion of Methane from node_0046 to node_0426 is: 1
# Conversion of Methane from node_0047 to node_0048 is: 1
# Conversion of Methane from node_0047 to node_0427 is: 1
# Conversion of Methane from node_0048 to node_0428 is: 1
# Conversion of Methane from node_0049 to node_0108 is: 1
# Conversion of Methane from node_0049 to node_0050 is: 1
# Conversion of Methane from node_0049 to node_0329 is: 1
# Conversion of Methane from node_0049 to node_0429_2 is: 1
# Conversion of Methane from node_0049 to node_0429_1 is: 1
# Conversion of Methane from node_0050 to node_0054 is: 1
# Conversion of Methane from node_0050 to node_0051 is: 1
# Conversion of Methane from node_0050 to node_0065 is: 1
# Conversion of Methane from node_0051 to node_0052_2 is: 1
# Conversion of Methane from node_0051 to node_0053 is: 1
# Conversion of Methane from node_0051 to node_0325 is: 1
# Conversion of Methane from node_0051 to node_0430 is: 1
# Conversion of Methane from node_0051 to node_0052_1 is: 1
# Conversion of Methane from node_0051 to node_0052_3 is: 1
# Conversion of Methane from node_0052 to node_0431 is: 1
# Conversion of Methane from node_0052 to node_0324 is: 1
# Conversion of Methane from node_0052 to node_0329 is: 1
# Conversion of Methane from node_0053 to node_0432 is: 1
# Conversion of Methane from node_0053 to node_0054 is: 1
# Conversion of Methane from node_0054 to node_0064 is: 1
# Conversion of Methane from node_0054 to node_0065 is: 1
# Conversion of Methane from node_0054 to node_0055 is: 1
# Conversion of Methane from node_0055 to node_0433 is: 1
# Conversion of Methane from node_0055 to node_0056 is: 1
# Conversion of Methane from node_0056 to node_0434 is: 1
# Conversion of Methane from node_0056 to node_0057 is: 1
# Conversion of Methane from node_0057 to node_0061 is: 1
# Conversion of Methane from node_0057 to node_0435 is: 1
# Conversion of Methane from node_0057 to node_0060 is: 1
# Conversion of Methane from node_0057 to node_0360 is: 1
# Conversion of Methane from node_0057 to node_0058 is: 1
# Conversion of Methane from node_0058 to node_0059 is: 1
# Conversion of Methane from node_0058 to node_0436 is: 1
# Conversion of Methane from node_0059 to node_0438 is: 1
# Conversion of Methane from node_0059 to node_0437 is: 1
# Conversion of Methane from node_0059 to node_0439 is: 1
# Conversion of Methane from node_0060 to node_0440 is: 1
# Conversion of Methane from node_0061 to node_0066 is: 1
# Conversion of Methane from node_0061 to node_0063 is: 1
# Conversion of Methane from node_0061 to node_0062 is: 1
# Conversion of Methane from node_0061 to node_0215 is: 1
# Conversion of Methane from node_0061 to node_0429 is: 1
# Conversion of Methane from node_0061 to node_0064 is: 1
# Conversion of Methane from node_0062 to node_0441_2 is: 1
# Conversion of Methane from node_0062 to node_0441_1 is: 1
# Conversion of Methane from node_0062 to node_0442 is: 1
# Conversion of Methane from node_0062 to node_0363 is: 1
# Conversion of Methane from node_0062 to node_0443 is: 1
# Conversion of Methane from node_0062 to node_0365 is: 1
# Conversion of Methane from node_0062 to node_0063 is: 1
# Conversion of Methane from node_0062 to node_0215 is: 1
# Conversion of Methane from node_0063 to node_0444 is: 1
# Conversion of Methane from node_0064 to node_0445 is: 1
# Conversion of Methane from node_0065 to node_0066 is: 1
# Conversion of Methane from node_0065 to node_0067 is: 1
# Conversion of Methane from node_0065 to node_0442 is: 1
# Conversion of Methane from node_0066 to node_0446 is: 1
# Conversion of Methane from node_0067 to node_0103_1 is: 1
# Conversion of Methane from node_0067 to node_0447_1 is: 1
# Conversion of Methane from node_0067 to node_0447_2 is: 1
# Conversion of Methane from node_0067 to node_0103_2 is: 1
# Conversion of Methane from node_0068 to node_0069 is: 1
# Conversion of Methane from node_0068 to node_0070 is: 1
# Conversion of Methane from node_0069 to node_0448 is: 1
# Conversion of Methane from node_0070 to node_0449 is: 1
# Conversion of Methane from node_0070 to node_0071 is: 1
# Conversion of Methane from node_0071 to node_0302_1 is: 1
# Conversion of Methane from node_0071 to node_0302_2 is: 1
# Conversion of Methane from node_0071 to node_0450_2 is: 1
# Conversion of Methane from node_0071 to node_0072 is: 1
# Conversion of Methane from node_0071 to node_0450_1 is: 1
# Conversion of Methane from node_0072 to node_0073 is: 1
# Conversion of Methane from node_0072 to node_0451 is: 1
# Conversion of Methane from node_0073 to node_0074 is: 1
# Conversion of Methane from node_0074 to node_0236_2 is: 1
# Conversion of Methane from node_0074 to node_0236_1 is: 1
# Conversion of Methane from node_0074 to node_0453_4 is: 1
# Conversion of Methane from node_0074 to node_0226 is: 1
# Conversion of Methane from node_0074 to node_0453_3 is: 1
# Conversion of Methane from node_0074 to node_0079 is: 1
# Conversion of Methane from node_0074 to node_0453_2 is: 1
# Conversion of Methane from node_0074 to node_0237 is: 1
# Conversion of Methane from node_0074 to node_0453_1 is: 1
# Conversion of Methane from node_0074 to node_0452 is: 1
# Conversion of Methane from node_0075 to node_0076 is: 1
# Conversion of Methane from node_0075 to node_0454 is: 1
# Conversion of Methane from node_0076 to node_0455_2 is: 1
# Conversion of Methane from node_0076 to node_0301 is: 1
# Conversion of Methane from node_0076 to node_0077 is: 1
# Conversion of Methane from node_0076 to node_0455_1 is: 1
# Conversion of Methane from node_0076 to node_0298 is: 1
# Conversion of Methane from node_0076 to node_0299 is: 1
# Conversion of Methane from node_0077 to node_0456 is: 1
# Conversion of Methane from node_0077 to node_0078 is: 1
# Conversion of Methane from node_0078 to node_0080 is: 0
# Conversion of Methane from node_0078 to node_0079 is: 0
# Conversion of Methane from node_0079 to node_0239 is: 1
# Conversion of Methane from node_0079 to node_0240 is: 0
# Conversion of Methane from node_0079 to node_0457 is: 1
# Conversion of Methane from node_0080 to node_0081 is: 0
# Conversion of Methane from node_0080 to node_0458 is: 1
# Conversion of Methane from node_0081 to node_0459 is: 1
# Conversion of Methane from node_0081 to node_0082 is: 0
# Conversion of Methane from node_0082 to node_0460 is: 1
# Conversion of Methane from node_0082 to node_0083 is: 0
# Conversion of Methane from node_0083 to node_0084 is: 0
# Conversion of Methane from node_0083 to node_0461 is: 1
# Conversion of Methane from node_0084 to node_0085 is: 0
# Conversion of Methane from node_0084 to node_0462 is: 1
# Conversion of Methane from node_0084 to node_0463 is: 1
# Conversion of Methane from node_0085 to node_0464 is: 1
# Conversion of Methane from node_0085 to node_0086 is: 0
# Conversion of Methane from node_0086 to node_0091 is: 0
# Conversion of Methane from node_0086 to node_0411 is: 1
# Conversion of Methane from node_0086 to node_0178 is: 1
# Conversion of Methane from node_0086 to node_0090 is: 1
# Conversion of Methane from node_0087 to node_0162_1 is: 1
# Conversion of Methane from node_0087 to node_0162_2 is: 1
# Conversion of Methane from node_0087 to node_0164 is: 1
# Conversion of Methane from node_0087 to node_0371_1 is: 1
# Conversion of Methane from node_0087 to node_0371_2 is: 1
# Conversion of Methane from node_0088 to node_0095 is: 1
# Conversion of Methane from node_0088 to node_0090 is: 1
# Conversion of Methane from node_0088 to node_0089 is: 1
# Conversion of Methane from node_0089 to node_0466 is: 1
# Conversion of Methane from node_0089 to node_0465 is: 1
# Conversion of Methane from node_0090 to node_0467 is: 1
# Conversion of Methane from node_0091 to node_0092 is: 0
# Conversion of Methane from node_0091 to node_0468 is: 1
# Conversion of Methane from node_0092 to node_0110_1 is: 1
# Conversion of Methane from node_0092 to node_0093 is: 0
# Conversion of Methane from node_0092 to node_0411 is: 1
# Conversion of Methane from node_0092 to node_0110_2 is: 1
# Conversion of Methane from node_0093 to node_0133 is: 1
# Conversion of Methane from node_0093 to node_0469 is: 1
# Conversion of Methane from node_0094 to node_0470 is: 1
# Conversion of Methane from node_0095 to node_0471 is: 1
# Conversion of Methane from node_0095 to node_0096 is: 1
# Conversion of Methane from node_0096 to node_0472 is: 1
# Conversion of Methane from node_0097 to node_0473_2 is: 1
# Conversion of Methane from node_0097 to node_0473_1 is: 1
# Conversion of Methane from node_0097 to node_0395_4 is: 1
# Conversion of Methane from node_0097 to node_0395_3 is: 1
# Conversion of Methane from node_0098 to node_0394 is: 1
# Conversion of Methane from node_0098 to node_0099_1 is: 1
# Conversion of Methane from node_0098 to node_0099_2 is: 1
# Conversion of Methane from node_0098 to node_0395 is: 1
# Conversion of Methane from node_0098 to node_0203 is: 1
# Conversion of Methane from node_0098 to node_0474 is: 1
# Conversion of Methane from node_0099 to node_0475 is: 1
# Conversion of Methane from node_0099 to node_0203 is: 1
# Conversion of Methane from node_0099 to node_0114_2 is: 1
# Conversion of Methane from node_0099 to node_0114_1 is: 1
# Conversion of Methane from node_0099 to node_0199 is: 1
# Conversion of Methane from node_0100 to node_0101_2 is: 1
# Conversion of Methane from node_0100 to node_0101_1 is: 1
# Conversion of Methane from node_0100 to node_0358 is: 1
# Conversion of Methane from node_0100 to node_0359 is: 1
# Conversion of Methane from node_0101 to node_0102_2 is: 1
# Conversion of Methane from node_0101 to node_0102_1 is: 1
# Conversion of Methane from node_0102 to node_0447_4 is: 1
# Conversion of Methane from node_0102 to node_0447_3 is: 1
# Conversion of Methane from node_0103 to node_0104_2 is: 1
# Conversion of Methane from node_0103 to node_0442 is: 1
# Conversion of Methane from node_0103 to node_0104_1 is: 1
# Conversion of Methane from node_0104 to node_0106_2 is: 1
# Conversion of Methane from node_0104 to node_0106_1 is: 1
# Conversion of Methane from node_0104 to node_0476 is: 1
# Conversion of Methane from node_0104 to node_0105 is: 1
# Conversion of Methane from node_0105 to node_0106 is: 1
# Conversion of Methane from node_0105 to node_0452 is: 1
# Conversion of Methane from node_0106 to node_0477 is: 1
# Conversion of Methane from node_0106 to node_0316 is: 1
# Conversion of Methane from node_0106 to node_0107 is: 1
# Conversion of Methane from node_0106 to node_0108 is: 1
# Conversion of Methane from node_0107 to node_0478 is: 1
# Conversion of Methane from node_0107 to node_0108 is: 1
# Conversion of Methane from node_0108 to node_0109_2 is: 1
# Conversion of Methane from node_0108 to node_0109_1 is: 1
# Conversion of Methane from node_0108 to node_0109_3 is: 1
# Conversion of Methane from node_0108 to node_0317 is: 1
# Conversion of Methane from node_0109 to node_0318 is: 1
# Conversion of Methane from node_0109 to node_0110_4 is: 1
# Conversion of Methane from node_0109 to node_0110_3 is: 1
# Conversion of Methane from node_0109 to node_0204 is: 1
# Conversion of Methane from node_0110 to node_0319 is: 1
# Conversion of Methane from node_0110 to node_0320 is: 1
# Conversion of Methane from node_0110 to node_0111 is: 1
# Conversion of Methane from node_0110 to node_0112 is: 1
# Conversion of Methane from node_0111 to node_0181 is: 1
# Conversion of Methane from node_0111 to node_0113_1 is: 1
# Conversion of Methane from node_0111 to node_0113_2 is: 1
# Conversion of Methane from node_0111 to node_0179 is: 1
# Conversion of Methane from node_0111 to node_0321 is: 1
# Conversion of Methane from node_0111 to node_0112 is: 1
# Conversion of Methane from node_0112 to node_0479 is: 1
# Conversion of Methane from node_0113 to node_0480 is: 1
# Conversion of Methane from node_0113 to node_0131_2 is: 1
# Conversion of Methane from node_0113 to node_0131_1 is: 1
# Conversion of Methane from node_0114 to node_0115_1 is: 1
# Conversion of Methane from node_0114 to node_0481 is: 1
# Conversion of Methane from node_0114 to node_0115_2 is: 1
# Conversion of Methane from node_0115 to node_0116_1 is: 1
# Conversion of Methane from node_0115 to node_0116_2 is: 1
# Conversion of Methane from node_0116 to node_0117_2 is: 1
# Conversion of Methane from node_0116 to node_0117_1 is: 1
# Conversion of Methane from node_0117 to node_0118_2 is: 1
# Conversion of Methane from node_0117 to node_0118_1 is: 1
# Conversion of Methane from node_0118 to node_0119_2 is: 1
# Conversion of Methane from node_0118 to node_0119_1 is: 1
# Conversion of Methane from node_0119 to node_0120_2 is: 1
# Conversion of Methane from node_0119 to node_0120_1 is: 1
# Conversion of Methane from node_0120 to node_0121_2 is: 1
# Conversion of Methane from node_0120 to node_0121_1 is: 1
# Conversion of Methane from node_0121 to node_0122_1 is: 1
# Conversion of Methane from node_0121 to node_0122_2 is: 1
# Conversion of Methane from node_0122 to node_0123_2 is: 1
# Conversion of Methane from node_0122 to node_0123_1 is: 1
# Conversion of Methane from node_0123 to node_0373 is: 1
# Conversion of Methane from node_0123 to node_0132_1 is: 1
# Conversion of Methane from node_0123 to node_0124_2 is: 1
# Conversion of Methane from node_0123 to node_0124_1 is: 1
# Conversion of Methane from node_0123 to node_0483 is: 1
# Conversion of Methane from node_0123 to node_0132_2 is: 1
# Conversion of Methane from node_0123 to node_0482_1 is: 1
# Conversion of Methane from node_0123 to node_0482_2 is: 1
# Conversion of Methane from node_0124 to node_0125_2 is: 1
# Conversion of Methane from node_0124 to node_0125_1 is: 1
# Conversion of Methane from node_0125 to node_0484 is: 1
# Conversion of Methane from node_0125 to node_0126_2 is: 1
# Conversion of Methane from node_0125 to node_0126_1 is: 1
# Conversion of Methane from node_0126 to node_0127_1 is: 1
# Conversion of Methane from node_0126 to node_0127_2 is: 1
# Conversion of Methane from node_0127 to node_0128_2 is: 1
# Conversion of Methane from node_0127 to node_0128_1 is: 1
# Conversion of Methane from node_0128 to node_0338 is: 1
# Conversion of Methane from node_0128 to node_0485_1 is: 1
# Conversion of Methane from node_0128 to node_0372 is: 1
# Conversion of Methane from node_0128 to node_0485_2 is: 1
# Conversion of Methane from node_0128 to node_0486 is: 1
# Conversion of Methane from node_0129 to node_0130_1 is: 1
# Conversion of Methane from node_0129 to node_0338_1 is: 1
# Conversion of Methane from node_0129 to node_0338_2 is: 1
# Conversion of Methane from node_0129 to node_0130_2 is: 1
# Conversion of Methane from node_0129 to node_0346 is: 1
# Conversion of Methane from node_0129 to node_0372_1 is: 1
# Conversion of Methane from node_0129 to node_0372_2 is: 1
# Conversion of Methane from node_0129 to node_0487 is: 1
# Conversion of Methane from node_0130 to node_0488 is: 1
# Conversion of Methane from node_0130 to node_0489 is: 1
# Conversion of Methane from node_0131 to node_0482_3 is: 1
# Conversion of Methane from node_0131 to node_0482_4 is: 1
# Conversion of Methane from node_0132 to node_0374 is: 1
# Conversion of Methane from node_0133 to node_0134 is: 1
# Conversion of Methane from node_0133 to node_0336 is: 1
# Conversion of Methane from node_0133 to node_0361 is: 1
# Conversion of Methane from node_0133 to node_0490 is: 1
# Conversion of Methane from node_0134 to node_0491 is: 1
# Conversion of Methane from node_0134 to node_0492 is: 1
# Conversion of Methane from node_0135 to node_0136 is: 1
# Conversion of Methane from node_0135 to node_0380_2 is: 1
# Conversion of Methane from node_0135 to node_0380_1 is: 1
# Conversion of Methane from node_0136 to node_0493_5 is: 1
# Conversion of Methane from node_0136 to node_0493_4 is: 1
# Conversion of Methane from node_0136 to node_0493_3 is: 1
# Conversion of Methane from node_0136 to node_0493_2 is: 1
# Conversion of Methane from node_0136 to node_0493_1 is: 1
# Conversion of Methane from node_0136 to node_0362 is: 1
# Conversion of Methane from node_0136 to node_0208 is: 1
# Conversion of Methane from node_0136 to node_0209 is: 1
# Conversion of Methane from node_0137 to node_0208 is: 1
# Conversion of Methane from node_0137 to node_0162 is: 1
# Conversion of Methane from node_0137 to node_0212 is: 1
# Conversion of Methane from node_0137 to node_0138 is: 1
# Conversion of Methane from node_0137 to node_0161 is: 1
# Conversion of Methane from node_0138 to node_0139 is: 1
# Conversion of Methane from node_0139 to node_0266 is: 1
# Conversion of Methane from node_0139 to node_0495 is: 1
# Conversion of Methane from node_0139 to node_0268_1 is: 1
# Conversion of Methane from node_0139 to node_0494_1 is: 1
# Conversion of Methane from node_0139 to node_0269 is: 1
# Conversion of Methane from node_0139 to node_0268_3 is: 1
# Conversion of Methane from node_0139 to node_0268_2 is: 1
# Conversion of Methane from node_0139 to node_0494_2 is: 1
# Conversion of Methane from node_0140 to node_0141 is: 1
# Conversion of Methane from node_0140 to node_0144 is: 1
# Conversion of Methane from node_0140 to node_0162 is: 1
# Conversion of Methane from node_0140 to node_0496_3 is: 1
# Conversion of Methane from node_0140 to node_0497 is: 1
# Conversion of Methane from node_0140 to node_0496_5 is: 1
# Conversion of Methane from node_0140 to node_0496_4 is: 1
# Conversion of Methane from node_0140 to node_0496_2 is: 1
# Conversion of Methane from node_0140 to node_0496_1 is: 1
# Conversion of Methane from node_0141 to node_0498_2 is: 1
# Conversion of Methane from node_0141 to node_0142 is: 1
# Conversion of Methane from node_0141 to node_0498_1 is: 1
# Conversion of Methane from node_0142 to node_0176_2 is: 1
# Conversion of Methane from node_0142 to node_0176_1 is: 1
# Conversion of Methane from node_0142 to node_0143 is: 1
# Conversion of Methane from node_0142 to node_0144 is: 1
# Conversion of Methane from node_0142 to node_0499 is: 1
# Conversion of Methane from node_0143 to node_0169 is: 1
# Conversion of Methane from node_0143 to node_0170 is: 1
# Conversion of Methane from node_0144 to node_0500 is: 1
# Conversion of Methane from node_0145 to node_0501 is: 1
# Conversion of Methane from node_0145 to node_0146_2 is: 1
# Conversion of Methane from node_0145 to node_0146_1 is: 1
# Conversion of Methane from node_0146 to node_0147 is: 1
# Conversion of Methane from node_0147 to node_0148 is: 1
# Conversion of Methane from node_0147 to node_0149 is: 1
# Conversion of Methane from node_0147 to node_0501 is: 1
# Conversion of Methane from node_0148 to node_0502 is: 1
# Conversion of Methane from node_0149 to node_0150 is: 1
# Conversion of Methane from node_0150 to node_0503 is: 1
# Conversion of Methane from node_0150 to node_0151 is: 1
# Conversion of Methane from node_0151 to node_0152 is: 1
# Conversion of Methane from node_0151 to node_0156 is: 1
# Conversion of Methane from node_0152 to node_0504 is: 1
# Conversion of Methane from node_0152 to node_0153 is: 1
# Conversion of Methane from node_0153 to node_0158 is: 1
# Conversion of Methane from node_0153 to node_0154 is: 1
# Conversion of Methane from node_0154 to node_0155 is: 1
# Conversion of Methane from node_0154 to node_0505 is: 1
# Conversion of Methane from node_0155 to node_0508 is: 1
# Conversion of Methane from node_0155 to node_0507 is: 1
# Conversion of Methane from node_0155 to node_0506 is: 1
# Conversion of Methane from node_0156 to node_0509 is: 1
# Conversion of Methane from node_0156 to node_0157_2 is: 1
# Conversion of Methane from node_0156 to node_0157_1 is: 1
# Conversion of Methane from node_0157 to node_0161_2 is: 1
# Conversion of Methane from node_0157 to node_0158 is: 1
# Conversion of Methane from node_0157 to node_0167 is: 1
# Conversion of Methane from node_0157 to node_0161_1 is: 1
# Conversion of Methane from node_0158 to node_0510 is: 1
# Conversion of Methane from node_0158 to node_0159 is: 1
# Conversion of Methane from node_0159 to node_0511 is: 1
# Conversion of Methane from node_0159 to node_0160 is: 1
# Conversion of Methane from node_0160 to node_0296 is: 1
# Conversion of Methane from node_0160 to node_0297 is: 1
# Conversion of Methane from node_0161 to node_0514 is: 1
# Conversion of Methane from node_0161 to node_0513 is: 1
# Conversion of Methane from node_0161 to node_0499 is: 1
# Conversion of Methane from node_0161 to node_0512 is: 1
# Conversion of Methane from node_0162 to node_0514 is: 1
# Conversion of Methane from node_0162 to node_0163 is: 1
# Conversion of Methane from node_0163 to node_0515 is: 1
# Conversion of Methane from node_0163 to node_0210 is: 1
# Conversion of Methane from node_0164 to node_0165_1 is: 1
# Conversion of Methane from node_0164 to node_0165_2 is: 1
# Conversion of Methane from node_0164 to node_0349 is: 1
# Conversion of Methane from node_0164 to node_0403 is: 1
# Conversion of Methane from node_0164 to node_0166_1 is: 1
# Conversion of Methane from node_0164 to node_0166_2 is: 1
# Conversion of Methane from node_0164 to node_0516 is: 1
# Conversion of Methane from node_0164 to node_0350 is: 1
# Conversion of Methane from node_0165 to node_0514 is: 1
# Conversion of Methane from node_0165 to node_0418 is: 1
# Conversion of Methane from node_0166 to node_0348 is: 1
# Conversion of Methane from node_0166 to node_0349 is: 1
# Conversion of Methane from node_0166 to node_0517 is: 1
# Conversion of Methane from node_0166 to node_0518 is: 1
# Conversion of Methane from node_0166 to node_0347 is: 1
# Conversion of Methane from node_0167 to node_0168_1 is: 1
# Conversion of Methane from node_0167 to node_0168_2 is: 1
# Conversion of Methane from node_0167 to node_0171 is: 1
# Conversion of Methane from node_0167 to node_0172 is: 1
# Conversion of Methane from node_0168 to node_0169 is: 1
# Conversion of Methane from node_0169 to node_0171 is: 1
# Conversion of Methane from node_0170 to node_0423 is: 1
# Conversion of Methane from node_0171 to node_0174 is: 1
# Conversion of Methane from node_0171 to node_0173 is: 1
# Conversion of Methane from node_0172 to node_0519 is: 1
# Conversion of Methane from node_0172 to node_0520 is: 1
# Conversion of Methane from node_0173 to node_0521 is: 1
# Conversion of Methane from node_0173 to node_0522 is: 1
# Conversion of Methane from node_0174 to node_0175 is: 1
# Conversion of Methane from node_0174 to node_0523 is: 1
# Conversion of Methane from node_0175 to node_0525_2 is: 1
# Conversion of Methane from node_0175 to node_0525_1 is: 1
# Conversion of Methane from node_0175 to node_0524 is: 1
# Conversion of Methane from node_0176 to node_0177 is: 1
# Conversion of Methane from node_0177 to node_0526 is: 1
# Conversion of Methane from node_0177 to node_0527 is: 1
# Conversion of Methane from node_0178 to node_0528 is: 1
# Conversion of Methane from node_0179 to node_0529 is: 1
# Conversion of Methane from node_0180 to node_0530 is: 1
# Conversion of Methane from node_0180 to node_0181 is: 1
# Conversion of Methane from node_0181 to node_0531 is: 1
# Conversion of Methane from node_0182 to node_0532 is: 1
# Conversion of Methane from node_0183 to node_0184 is: 1
# Conversion of Methane from node_0184 to node_0533 is: 1
# Conversion of Methane from node_0184 to node_0185 is: 1
# Conversion of Methane from node_0185 to node_0186 is: 1
# Conversion of Methane from node_0185 to node_0189 is: 1
# Conversion of Methane from node_0185 to node_0190 is: 1
# Conversion of Methane from node_0186 to node_0188 is: 1
# Conversion of Methane from node_0186 to node_0187 is: 1
# Conversion of Methane from node_0187 to node_0188 is: 1
# Conversion of Methane from node_0187 to node_0534 is: 1
# Conversion of Methane from node_0188 to node_0189_1 is: 1
# Conversion of Methane from node_0188 to node_0189_2 is: 1
# Conversion of Methane from node_0188 to node_0191 is: 1
# Conversion of Methane from node_0189 to node_0190 is: 1
# Conversion of Methane from node_0189 to node_0535 is: 1
# Conversion of Methane from node_0190 to node_0536 is: 1
# Conversion of Methane from node_0191 to node_0532 is: 1
# Conversion of Methane from node_0191 to node_0192 is: 1
# Conversion of Methane from node_0192 to node_0537 is: 1
# Conversion of Methane from node_0193 to node_0538 is: 1
# Conversion of Methane from node_0193 to node_0194 is: 1
# Conversion of Methane from node_0194 to node_0382 is: 1
# Conversion of Methane from node_0195 to node_0382 is: 1
# Conversion of Methane from node_0195 to node_0196 is: 1
# Conversion of Methane from node_0195 to node_0381 is: 1
# Conversion of Methane from node_0196 to node_0384 is: 1
# Conversion of Methane from node_0197 to node_0539 is: 1
# Conversion of Methane from node_0198 to node_0540 is: 1
# Conversion of Methane from node_0198 to node_0199 is: 1
# Conversion of Methane from node_0199 to node_0541 is: 1
# Conversion of Methane from node_0200 to node_0542 is: 1
# Conversion of Methane from node_0201 to node_0202_1 is: 1
# Conversion of Methane from node_0201 to node_0202_2 is: 1
# Conversion of Methane from node_0202 to node_0543 is: 1
# Conversion of Methane from node_0203 to node_0545_1 is: 1
# Conversion of Methane from node_0203 to node_0544 is: 1
# Conversion of Methane from node_0203 to node_0545_2 is: 1
# Conversion of Methane from node_0204 to node_0330 is: 1
# Conversion of Methane from node_0204 to node_0331 is: 1
# Conversion of Methane from node_0205 to node_0347 is: 1
# Conversion of Methane from node_0206 to node_0546 is: 1
# Conversion of Methane from node_0206 to node_0207 is: 1
# Conversion of Methane from node_0207 to node_0547 is: 1
# Conversion of Methane from node_0208 to node_0548 is: 1
# Conversion of Methane from node_0209 to node_0210 is: 1
# Conversion of Methane from node_0209 to node_0549 is: 1
# Conversion of Methane from node_0210 to node_0550 is: 1
# Conversion of Methane from node_0211 to node_0371 is: 1
# Conversion of Methane from node_0212 to node_0213 is: 1
# Conversion of Methane from node_0213 to node_0551 is: 1
# Conversion of Methane from node_0214 to node_0215 is: 1
# Conversion of Methane from node_0214 to node_0363 is: 1
# Conversion of Methane from node_0215 to node_0443 is: 1
# Conversion of Methane from node_0215 to node_0365 is: 1
# Conversion of Methane from node_0216 to node_0224 is: 1
# Conversion of Methane from node_0216 to node_0217_1 is: 1
# Conversion of Methane from node_0216 to node_0217_2 is: 1
# Conversion of Methane from node_0216 to node_0218 is: 1
# Conversion of Methane from node_0217 to node_0552 is: 1
# Conversion of Methane from node_0218 to node_0219_1 is: 1
# Conversion of Methane from node_0218 to node_0553 is: 1
# Conversion of Methane from node_0218 to node_0219_2 is: 1
# Conversion of Methane from node_0219 to node_0220_1 is: 1
# Conversion of Methane from node_0219 to node_0220_2 is: 1
# Conversion of Methane from node_0220 to node_0221_1 is: 1
# Conversion of Methane from node_0220 to node_0221_2 is: 1
# Conversion of Methane from node_0220 to node_0224 is: 1
# Conversion of Methane from node_0221 to node_0222 is: 1
# Conversion of Methane from node_0221 to node_0229 is: 1
# Conversion of Methane from node_0221 to node_0230_1 is: 1
# Conversion of Methane from node_0221 to node_0230_2 is: 1
# Conversion of Methane from node_0222 to node_0554 is: 1
# Conversion of Methane from node_0222 to node_0223 is: 1
# Conversion of Methane from node_0223 to node_0455 is: 1
# Conversion of Methane from node_0223 to node_0302 is: 1
# Conversion of Methane from node_0223 to node_0303 is: 1
# Conversion of Methane from node_0224 to node_0225 is: 1
# Conversion of Methane from node_0225 to node_0226 is: 1
# Conversion of Methane from node_0225 to node_0227 is: 1
# Conversion of Methane from node_0225 to node_0555 is: 1
# Conversion of Methane from node_0226 to node_0228_2 is: 1
# Conversion of Methane from node_0226 to node_0236_4 is: 1
# Conversion of Methane from node_0226 to node_0236_3 is: 1
# Conversion of Methane from node_0226 to node_0228_1 is: 1
# Conversion of Methane from node_0226 to node_0556_2 is: 1
# Conversion of Methane from node_0226 to node_0556_1 is: 1
# Conversion of Methane from node_0226 to node_0227 is: 1
# Conversion of Methane from node_0227 to node_0228_5 is: 1
# Conversion of Methane from node_0227 to node_0228_4 is: 1
# Conversion of Methane from node_0227 to node_0228_3 is: 1
# Conversion of Methane from node_0228 to node_0233_2 is: 1
# Conversion of Methane from node_0228 to node_0233_1 is: 1
# Conversion of Methane from node_0228 to node_0229 is: 1
# Conversion of Methane from node_0228 to node_0557 is: 1
# Conversion of Methane from node_0229 to node_0558 is: 1
# Conversion of Methane from node_0230 to node_0231_1 is: 1
# Conversion of Methane from node_0230 to node_0231_2 is: 1
# Conversion of Methane from node_0231 to node_0559 is: 1
# Conversion of Methane from node_0231 to node_0232_1 is: 1
# Conversion of Methane from node_0231 to node_0232_2 is: 1
# Conversion of Methane from node_0232 to node_0234_2 is: 1
# Conversion of Methane from node_0232 to node_0560 is: 1
# Conversion of Methane from node_0232 to node_0234_1 is: 1
# Conversion of Methane from node_0233 to node_0234_3 is: 1
# Conversion of Methane from node_0233 to node_0234_4 is: 1
# Conversion of Methane from node_0233 to node_0234_5 is: 1
# Conversion of Methane from node_0233 to node_0234_6 is: 1
# Conversion of Methane from node_0233 to node_0235 is: 1
# Conversion of Methane from node_0234 to node_0243_1 is: 1
# Conversion of Methane from node_0234 to node_0242 is: 0
# Conversion of Methane from node_0234 to node_0243_2 is: 1
# Conversion of Methane from node_0234 to node_0314_2 is: 0
# Conversion of Methane from node_0234 to node_0314_1 is: 1
# Conversion of Methane from node_0234 to node_0312 is: 1
# Conversion of Methane from node_0235 to node_0556_4 is: 1
# Conversion of Methane from node_0235 to node_0556_3 is: 1
# Conversion of Methane from node_0236 to node_0453 is: 1
# Conversion of Methane from node_0237 to node_0239 is: 1
# Conversion of Methane from node_0237 to node_0238 is: 1
# Conversion of Methane from node_0238 to node_0241 is: 0
# Conversion of Methane from node_0238 to node_0246 is: 1
# Conversion of Methane from node_0238 to node_0242 is: 0
# Conversion of Methane from node_0238 to node_0243 is: 1
# Conversion of Methane from node_0239 to node_0561 is: 1
# Conversion of Methane from node_0240 to node_0562 is: 1
# Conversion of Methane from node_0240 to node_0241 is: 0
# Conversion of Methane from node_0241 to node_0246 is: 1
# Conversion of Methane from node_0242 to node_0563 is: 1
# Conversion of Methane from node_0243 to node_0252 is: 1
# Conversion of Methane from node_0243 to node_0244 is: 1
# Conversion of Methane from node_0244 to node_0245 is: 1
# Conversion of Methane from node_0244 to node_0564 is: 1
# Conversion of Methane from node_0245 to node_0248 is: 1
# Conversion of Methane from node_0245 to node_0566 is: 1
# Conversion of Methane from node_0245 to node_0565 is: 1
# Conversion of Methane from node_0245 to node_0250 is: 1
# Conversion of Methane from node_0245 to node_0249_2 is: 1
# Conversion of Methane from node_0245 to node_0249_1 is: 1
# Conversion of Methane from node_0245 to node_0247 is: 1
# Conversion of Methane from node_0246 to node_0247_1 is: 1
# Conversion of Methane from node_0246 to node_0247_2 is: 1
# Conversion of Methane from node_0247 to node_0250_1 is: 1
# Conversion of Methane from node_0247 to node_0250_2 is: 1
# Conversion of Methane from node_0248 to node_0249 is: 1
# Conversion of Methane from node_0248 to node_0567_3 is: 1
# Conversion of Methane from node_0248 to node_0567_2 is: 1
# Conversion of Methane from node_0248 to node_0567_1 is: 1
# Conversion of Methane from node_0248 to node_0313_1 is: 1
# Conversion of Methane from node_0248 to node_0313_2 is: 1
# Conversion of Methane from node_0248 to node_0252 is: 1
# Conversion of Methane from node_0249 to node_0251_2 is: 1
# Conversion of Methane from node_0249 to node_0260_1 is: 1
# Conversion of Methane from node_0249 to node_0260_2 is: 1
# Conversion of Methane from node_0249 to node_0251_1 is: 1
# Conversion of Methane from node_0249 to node_0261 is: 1
# Conversion of Methane from node_0250 to node_0251_3 is: 1
# Conversion of Methane from node_0250 to node_0251_4 is: 1
# Conversion of Methane from node_0250 to node_0562_3 is: 1
# Conversion of Methane from node_0250 to node_0251_5 is: 1
# Conversion of Methane from node_0250 to node_0562_1 is: 1
# Conversion of Methane from node_0250 to node_0562_2 is: 1
# Conversion of Methane from node_0251 to node_0253_1 is: 1
# Conversion of Methane from node_0251 to node_0253_2 is: 1
# Conversion of Methane from node_0251 to node_0253_3 is: 1
# Conversion of Methane from node_0252 to node_0568 is: 1
# Conversion of Methane from node_0253 to node_0258_1 is: 1
# Conversion of Methane from node_0253 to node_0258_2 is: 1
# Conversion of Methane from node_0253 to node_0569_1 is: 1
# Conversion of Methane from node_0253 to node_0254 is: 1
# Conversion of Methane from node_0253 to node_0569_2 is: 1
# Conversion of Methane from node_0254 to node_0255 is: 1
# Conversion of Methane from node_0255 to node_0256 is: 1
# Conversion of Methane from node_0255 to node_0258 is: 1
# Conversion of Methane from node_0256 to node_0570 is: 1
# Conversion of Methane from node_0256 to node_0257 is: 1
# Conversion of Methane from node_0257 to node_0572 is: 1
# Conversion of Methane from node_0257 to node_0571 is: 1
# Conversion of Methane from node_0258 to node_0260_3 is: 1
# Conversion of Methane from node_0258 to node_0260_4 is: 1
# Conversion of Methane from node_0258 to node_0259 is: 1
# Conversion of Methane from node_0259 to node_0261 is: 1
# Conversion of Methane from node_0260 to node_0573 is: 1
# Conversion of Methane from node_0261 to node_0574 is: 1
# Conversion of Methane from node_0261 to node_0262_1 is: 1
# Conversion of Methane from node_0261 to node_0262_2 is: 1
# Conversion of Methane from node_0261 to node_0262_3 is: 1
# Conversion of Methane from node_0261 to node_0567 is: 1
# Conversion of Methane from node_0262 to node_0315 is: 1
# Conversion of Methane from node_0262 to node_0576 is: 1
# Conversion of Methane from node_0262 to node_0577 is: 1
# Conversion of Methane from node_0262 to node_0567 is: 1
# Conversion of Methane from node_0262 to node_0575 is: 1
# Conversion of Methane from node_0262 to node_0263_2 is: 1
# Conversion of Methane from node_0262 to node_0263_1 is: 1
# Conversion of Methane from node_0262 to node_0364 is: 1
# Conversion of Methane from node_0263 to node_0577_2 is: 1
# Conversion of Methane from node_0263 to node_0577_1 is: 1
# Conversion of Methane from node_0263 to node_0264_1 is: 1
# Conversion of Methane from node_0263 to node_0264_2 is: 1
# Conversion of Methane from node_0263 to node_0264_3 is: 1
# Conversion of Methane from node_0264 to node_0267 is: 1
# Conversion of Methane from node_0264 to node_0266_2 is: 1
# Conversion of Methane from node_0264 to node_0265_3 is: 1
# Conversion of Methane from node_0264 to node_0266_1 is: 1
# Conversion of Methane from node_0264 to node_0265_1 is: 1
# Conversion of Methane from node_0264 to node_0578 is: 1
# Conversion of Methane from node_0264 to node_0265_2 is: 1
# Conversion of Methane from node_0265 to node_0270 is: 1
# Conversion of Methane from node_0265 to node_0579 is: 1
# Conversion of Methane from node_0265 to node_0580 is: 1
# Conversion of Methane from node_0266 to node_0267 is: 1
# Conversion of Methane from node_0267 to node_0494_4 is: 1
# Conversion of Methane from node_0267 to node_0494_3 is: 1
# Conversion of Methane from node_0268 to node_0271 is: 1
# Conversion of Methane from node_0268 to node_0272 is: 1
# Conversion of Methane from node_0269 to node_0581 is: 1
# Conversion of Methane from node_0269 to node_0270 is: 1
# Conversion of Methane from node_0270 to node_0583 is: 1
# Conversion of Methane from node_0270 to node_0272 is: 1
# Conversion of Methane from node_0270 to node_0582 is: 1
# Conversion of Methane from node_0271 to node_0276 is: 1
# Conversion of Methane from node_0271 to node_0275 is: 1
# Conversion of Methane from node_0271 to node_0274 is: 1
# Conversion of Methane from node_0271 to node_0272 is: 1
# Conversion of Methane from node_0272 to node_0273 is: 1
# Conversion of Methane from node_0273 to node_0584 is: 1
# Conversion of Methane from node_0273 to node_0274 is: 1
# Conversion of Methane from node_0273 to node_0296 is: 1
# Conversion of Methane from node_0274 to node_0287 is: 1
# Conversion of Methane from node_0275 to node_0278 is: 1
# Conversion of Methane from node_0275 to node_0287 is: 1
# Conversion of Methane from node_0276 to node_0277 is: 1
# Conversion of Methane from node_0276 to node_0585 is: 1
# Conversion of Methane from node_0277 to node_0278 is: 1
# Conversion of Methane from node_0277 to node_0586 is: 1
# Conversion of Methane from node_0277 to node_0279_1 is: 1
# ...
# Conversion of Hydrogen from node_0102_1 to node_0102 is: 0
# Conversion of Hydrogen from node_0102_2 to node_0102 is: 0
# Conversion of Hydrogen from node_0103_1 to node_0103 is: 0
# Conversion of Hydrogen from node_0103_2 to node_0103 is: 0
# Conversion of Hydrogen from node_0104_1 to node_0104 is: 0
# Conversion of Hydrogen from node_0104_2 to node_0104 is: 0
# Conversion of Hydrogen from node_0106_1 to node_0106 is: 0
# Conversion of Hydrogen from node_0106_2 to node_0106 is: 0
# Conversion of Hydrogen from node_0109_1 to node_0109 is: 0
# Conversion of Hydrogen from node_0109_2 to node_0109 is: 0
# Conversion of Hydrogen from node_0109_3 to node_0109 is: 0
# Conversion of Hydrogen from node_0110_1 to node_0110 is: 0
# Conversion of Hydrogen from node_0110_2 to node_0110 is: 0
# Conversion of Hydrogen from node_0110_3 to node_0110 is: 0
# Conversion of Hydrogen from node_0110_4 to node_0110 is: 0
# Conversion of Hydrogen from node_0113_1 to node_0113 is: 0
# Conversion of Hydrogen from node_0113_2 to node_0113 is: 0
# Conversion of Hydrogen from node_0114_1 to node_0114 is: 0
# Conversion of Hydrogen from node_0114_2 to node_0114 is: 0
# Conversion of Hydrogen from node_0115_1 to node_0115 is: 0
# Conversion of Hydrogen from node_0115_2 to node_0115 is: 0
# Conversion of Hydrogen from node_0116_1 to node_0116 is: 0
# Conversion of Hydrogen from node_0116_2 to node_0116 is: 0
# Conversion of Hydrogen from node_0117_1 to node_0117 is: 0
# Conversion of Hydrogen from node_0117_2 to node_0117 is: 0
# Conversion of Hydrogen from node_0118_1 to node_0118 is: 0
# Conversion of Hydrogen from node_0118_2 to node_0118 is: 0
# Conversion of Hydrogen from node_0119_1 to node_0119 is: 0
# Conversion of Hydrogen from node_0119_2 to node_0119 is: 0
# Conversion of Hydrogen from node_0120_1 to node_0120 is: 0
# Conversion of Hydrogen from node_0120_2 to node_0120 is: 0
# Conversion of Hydrogen from node_0121_1 to node_0121 is: 0
# Conversion of Hydrogen from node_0121_2 to node_0121 is: 0
# Conversion of Hydrogen from node_0122_1 to node_0122 is: 0
# Conversion of Hydrogen from node_0122_2 to node_0122 is: 0
# Conversion of Hydrogen from node_0123_1 to node_0123 is: 0
# Conversion of Hydrogen from node_0123_2 to node_0123 is: 0
# Conversion of Hydrogen from node_0124_1 to node_0124 is: 0
# Conversion of Hydrogen from node_0124_2 to node_0124 is: 0
# Conversion of Hydrogen from node_0125_1 to node_0125 is: 0
# Conversion of Hydrogen from node_0125_2 to node_0125 is: 0
# Conversion of Hydrogen from node_0126_1 to node_0126 is: 0
# Conversion of Hydrogen from node_0126_2 to node_0126 is: 0
# Conversion of Hydrogen from node_0127_1 to node_0127 is: 0
# Conversion of Hydrogen from node_0127_2 to node_0127 is: 0
# Conversion of Hydrogen from node_0128_1 to node_0128 is: 0
# Conversion of Hydrogen from node_0128_2 to node_0128 is: 0
# Conversion of Hydrogen from node_0130_1 to node_0130 is: 0
# Conversion of Hydrogen from node_0130_2 to node_0130 is: 0
# Conversion of Hydrogen from node_0131_1 to node_0131 is: 0
# Conversion of Hydrogen from node_0131_2 to node_0131 is: 0
# Conversion of Hydrogen from node_0132_1 to node_0132 is: 0
# Conversion of Hydrogen from node_0132_2 to node_0132 is: 0
# Conversion of Hydrogen from node_0146_1 to node_0146 is: 0
# Conversion of Hydrogen from node_0146_2 to node_0146 is: 0
# Conversion of Hydrogen from node_0157_1 to node_0157 is: 0
# Conversion of Hydrogen from node_0157_2 to node_0157 is: 0
# Conversion of Hydrogen from node_0161_1 to node_0161 is: 0
# Conversion of Hydrogen from node_0161_2 to node_0161 is: 0
# Conversion of Hydrogen from node_0162_1 to node_0162 is: 0
# Conversion of Hydrogen from node_0162_2 to node_0162 is: 0
# Conversion of Hydrogen from node_0165_1 to node_0165 is: 0
# Conversion of Hydrogen from node_0165_2 to node_0165 is: 0
# Conversion of Hydrogen from node_0166_1 to node_0166 is: 0
# Conversion of Hydrogen from node_0166_2 to node_0166 is: 0
# Conversion of Hydrogen from node_0168_1 to node_0168 is: 0
# Conversion of Hydrogen from node_0168_2 to node_0168 is: 0
# Conversion of Hydrogen from node_0176_1 to node_0176 is: 0
# Conversion of Hydrogen from node_0176_2 to node_0176 is: 0
# Conversion of Hydrogen from node_0189_1 to node_0189 is: 0
# Conversion of Hydrogen from node_0189_2 to node_0189 is: 0
# Conversion of Hydrogen from node_0195_1 to node_0195 is: 0
# Conversion of Hydrogen from node_0195_2 to node_0195 is: 0
# Conversion of Hydrogen from node_0195_3 to node_0195 is: 0
# Conversion of Hydrogen from node_0201_1 to node_0201 is: 0
# Conversion of Hydrogen from node_0201_2 to node_0201 is: 0
# Conversion of Hydrogen from node_0202_1 to node_0202 is: 0
# Conversion of Hydrogen from node_0202_2 to node_0202 is: 0
# Conversion of Hydrogen from node_0212_1 to node_0212 is: 0
# Conversion of Hydrogen from node_0212_2 to node_0212 is: 0
# Conversion of Hydrogen from node_0212_3 to node_0212 is: 0
# Conversion of Hydrogen from node_0212_4 to node_0212 is: 0
# Conversion of Hydrogen from node_0217_1 to node_0217 is: 0
# Conversion of Hydrogen from node_0217_2 to node_0217 is: 0
# Conversion of Hydrogen from node_0219_1 to node_0219 is: 0
# Conversion of Hydrogen from node_0219_2 to node_0219 is: 0
# Conversion of Hydrogen from node_0220_1 to node_0220 is: 0
# Conversion of Hydrogen from node_0220_2 to node_0220 is: 0
# Conversion of Hydrogen from node_0221_1 to node_0221 is: 0
# Conversion of Hydrogen from node_0221_2 to node_0221 is: 0
# Conversion of Hydrogen from node_0228_1 to node_0228 is: 0
# Conversion of Hydrogen from node_0228_2 to node_0228 is: 0
# Conversion of Hydrogen from node_0228_3 to node_0228 is: 0
# Conversion of Hydrogen from node_0228_4 to node_0228 is: 0
# Conversion of Hydrogen from node_0228_5 to node_0228 is: 0
# Conversion of Hydrogen from node_0230_1 to node_0230 is: 0
# Conversion of Hydrogen from node_0230_2 to node_0230 is: 0
# Conversion of Hydrogen from node_0231_1 to node_0231 is: 0
# Conversion of Hydrogen from node_0231_2 to node_0231 is: 0
# Conversion of Hydrogen from node_0232_1 to node_0232 is: 0
# Conversion of Hydrogen from node_0232_2 to node_0232 is: 0
# Conversion of Hydrogen from node_0233_1 to node_0233 is: 0
# Conversion of Hydrogen from node_0233_2 to node_0233 is: 0
# Conversion of Hydrogen from node_0234_1 to node_0234 is: 0
# Conversion of Hydrogen from node_0234_2 to node_0234 is: 0
# Conversion of Hydrogen from node_0234_3 to node_0234 is: 0
# Conversion of Hydrogen from node_0234_4 to node_0234 is: 0
# Conversion of Hydrogen from node_0234_5 to node_0234 is: 0
# Conversion of Hydrogen from node_0234_6 to node_0234 is: 0
# Conversion of Hydrogen from node_0236_1 to node_0236 is: 0
# Conversion of Hydrogen from node_0236_2 to node_0236 is: 0
# Conversion of Hydrogen from node_0236_3 to node_0236 is: 0
# Conversion of Hydrogen from node_0236_4 to node_0236 is: 0
# Conversion of Hydrogen from node_0243_1 to node_0243 is: 0
# Conversion of Hydrogen from node_0243_2 to node_0243 is: 0
# Conversion of Hydrogen from node_0247_1 to node_0247 is: 0
# Conversion of Hydrogen from node_0247_2 to node_0247 is: 0
# Conversion of Hydrogen from node_0249_1 to node_0249 is: 0
# Conversion of Hydrogen from node_0249_2 to node_0249 is: 0
# Conversion of Hydrogen from node_0250_1 to node_0250 is: 0
# Conversion of Hydrogen from node_0250_2 to node_0250 is: 0
# Conversion of Hydrogen from node_0251_1 to node_0251 is: 0
# Conversion of Hydrogen from node_0251_2 to node_0251 is: 0
# Conversion of Hydrogen from node_0251_3 to node_0251 is: 0
# Conversion of Hydrogen from node_0251_4 to node_0251 is: 0
# Conversion of Hydrogen from node_0251_5 to node_0251 is: 0
# Conversion of Hydrogen from node_0253_1 to node_0253 is: 0
# Conversion of Hydrogen from node_0253_2 to node_0253 is: 0
# Conversion of Hydrogen from node_0253_3 to node_0253 is: 0
# Conversion of Hydrogen from node_0258_1 to node_0258 is: 0
# Conversion of Hydrogen from node_0258_2 to node_0258 is: 0
# Conversion of Hydrogen from node_0260_1 to node_0260 is: 0
# Conversion of Hydrogen from node_0260_2 to node_0260 is: 0
# Conversion of Hydrogen from node_0260_3 to node_0260 is: 0
# Conversion of Hydrogen from node_0260_4 to node_0260 is: 0
# Conversion of Hydrogen from node_0262_1 to node_0262 is: 0
# Conversion of Hydrogen from node_0262_2 to node_0262 is: 0
# Conversion of Hydrogen from node_0262_3 to node_0262 is: 0
# Conversion of Hydrogen from node_0263_1 to node_0263 is: 0
# Conversion of Hydrogen from node_0263_2 to node_0263 is: 0
# Conversion of Hydrogen from node_0264_1 to node_0264 is: 0
# Conversion of Hydrogen from node_0264_2 to node_0264 is: 0
# Conversion of Hydrogen from node_0264_3 to node_0264 is: 0
# Conversion of Hydrogen from node_0265_1 to node_0265 is: 0
# Conversion of Hydrogen from node_0265_2 to node_0265 is: 0
# Conversion of Hydrogen from node_0265_3 to node_0265 is: 0
# Conversion of Hydrogen from node_0266_1 to node_0266 is: 0
# Conversion of Hydrogen from node_0266_2 to node_0266 is: 0
# Conversion of Hydrogen from node_0268_1 to node_0268 is: 0
# Conversion of Hydrogen from node_0268_2 to node_0268 is: 0
# Conversion of Hydrogen from node_0268_3 to node_0268 is: 0
# Conversion of Hydrogen from node_0279_1 to node_0279 is: 0
# Conversion of Hydrogen from node_0279_2 to node_0279 is: 0
# Conversion of Hydrogen from node_0298_1 to node_0298 is: 0
# Conversion of Hydrogen from node_0298_2 to node_0298 is: 0
# Conversion of Hydrogen from node_0302_1 to node_0302 is: 0
# Conversion of Hydrogen from node_0302_2 to node_0302 is: 0
# Conversion of Hydrogen from node_0312_1 to node_0312 is: 0
# Conversion of Hydrogen from node_0312_2 to node_0312 is: 0
# Conversion of Hydrogen from node_0313_1 to node_0313 is: 0
# Conversion of Hydrogen from node_0313_2 to node_0313 is: 0
# Conversion of Hydrogen from node_0313_3 to node_0313 is: 0
# Conversion of Hydrogen from node_0313_4 to node_0313 is: 0
# Conversion of Hydrogen from node_0313_5 to node_0313 is: 0
# Conversion of Hydrogen from node_0313_6 to node_0313 is: 0
# Conversion of Hydrogen from node_0314_1 to node_0314 is: 0
# Conversion of Hydrogen from node_0314_2 to node_0314 is: 0
# Conversion of Hydrogen from node_0324_1 to node_0324 is: 0
# Conversion of Hydrogen from node_0324_2 to node_0324 is: 0
# Conversion of Hydrogen from node_0326_1 to node_0326 is: 0
# Conversion of Hydrogen from node_0326_2 to node_0326 is: 0
# Conversion of Hydrogen from node_0327_1 to node_0327 is: 0
# Conversion of Hydrogen from node_0327_2 to node_0327 is: 0
# Conversion of Hydrogen from node_0333_1 to node_0333 is: 0
# Conversion of Hydrogen from node_0333_2 to node_0333 is: 0
# Conversion of Hydrogen from node_0335_1 to node_0335 is: 0
# Conversion of Hydrogen from node_0335_2 to node_0335 is: 0
# Conversion of Hydrogen from node_0336_1 to node_0336 is: 0
# Conversion of Hydrogen from node_0336_2 to node_0336 is: 0
# Conversion of Hydrogen from node_0337_1 to node_0337 is: 0
# Conversion of Hydrogen from node_0337_2 to node_0337 is: 0
# Conversion of Hydrogen from node_0338_1 to node_0338 is: 0
# Conversion of Hydrogen from node_0338_2 to node_0338 is: 0
# Conversion of Hydrogen from node_0352_1 to node_0352 is: 0
# Conversion of Hydrogen from node_0352_2 to node_0352 is: 0
# Conversion of Hydrogen from node_0371_1 to node_0371 is: 0
# Conversion of Hydrogen from node_0371_2 to node_0371 is: 0
# Conversion of Hydrogen from node_0372_1 to node_0372 is: 0
# Conversion of Hydrogen from node_0372_2 to node_0372 is: 0
# Conversion of Hydrogen from node_0380_1 to node_0380 is: 0
# Conversion of Hydrogen from node_0380_2 to node_0380 is: 0
# Conversion of Hydrogen from node_0384_1 to node_0384 is: 0
# Conversion of Hydrogen from node_0384_2 to node_0384 is: 0
# Conversion of Hydrogen from node_0384_3 to node_0384 is: 0
# Conversion of Hydrogen from node_0384_4 to node_0384 is: 0
# Conversion of Hydrogen from node_0391_1 to node_0391 is: 0
# Conversion of Hydrogen from node_0391_2 to node_0391 is: 0
# Conversion of Hydrogen from node_0393_1 to node_0393 is: 0
# Conversion of Hydrogen from node_0393_2 to node_0393 is: 0
# Conversion of Hydrogen from node_0395_1 to node_0395 is: 0
# Conversion of Hydrogen from node_0395_2 to node_0395 is: 0
# Conversion of Hydrogen from node_0395_3 to node_0395 is: 0
# Conversion of Hydrogen from node_0395_4 to node_0395 is: 0
# Conversion of Hydrogen from node_0423_1 to node_0423 is: 0
# Conversion of Hydrogen from node_0423_2 to node_0423 is: 0
# Conversion of Hydrogen from node_0429_1 to node_0429 is: 0
# Conversion of Hydrogen from node_0429_2 to node_0429 is: 0
# Conversion of Hydrogen from node_0441_1 to node_0441 is: 0
# Conversion of Hydrogen from node_0441_2 to node_0441 is: 0
# Conversion of Hydrogen from node_0447_1 to node_0447 is: 0
# Conversion of Hydrogen from node_0447_2 to node_0447 is: 0
# Conversion of Hydrogen from node_0447_3 to node_0447 is: 0
# Conversion of Hydrogen from node_0447_4 to node_0447 is: 0
# Conversion of Hydrogen from node_0450_1 to node_0450 is: 0
# Conversion of Hydrogen from node_0450_2 to node_0450 is: 0
# Conversion of Hydrogen from node_0450_3 to node_0450 is: 0
# Conversion of Hydrogen from node_0450_4 to node_0450 is: 0
# Conversion of Hydrogen from node_0453_1 to node_0453 is: 0
# Conversion of Hydrogen from node_0453_2 to node_0453 is: 0
# Conversion of Hydrogen from node_0453_3 to node_0453 is: 0
# Conversion of Hydrogen from node_0453_4 to node_0453 is: 0
# Conversion of Hydrogen from node_0455_1 to node_0455 is: 0
# Conversion of Hydrogen from node_0455_2 to node_0455 is: 0
# Conversion of Hydrogen from node_0473_1 to node_0473 is: 0
# Conversion of Hydrogen from node_0473_2 to node_0473 is: 0
# Conversion of Hydrogen from node_0482_1 to node_0482 is: 0
# Conversion of Hydrogen from node_0482_2 to node_0482 is: 0
# Conversion of Hydrogen from node_0482_3 to node_0482 is: 0
# Conversion of Hydrogen from node_0482_4 to node_0482 is: 0
# Conversion of Hydrogen from node_0485_1 to node_0485 is: 0
# Conversion of Hydrogen from node_0485_2 to node_0485 is: 0
# Conversion of Hydrogen from node_0493_1 to node_0493 is: 0
# Conversion of Hydrogen from node_0493_2 to node_0493 is: 0
# Conversion of Hydrogen from node_0493_3 to node_0493 is: 0
# Conversion of Hydrogen from node_0493_4 to node_0493 is: 0
# Conversion of Hydrogen from node_0493_5 to node_0493 is: 0
# Conversion of Hydrogen from node_0494_1 to node_0494 is: 0
# Conversion of Hydrogen from node_0494_2 to node_0494 is: 0
# Conversion of Hydrogen from node_0494_3 to node_0494 is: 0
# Conversion of Hydrogen from node_0494_4 to node_0494 is: 0
# Conversion of Hydrogen from node_0496_1 to node_0496 is: 0
# Conversion of Hydrogen from node_0496_2 to node_0496 is: 0
# Conversion of Hydrogen from node_0496_3 to node_0496 is: 0
# Conversion of Hydrogen from node_0496_4 to node_0496 is: 0
# Conversion of Hydrogen from node_0496_5 to node_0496 is: 0
# Conversion of Hydrogen from node_0498_1 to node_0498 is: 0
# Conversion of Hydrogen from node_0498_2 to node_0498 is: 0
# Conversion of Hydrogen from node_0516_1 to node_0516 is: 0
# Conversion of Hydrogen from node_0516_2 to node_0516 is: 0
# Conversion of Hydrogen from node_0525_1 to node_0525 is: 0
# Conversion of Hydrogen from node_0525_2 to node_0525 is: 0
# Conversion of Hydrogen from node_0545_1 to node_0545 is: 0
# Conversion of Hydrogen from node_0545_2 to node_0545 is: 0
# Conversion of Hydrogen from node_0556_1 to node_0556 is: 0
# Conversion of Hydrogen from node_0556_2 to node_0556 is: 0
# Conversion of Hydrogen from node_0556_3 to node_0556 is: 0
# Conversion of Hydrogen from node_0556_4 to node_0556 is: 0
# Conversion of Hydrogen from node_0562_1 to node_0562 is: 0
# Conversion of Hydrogen from node_0562_2 to node_0562 is: 0
# Conversion of Hydrogen from node_0562_3 to node_0562 is: 0
# Conversion of Hydrogen from node_0567_1 to node_0567 is: 0
# Conversion of Hydrogen from node_0567_2 to node_0567 is: 0
# Conversion of Hydrogen from node_0567_3 to node_0567 is: 0
# Conversion of Hydrogen from node_0569_1 to node_0569 is: 0
# Conversion of Hydrogen from node_0569_2 to node_0569 is: 0
# Conversion of Hydrogen from node_0577_1 to node_0577 is: 0
# Conversion of Hydrogen from node_0577_2 to node_0577 is: 0
# Conversion of Hydrogen from node_0584_1 to node_0584 is: 0
# Conversion of Hydrogen from node_0584_2 to node_0584 is: 0
# Conversion of Hydrogen from node_0643_1 to node_0643 is: 0
# Conversion of Hydrogen from node_0643_2 to node_0643 is: 0
